# %%
# boolean network packages
from sad2_final_project.analysis import BooleanNetworkExperiment
# system packages
import os
from pathlib import Path


# paths
## set global dir
cwd=Path.cwd()
if cwd.name == "notebooks":
    os.chdir(cwd.parent) 
print(os.getcwd())
## create paths 
DATA_PATH = Path('data')
# # TODO OBSOLETE 
# DATASET_PATH = DATA_PATH / 'datasets'
# BN_TRUE_PATH = DATA_PATH / 'bn_ground_truth'
# BN_DATASET_BNFINDER_FORMAT_PATH = DATA_PATH / 'datasets_bnfinder_format'
# BN_RESULT_PATH = DATA_PATH / "result"
## create directories
# !mkdir -p {DATA_PATH}
# TODO OBSOLETE
# !mkdir -p {DATASET_PATH}
# !mkdir -p {BN_TRUE_PATH}
# !mkdir -p {BN_DATASET_BNFINDER_FORMAT_PATH}
# !mkdir -p {BN_RESULT_PATH}
# Out:
# /home/asia/rok3/sad2/final_project/SAD2_final_project

# %%
# TODO: REMOVE - only for fast test s
# create experiments:
## case: Relation between trajectory length and entering attractors
exp_trajectory_length = BooleanNetworkExperiment(
    # paths
    data_path=DATA_PATH,
    experiment_name='MICHAŁ_METRICS',
    # experiment values
    num_nodes=[6, 10],
    update_mode=["synchronous", "asynchronous"], # , "asynchronous"
    trajectory_length=list(range(10, 40, 100)),
    n_trajectories=[10],
    sampling_frequency=[3],
    score_functions=["MDL"],
    # TODO - add metrics options 

    n_parents_per_node=[[2, 3, 4]],
    # amount of samples per experiment 
    n_repetitions=1,
    simulate_trajectories_to_csv_kwargs = {
            # "sampling_frequency": 1,
            "target_attractor_ratio": 0.5,  # Approximate fraction of trajectory in attractor (0-1)
            "tolerance": 0.25,               # Allowed deviation from the calculated entrance step (0-1)
        }
) 
exp_trajectory_length.show_experiment_df()

exp_trajectory_length.normalize_sample(100)

# %%
# Uruchomienie pełnego eksperymentu (test całego pipeline'u)
exp_trajectory_length.run_experiment(n_jobs=1)

# Sprawdzenie, jakie pliki zostały wygenerowane
from pathlib import Path
import os

experiment_dir = Path("data/MICHAŁ_METRICS")
print("Zawartość katalogu eksperymentu:")
for path in experiment_dir.rglob("*"):
    print(path)
# Out:
# Dataset saved to data/MICHAŁ_METRICS/datasets/0000.csv (actual attractor ratio: 0.87)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0000.csv
#    Loaded dataset with shape: (1800, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0000.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0000.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0000_MDL.sif
# ('G1', 'G3')
# ('G1', 'G4')
# ('G1', 'G5')
# ('G2', 'G3')
# ('G2', 'G5')
# ('G3', 'G1')
# ('G3', 'G2')
# ('G3', 'G6')
# ('G4', 'G2')
# ('G4', 'G6')
# ('G5', 'G1')
# ('G5', 'G6')
# ('G6', 'G1')
# ('G6', 'G5')
# [MDL] Inferred 14 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
# Dataset saved to data/MICHAŁ_METRICS/datasets/0001.csv (actual attractor ratio: 0.63)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0001.csv
#    Loaded dataset with shape: (600, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0001.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0001.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0001_MDL.sif
# ('G1', 'G2')
# ('G1', 'G3')
# ('G1', 'G5')
# ('G1', 'G6')
# ('G2', 'G1')
# ('G2', 'G4')
# ('G2', 'G5')
# ('G4', 'G3')
# ('G5', 'G1')
# ('G5', 'G2')
# ('G5', 'G6')
# ('G6', 'G1')
# ('G6', 'G2')
# ('G6', 'G5')
# [MDL] Inferred 14 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
# Dataset saved to data/MICHAŁ_METRICS/datasets/0002.csv (actual attractor ratio: 0.84)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0002.csv
#    Loaded dataset with shape: (3000, 10)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0002.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0002.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0002_MDL.sif
# ('G1', 'G6')
# ('G1', 'G8')
# ('G1', 'G9')
# ('G2', 'G1')
# ('G2', 'G3')
# ('G2', 'G4')
# ('G2', 'G6')
# ('G2', 'G7')
# ('G2', 'G8')
# ('G2', 'G9')
# ('G2', 'G10')
# ('G3', 'G1')
# ('G3', 'G2')
# ('G3', 'G5')
# ('G3', 'G6')
# ('G3', 'G9')
# ('G4', 'G8')
# ('G5', 'G2')
# ('G5', 'G3')
# ('G5', 'G7')
# ('G6', 'G1')
# ('G6', 'G2')
# ('G6', 'G3')
# ('G6', 'G4')
# ('G6', 'G5')
# ('G6', 'G7')
# ('G6', 'G8')
# ('G6', 'G10')
# ('G7', 'G1')
# ('G7', 'G6')
# ('G7', 'G10')
# ('G8', 'G3')
# ('G8', 'G4')
# ('G8', 'G5')
# ('G8', 'G6')
# ('G8', 'G7')
# ('G9', 'G2')
# ('G9', 'G3')
# ('G9', 'G4')
# ('G9', 'G5')
# ('G9', 'G7')
# [MDL] Inferred 41 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
# Dataset saved to data/MICHAŁ_METRICS/datasets/0003.csv (actual attractor ratio: 0.25)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0003.csv
#    Loaded dataset with shape: (1000, 10)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0003.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0003.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0003_MDL.sif
# ('G1', 'G4')
# ('G1', 'G7')
# ('G1', 'G10')
# ('G2', 'G9')
# ('G3', 'G6')
# ('G4', 'G1')
# ('G4', 'G2')
# ('G4', 'G6')
# ('G5', 'G1')
# ('G5', 'G4')
# ('G5', 'G8')
# ('G6', 'G3')
# ('G6', 'G8')
# ('G7', 'G1')
# ('G7', 'G4')
# ('G7', 'G9')
# ('G7', 'G10')
# ('G8', 'G2')
# ('G8', 'G5')
# ('G8', 'G6')
# ('G9', 'G2')
# ('G9', 'G5')
# ('G9', 'G7')
# ('G10', 'G5')
# ('G10', 'G7')
# [MDL] Inferred 25 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
#
# [SUMMARY] Generated datasets: 4/4
# Zawartość katalogu eksperymentu:
# data/MICHAŁ_METRICS/datasets_bnfinder
# data/MICHAŁ_METRICS/results
# data/MICHAŁ_METRICS/bn_ground_truth
# data/MICHAŁ_METRICS/datasets
# data/MICHAŁ_METRICS/datasets_bnfinder/0001.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0003.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0002.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0000.txt
# data/MICHAŁ_METRICS/results/metadata.csv
# data/MICHAŁ_METRICS/results/0003_MDL_log.txt
# data/MICHAŁ_METRICS/results/0000_MDL_log.txt
# data/MICHAŁ_METRICS/results/0002_MDL.sif
# data/MICHAŁ_METRICS/results/0001_MDL.sif
# data/MICHAŁ_METRICS/results/0001_MDL_log.txt
# data/MICHAŁ_METRICS/results/joined_results_MICHAŁ_METRICS.csv
# data/MICHAŁ_METRICS/results/0003_MDL.sif
# data/MICHAŁ_METRICS/results/0002_MDL_log.txt
# data/MICHAŁ_METRICS/results/0000_MDL.sif
# data/MICHAŁ_METRICS/bn_ground_truth/0000.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0002.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0001.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0003.csv
# data/MICHAŁ_METRICS/datasets/0000.csv
# data/MICHAŁ_METRICS/datasets/0002.csv
# data/MICHAŁ_METRICS/datasets/0001.csv
# data/MICHAŁ_METRICS/datasets/0003.csv

# %%
# TODO: REMOVE - only for fast test s
# create experiments:
## case: Relation between trajectory length and entering attractors
exp_trajectory_length = BooleanNetworkExperiment(
    # paths
    data_path=DATA_PATH,
    experiment_name='MICHAŁ_METRICS',
    # experiment values
    num_nodes=[6, 8, 12],
    update_mode=["synchronous", "asynchronous"], # , "asynchronous"
    trajectory_length=list(range(5, 10, 20)),
    n_trajectories=[10],
    sampling_frequency=[1, 3],
    score_functions=["MDL", "BDE"],
    # TODO - add metrics options 

    n_parents_per_node=[[1, 2, 3, 4]],
    # amount of samples per experiment 
    n_repetitions=1,
    simulate_trajectories_to_csv_kwargs = {
            # "sampling_frequency": 1,
            "target_attractor_ratio": 0.5,  # Approximate fraction of trajectory in attractor (0-1)
            "tolerance": 0.25,               # Allowed deviation from the calculated entrance step (0-1)
        }
) 
exp_trajectory_length.show_experiment_df()
# Out:
#     num_nodes   update_mode  trajectory_length  n_trajectories  \
# 0           6   synchronous                  5              10
# 1           6   synchronous                  5              10
# 2           6   synchronous                  5              10
# 3           6   synchronous                  5              10
# 4           6  asynchronous                  5              10
# 5           6  asynchronous                  5              10
# 6           6  asynchronous                  5              10
# 7           6  asynchronous                  5              10
# 8           8   synchronous                  5              10
# 9           8   synchronous                  5              10
# 10          8   synchronous                  5              10
# 11          8   synchronous                  5              10
# 12          8  asynchronous                  5              10
# 13          8  asynchronous                  5              10
# 14          8  asynchronous                  5              10
# 15          8  asynchronous                  5              10
# 16         12   synchronous                  5              10
# 17         12   synchronous                  5              10
# 18         12   synchronous                  5              10
# 19         12   synchronous                  5              10
# 20         12  asynchronous                  5              10
# 21         12  asynchronous                  5              10
# 22         12  asynchronous                  5              10
# 23         12  asynchronous                  5              10
#
#     sampling_frequency score_function n_parents_per_node  rep_id condition_id  \
# 0                    1            MDL       [1, 2, 3, 4]       0         0000
# 1                    1            BDE       [1, 2, 3, 4]       0         0001
# 2                    3            MDL       [1, 2, 3, 4]       0         0002
# 3                    3            BDE       [1, 2, 3, 4]       0         0003
# 4                    1            MDL       [1, 2, 3, 4]       0         0004
# 5                    1            BDE       [1, 2, 3, 4]       0         0005
# 6                    3            MDL       [1, 2, 3, 4]       0         0006
# 7                    3            BDE       [1, 2, 3, 4]       0         0007
# 8                    1            MDL       [1, 2, 3, 4]       0         0008
# 9                    1            BDE       [1, 2, 3, 4]       0         0009
# 10                   3            MDL       [1, 2, 3, 4]       0         0010
# 11                   3            BDE       [1, 2, 3, 4]       0         0011
# 12                   1            MDL       [1, 2, 3, 4]       0         0012
# 13                   1            BDE       [1, 2, 3, 4]       0         0013
# 14                   3            MDL       [1, 2, 3, 4]       0         0014
# 15                   3            BDE       [1, 2, 3, 4]       0         0015
# 16                   1            MDL       [1, 2, 3, 4]       0         0016
# 17                   1            BDE       [1, 2, 3, 4]       0         0017
# 18                   3            MDL       [1, 2, 3, 4]       0         0018
# 19                   3            BDE       [1, 2, 3, 4]       0         0019
# 20                   1            MDL       [1, 2, 3, 4]       0         0020
# 21                   1            BDE       [1, 2, 3, 4]       0         0021
# 22                   3            MDL       [1, 2, 3, 4]       0         0022
# 23                   3            BDE       [1, 2, 3, 4]       0         0023
#
#     success  attractor_ratio
# 0     False              NaN
# 1     False              NaN
# 2     False              NaN
# 3     False              NaN
# 4     False              NaN
# 5     False              NaN
# 6     False              NaN
# 7     False              NaN
# 8     False              NaN
# 9     False              NaN
# 10    False              NaN
# 11    False              NaN
# 12    False              NaN
# 13    False              NaN
# 14    False              NaN
# 15    False              NaN
# 16    False              NaN
# 17    False              NaN
# 18    False              NaN
# 19    False              NaN
# 20    False              NaN
# 21    False              NaN
# 22    False              NaN
# 23    False              NaN

# %%
# Uruchomienie pełnego eksperymentu (test całego pipeline'u)
exp_trajectory_length.run_experiment(n_jobs=1)

# Sprawdzenie, jakie pliki zostały wygenerowane
from pathlib import Path
import os

experiment_dir = Path("data/MICHAŁ_METRICS")
print("Zawartość katalogu eksperymentu:")
for path in experiment_dir.rglob("*"):
    print(path)
# Out:
# Dataset saved to data/MICHAŁ_METRICS/datasets/0000.csv (actual attractor ratio: 0.91)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0000.csv
#    Loaded dataset with shape: (100, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0000.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0000.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    BNFinder execution failed!
#    Error Output:
#  None
# [MDL] Failed: Command '['python2', '/home/maxi7524/.local/bin/bnf', '-e', PosixPath('data/MICHAŁ_METRICS/datasets_bnfinder/0000.txt'), '-n', PosixPath('data/MICHAŁ_METRICS/results/0000_MDL.sif'), '-s', 'MDL', '-v']' returned non-zero exit status 1.
#
# === DONE ===
# Dataset saved to data/MICHAŁ_METRICS/datasets/0001.csv (actual attractor ratio: 0.55)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0001.csv
#    Loaded dataset with shape: (100, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0001.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0001.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    BNFinder execution failed!
#    Error Output:
#  None
# [MDL] Failed: Command '['python2', '/home/maxi7524/.local/bin/bnf', '-e', PosixPath('data/MICHAŁ_METRICS/datasets_bnfinder/0001.txt'), '-n', PosixPath('data/MICHAŁ_METRICS/results/0001_MDL.sif'), '-s', 'MDL', '-v']' returned non-zero exit status 1.
#
# === DONE ===
# Dataset saved to data/MICHAŁ_METRICS/datasets/0002.csv (actual attractor ratio: 0.87)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0002.csv
#    Loaded dataset with shape: (100, 10)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0002.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0002.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    BNFinder execution failed!
#    Error Output:
#  None
# [MDL] Failed: Command '['python2', '/home/maxi7524/.local/bin/bnf', '-e', PosixPath('data/MICHAŁ_METRICS/datasets_bnfinder/0002.txt'), '-n', PosixPath('data/MICHAŁ_METRICS/results/0002_MDL.sif'), '-s', 'MDL', '-v']' returned non-zero exit status 1.
#
# === DONE ===
# Dataset saved to data/MICHAŁ_METRICS/datasets/0003.csv (actual attractor ratio: 0.22)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0003.csv
#    Loaded dataset with shape: (100, 10)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0003.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0003.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    BNFinder execution failed!
#    Error Output:
#  None
# [MDL] Failed: Command '['python2', '/home/maxi7524/.local/bin/bnf', '-e', PosixPath('data/MICHAŁ_METRICS/datasets_bnfinder/0003.txt'), '-n', PosixPath('data/MICHAŁ_METRICS/results/0003_MDL.sif'), '-s', 'MDL', '-v']' returned non-zero exit status 1.
#
# === DONE ===
#
# [SUMMARY] Generated datasets: 4/4
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Uruchomienie pełnego eksperymentu (test całego pipeline'u)
# ----> 2 exp_trajectory_length.run_experiment(n_jobs=1)
#       4 # Sprawdzenie, jakie pliki zostały wygenerowane
#       5 from pathlib import Path
#
# File ~/repositories/SAD2_final_project/src/sad2_final_project/analysis/experiment.py:279, in BooleanNetworkExperiment.run_experiment(self, n_jobs, subset)
#     276 print(f"\n[SUMMARY] Generated datasets: {success_count}/{len(rows)}")
#     278 # merge all csv
# --> 279 self._merge_csv()
#     280 # obtain metadata
#     281 self.save_experiment_df_to_csv()
#
# File ~/repositories/SAD2_final_project/src/sad2_final_project/analysis/experiment.py:161, in BooleanNetworkExperiment._merge_csv(self, csv_dir)
#     159 csv_files = sorted(csv_dir.glob("*.csv"))
#     160 if not csv_files:
# --> 161     raise RuntimeError("No CSV files to merge")
#     162 # join pdfs
#     163 df = pd.concat(
#     164     (pd.read_csv(f) for f in csv_files),
#     165     ignore_index=True
#     166 )
#
# RuntimeError: No CSV files to merge
