# %%
# boolean network packages
from sad2_final_project.analysis import BooleanNetworkExperiment
# system packages
import os
from pathlib import Path


# paths
## set global dir
cwd=Path.cwd()
if cwd.name == "notebooks":
    os.chdir(cwd.parent) 
print(os.getcwd())
## create paths 
DATA_PATH = Path('data')
# # TODO OBSOLETE 
# DATASET_PATH = DATA_PATH / 'datasets'
# BN_TRUE_PATH = DATA_PATH / 'bn_ground_truth'
# BN_DATASET_BNFINDER_FORMAT_PATH = DATA_PATH / 'datasets_bnfinder_format'
# BN_RESULT_PATH = DATA_PATH / "result"
## create directories
# !mkdir -p {DATA_PATH}
# TODO OBSOLETE
# !mkdir -p {DATASET_PATH}
# !mkdir -p {BN_TRUE_PATH}
# !mkdir -p {BN_DATASET_BNFINDER_FORMAT_PATH}
# !mkdir -p {BN_RESULT_PATH}
# Out:
# /home/maxi7524/repositories/SAD2_final_project

# %%
# TODO: REMOVE - only for fast test s
# create experiments:
## case: Relation between trajectory length and entering attractors
exp_trajectory_length = BooleanNetworkExperiment(
    # paths
    data_path=DATA_PATH,
    experiment_name='size_test',
    # experiment values
    num_nodes=[5],
    update_mode=["synchronous", "asynchronous"], # , "asynchronous"
    trajectory_length=[60],
    n_trajectories=[10],
    sampling_frequency=[3],
    score_functions=["MDL", "BDE"],
    # TODO - add metrics options 
    # analysis_metrics= ["TP", "FP", "FN", "precision", "recall", "sensitivity", "AHD"],

    n_parents_per_node=[[1, 2, 3]],
    # amount of samples per experiment 
    n_repetitions=2,
    simulate_trajectories_to_csv_kwargs = {
            # "sampling_frequency": 1,
            "target_attractor_ratio": 0.5,  # Approximate fraction of trajectory in attractor (0-1)
            "tolerance": 0.01,               # Allowed deviation from the calculated entrance step (0-1)
        }
) 
exp_trajectory_length.normalize_sample(100)
exp_trajectory_length.show_experiment_df()
# Out:
#    num_nodes   update_mode  trajectory_length  n_trajectories  \
# 0          5   synchronous                 60               9
# 1          5   synchronous                 60               9
# 2          5   synchronous                 60               9
# 3          5   synchronous                 60               9
# 4          5  asynchronous                 60               9
# 5          5  asynchronous                 60               9
# 6          5  asynchronous                 60               9
# 7          5  asynchronous                 60               9
#
#    sampling_frequency score_function n_parents_per_node  rep_id  \
# 0                   3            MDL          [1, 2, 3]       0
# 1                   3            MDL          [1, 2, 3]       1
# 2                   3            BDE          [1, 2, 3]       0
# 3                   3            BDE          [1, 2, 3]       1
# 4                   3            MDL          [1, 2, 3]       0
# 5                   3            MDL          [1, 2, 3]       1
# 6                   3            BDE          [1, 2, 3]       0
# 7                   3            BDE          [1, 2, 3]       1
#
#   condition_id_name  condition_id_num
# 0             00000                 0
# 1             00001                 1
# 2             00002                 2
# 3             00003                 3
# 4             00004                 4
# 5             00005                 5
# 6             00006                 6
# 7             00007                 7

# %%
exp_trajectory_length.run_experiment(progress_interval=4)
# Out:
# [Progress] 4/8 conditions completed (50.0%)
# [Progress] 8/8 conditions completed (100.0%)
# 8
