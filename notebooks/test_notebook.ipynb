# %%
# boolean network packages
from sad2_final_project.analysis import BooleanNetworkExperiment
# system packages
import os
from pathlib import Path


# paths
## set global dir
cwd=Path.cwd()
if cwd.name == "notebooks":
    os.chdir(cwd.parent) 
print(os.getcwd())
## create paths 
DATA_PATH = Path('data')
# # TODO OBSOLETE 
# DATASET_PATH = DATA_PATH / 'datasets'
# BN_TRUE_PATH = DATA_PATH / 'bn_ground_truth'
# BN_DATASET_BNFINDER_FORMAT_PATH = DATA_PATH / 'datasets_bnfinder_format'
# BN_RESULT_PATH = DATA_PATH / "result"
## create directories
# !mkdir {DATA_PATH}
# TODO OBSOLETE
# !mkdir -p {DATASET_PATH}
# !mkdir -p {BN_TRUE_PATH}
# !mkdir -p {BN_DATASET_BNFINDER_FORMAT_PATH}
# !mkdir -p {BN_RESULT_PATH}
# Out:
# /home/asia/rok3/sad2/final_project/SAD2_final_project
# mkdir: cannot create directory ‘data’: File exists

# %%
# TODO: REMOVE - only for fast test s
# create experiments:
## case: Relation between trajectory length and entering attractors
exp_trajectory_length = BooleanNetworkExperiment(
    # paths
    data_path=DATA_PATH,
    experiment_name='MICHAŁ_METRICS',
    # experiment values
    num_nodes=[6, 8],
    update_mode=["synchronous", "asynchronous"], # , "asynchronous"
    trajectory_length=list(range(10, 40, 10)),
    n_trajectories=[5, 10],
    sampling_frequency=[1, 2, 3],
    score_functions=["MDL", "BDE"],
    # TODO - add metrics options 

    n_parents_per_node=[[2, 3, 4]],
    # amount of samples per experiment 
    n_repetitions=1,
    simulate_trajectories_to_csv_kwargs = {
            # "sampling_frequency": 1,
            "target_attractor_ratio": 0.5,  # Approximate fraction of trajectory in attractor (0-1)
            "tolerance": 0.25,               # Allowed deviation from the calculated entrance step (0-1)
        }
) 
exp_trajectory_length.show_experiment_df()
# Out:
#      num_nodes   update_mode  trajectory_length  n_trajectories  \
# 0            6   synchronous                 10               5
# 1            6   synchronous                 10               5
# 2            6   synchronous                 10               5
# 3            6   synchronous                 10               5
# 4            6   synchronous                 10               5
# ..         ...           ...                ...             ...
# 139          8  asynchronous                 30              10
# 140          8  asynchronous                 30              10
# 141          8  asynchronous                 30              10
# 142          8  asynchronous                 30              10
# 143          8  asynchronous                 30              10
#
#      sampling_frequency score_function n_parents_per_node  rep_id condition_id
# 0                     1            MDL          [2, 3, 4]       0         0000
# 1                     1            BDE          [2, 3, 4]       0         0001
# 2                     2            MDL          [2, 3, 4]       0         0002
# 3                     2            BDE          [2, 3, 4]       0         0003
# 4                     3            MDL          [2, 3, 4]       0         0004
# ..                  ...            ...                ...     ...          ...
# 139                   1            BDE          [2, 3, 4]       0         0139
# 140                   2            MDL          [2, 3, 4]       0         0140
# 141                   2            BDE          [2, 3, 4]       0         0141
# 142                   3            MDL          [2, 3, 4]       0         0142
# 143                   3            BDE          [2, 3, 4]       0         0143
#
# [144 rows x 9 columns]

# %%
# Uruchomienie pełnego eksperymentu (test całego pipeline'u)
exp_trajectory_length.run_experiment(n_jobs=1)

# Sprawdzenie, jakie pliki zostały wygenerowane
from pathlib import Path
import os

experiment_dir = Path("data/MICHAŁ_METRICS")
print("Zawartość katalogu eksperymentu:")
for path in experiment_dir.rglob("*"):
    print(path)
# Out:
# Ratios
# 0.25
# 0.75
# 9 0
# remaining_states=41
# max_possible_ratio=1.0
# min_possible_ratio=0.18
# 8 1
# remaining_states=32
# max_possible_ratio=0.98
# min_possible_ratio=0.34
# 9 0
# remaining_states=23
# max_possible_ratio=0.98
# min_possible_ratio=0.52
# 9 0
# remaining_states=14
# max_possible_ratio=0.98
# min_possible_ratio=0.7
# 9 0
# remaining_states=5
# max_possible_ratio=0.98
# min_possible_ratio=0.88
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0000.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 6 3
# remaining_states=41
# max_possible_ratio=0.94
# min_possible_ratio=0.12
# 6 3
# remaining_states=32
# max_possible_ratio=0.88
# min_possible_ratio=0.24
# 7 2
# remaining_states=23
# max_possible_ratio=0.84
# min_possible_ratio=0.38
# 6 3
# remaining_states=14
# max_possible_ratio=0.78
# min_possible_ratio=0.5
# 2 7
# remaining_states=5
# max_possible_ratio=0.64
# min_possible_ratio=0.54
# Dataset saved to data/MICHAŁ_METRICS/datasets/0001.csv (actual attractor ratio: 0.60)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0001.csv
#    Loaded dataset with shape: (50, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0001.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0001.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0001_BDE.sif
# 3
# 3
# 3
# [BDE] Inferred 3 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 18 0
# remaining_states=32
# max_possible_ratio=1.0
# min_possible_ratio=0.36
# 18 0
# remaining_states=14
# max_possible_ratio=1.0
# min_possible_ratio=0.72
# 18 0
# remaining_states=-4
# max_possible_ratio=1.0
# min_possible_ratio=1.08
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0002.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 18 0
# remaining_states=32
# max_possible_ratio=1.0
# min_possible_ratio=0.36
# 16 2
# remaining_states=14
# max_possible_ratio=0.96
# min_possible_ratio=0.68
# 17 1
# remaining_states=-4
# max_possible_ratio=0.94
# min_possible_ratio=1.02
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0003.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 27 0
# remaining_states=23
# max_possible_ratio=1.0
# min_possible_ratio=0.54
# 27 0
# remaining_states=-4
# max_possible_ratio=1.0
# min_possible_ratio=1.08
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0004.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 27 0
# remaining_states=23
# max_possible_ratio=1.0
# min_possible_ratio=0.54
# 27 0
# remaining_states=-4
# max_possible_ratio=1.0
# min_possible_ratio=1.08
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0005.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 4 5
# remaining_states=91
# max_possible_ratio=0.95
# min_possible_ratio=0.04
# 6 3
# remaining_states=82
# max_possible_ratio=0.92
# min_possible_ratio=0.1
# 5 4
# remaining_states=73
# max_possible_ratio=0.88
# min_possible_ratio=0.15
# 6 3
# remaining_states=64
# max_possible_ratio=0.85
# min_possible_ratio=0.21
# 6 3
# remaining_states=55
# max_possible_ratio=0.82
# min_possible_ratio=0.27
# 6 3
# remaining_states=46
# max_possible_ratio=0.79
# min_possible_ratio=0.33
# 6 3
# remaining_states=37
# max_possible_ratio=0.76
# min_possible_ratio=0.39
# 5 4
# remaining_states=28
# max_possible_ratio=0.72
# min_possible_ratio=0.44
# 5 4
# remaining_states=19
# max_possible_ratio=0.68
# min_possible_ratio=0.49
# 6 3
# remaining_states=10
# max_possible_ratio=0.65
# min_possible_ratio=0.55
# Dataset saved to data/MICHAŁ_METRICS/datasets/0006.csv (actual attractor ratio: 0.61)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0006.csv
#    Loaded dataset with shape: (100, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0006.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0006.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0006_MDL.sif
# 3
# 3
# 3
# 3
# 3
# [MDL] Inferred 5 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 9 0
# remaining_states=91
# max_possible_ratio=1.0
# min_possible_ratio=0.09
# 8 1
# remaining_states=82
# max_possible_ratio=0.99
# min_possible_ratio=0.17
# 9 0
# remaining_states=73
# max_possible_ratio=0.99
# min_possible_ratio=0.26
# 4 5
# remaining_states=64
# max_possible_ratio=0.94
# min_possible_ratio=0.3
# 9 0
# remaining_states=55
# max_possible_ratio=0.94
# min_possible_ratio=0.39
# 9 0
# remaining_states=46
# max_possible_ratio=0.94
# min_possible_ratio=0.48
# 9 0
# remaining_states=37
# max_possible_ratio=0.94
# min_possible_ratio=0.57
# 9 0
# remaining_states=28
# max_possible_ratio=0.94
# min_possible_ratio=0.66
# 9 0
# remaining_states=19
# max_possible_ratio=0.94
# min_possible_ratio=0.75
# 9 0
# remaining_states=10
# max_possible_ratio=0.94
# min_possible_ratio=0.84
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0007.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 17 1
# remaining_states=82
# max_possible_ratio=0.99
# min_possible_ratio=0.17
# 18 0
# remaining_states=64
# max_possible_ratio=0.99
# min_possible_ratio=0.35
# 16 2
# remaining_states=46
# max_possible_ratio=0.97
# min_possible_ratio=0.51
# 18 0
# remaining_states=28
# max_possible_ratio=0.97
# min_possible_ratio=0.69
# 15 3
# remaining_states=10
# max_possible_ratio=0.94
# min_possible_ratio=0.84
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0008.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 18 0
# remaining_states=82
# max_possible_ratio=1.0
# min_possible_ratio=0.18
# 18 0
# remaining_states=64
# max_possible_ratio=1.0
# min_possible_ratio=0.36
# 18 0
# remaining_states=46
# max_possible_ratio=1.0
# min_possible_ratio=0.54
# 18 0
# remaining_states=28
# max_possible_ratio=1.0
# min_possible_ratio=0.72
# 18 0
# remaining_states=10
# max_possible_ratio=1.0
# min_possible_ratio=0.9
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0009.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 27 0
# remaining_states=73
# max_possible_ratio=1.0
# min_possible_ratio=0.27
# 26 1
# remaining_states=46
# max_possible_ratio=0.99
# min_possible_ratio=0.53
# 24 3
# remaining_states=19
# max_possible_ratio=0.96
# min_possible_ratio=0.77
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0010.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 22 5
# remaining_states=73
# max_possible_ratio=0.95
# min_possible_ratio=0.22
# 25 2
# remaining_states=46
# max_possible_ratio=0.93
# min_possible_ratio=0.47
# 22 5
# remaining_states=19
# max_possible_ratio=0.88
# min_possible_ratio=0.69
# 24 3
# remaining_states=-8
# max_possible_ratio=0.85
# min_possible_ratio=0.93
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0011.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 19 0
# remaining_states=81
# max_possible_ratio=1.0
# min_possible_ratio=0.19
# 19 0
# remaining_states=62
# max_possible_ratio=1.0
# min_possible_ratio=0.38
# 18 1
# remaining_states=43
# max_possible_ratio=0.99
# min_possible_ratio=0.56
# 17 2
# remaining_states=24
# max_possible_ratio=0.97
# min_possible_ratio=0.73
# 19 0
# remaining_states=5
# max_possible_ratio=0.97
# min_possible_ratio=0.92
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0012.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 17 2
# remaining_states=81
# max_possible_ratio=0.98
# min_possible_ratio=0.17
# 16 3
# remaining_states=62
# max_possible_ratio=0.95
# min_possible_ratio=0.33
# 17 2
# remaining_states=43
# max_possible_ratio=0.93
# min_possible_ratio=0.5
# 18 1
# remaining_states=24
# max_possible_ratio=0.92
# min_possible_ratio=0.68
# 16 3
# remaining_states=5
# max_possible_ratio=0.89
# min_possible_ratio=0.84
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0013.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 38 0
# remaining_states=62
# max_possible_ratio=1.0
# min_possible_ratio=0.38
# 38 0
# remaining_states=24
# max_possible_ratio=1.0
# min_possible_ratio=0.76
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0014.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 38 0
# remaining_states=62
# max_possible_ratio=1.0
# min_possible_ratio=0.38
# 38 0
# remaining_states=24
# max_possible_ratio=1.0
# min_possible_ratio=0.76
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0015.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 57 0
# remaining_states=43
# max_possible_ratio=1.0
# min_possible_ratio=0.57
# 56 1
# remaining_states=-14
# max_possible_ratio=0.99
# min_possible_ratio=1.13
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0016.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 55 2
# remaining_states=43
# max_possible_ratio=0.98
# min_possible_ratio=0.55
# 55 2
# remaining_states=-14
# max_possible_ratio=0.96
# min_possible_ratio=1.1
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0017.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 19 0
# remaining_states=181
# max_possible_ratio=1.0
# min_possible_ratio=0.095
# 16 3
# remaining_states=162
# max_possible_ratio=0.985
# min_possible_ratio=0.175
# 18 1
# remaining_states=143
# max_possible_ratio=0.98
# min_possible_ratio=0.265
# 18 1
# remaining_states=124
# max_possible_ratio=0.975
# min_possible_ratio=0.355
# 19 0
# remaining_states=105
# max_possible_ratio=0.975
# min_possible_ratio=0.45
# 19 0
# remaining_states=86
# max_possible_ratio=0.975
# min_possible_ratio=0.545
# 18 1
# remaining_states=67
# max_possible_ratio=0.97
# min_possible_ratio=0.635
# 18 1
# remaining_states=48
# max_possible_ratio=0.965
# min_possible_ratio=0.725
# 17 2
# remaining_states=29
# max_possible_ratio=0.955
# min_possible_ratio=0.81
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0018.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 17 2
# remaining_states=181
# max_possible_ratio=0.99
# min_possible_ratio=0.085
# 18 1
# remaining_states=162
# max_possible_ratio=0.985
# min_possible_ratio=0.175
# 18 1
# remaining_states=143
# max_possible_ratio=0.98
# min_possible_ratio=0.265
# 19 0
# remaining_states=124
# max_possible_ratio=0.98
# min_possible_ratio=0.36
# 18 1
# remaining_states=105
# max_possible_ratio=0.975
# min_possible_ratio=0.45
# 19 0
# remaining_states=86
# max_possible_ratio=0.975
# min_possible_ratio=0.545
# 19 0
# remaining_states=67
# max_possible_ratio=0.975
# min_possible_ratio=0.64
# 18 1
# remaining_states=48
# max_possible_ratio=0.97
# min_possible_ratio=0.73
# 18 1
# remaining_states=29
# max_possible_ratio=0.965
# min_possible_ratio=0.82
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0019.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 34 4
# remaining_states=162
# max_possible_ratio=0.98
# min_possible_ratio=0.17
# 36 2
# remaining_states=124
# max_possible_ratio=0.97
# min_possible_ratio=0.35
# 36 2
# remaining_states=86
# max_possible_ratio=0.96
# min_possible_ratio=0.53
# 36 2
# remaining_states=48
# max_possible_ratio=0.95
# min_possible_ratio=0.71
# 37 1
# remaining_states=10
# max_possible_ratio=0.945
# min_possible_ratio=0.895
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0020.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 36 2
# remaining_states=162
# max_possible_ratio=0.99
# min_possible_ratio=0.18
# 36 2
# remaining_states=124
# max_possible_ratio=0.98
# min_possible_ratio=0.36
# 33 5
# remaining_states=86
# max_possible_ratio=0.955
# min_possible_ratio=0.525
# 37 1
# remaining_states=48
# max_possible_ratio=0.95
# min_possible_ratio=0.71
# 36 2
# remaining_states=10
# max_possible_ratio=0.94
# min_possible_ratio=0.89
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0021.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 54 3
# remaining_states=143
# max_possible_ratio=0.985
# min_possible_ratio=0.27
# 56 1
# remaining_states=86
# max_possible_ratio=0.98
# min_possible_ratio=0.55
# 56 1
# remaining_states=29
# max_possible_ratio=0.975
# min_possible_ratio=0.83
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0022.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 55 2
# remaining_states=143
# max_possible_ratio=0.99
# min_possible_ratio=0.275
# 55 2
# remaining_states=86
# max_possible_ratio=0.98
# min_possible_ratio=0.55
# 57 0
# remaining_states=29
# max_possible_ratio=0.98
# min_possible_ratio=0.835
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0023.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 28 1
# remaining_states=121
# max_possible_ratio=0.9933333333333333
# min_possible_ratio=0.18666666666666668
# 29 0
# remaining_states=92
# max_possible_ratio=0.9933333333333333
# min_possible_ratio=0.38
# 26 3
# remaining_states=63
# max_possible_ratio=0.9733333333333334
# min_possible_ratio=0.5533333333333333
# 25 4
# remaining_states=34
# max_possible_ratio=0.9466666666666667
# min_possible_ratio=0.72
# 24 5
# remaining_states=5
# max_possible_ratio=0.9133333333333333
# min_possible_ratio=0.88
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0024.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 28 1
# remaining_states=121
# max_possible_ratio=0.9933333333333333
# min_possible_ratio=0.18666666666666668
# 29 0
# remaining_states=92
# max_possible_ratio=0.9933333333333333
# min_possible_ratio=0.38
# 28 1
# remaining_states=63
# max_possible_ratio=0.9866666666666667
# min_possible_ratio=0.5666666666666667
# 29 0
# remaining_states=34
# max_possible_ratio=0.9866666666666667
# min_possible_ratio=0.76
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0025.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 58 0
# remaining_states=92
# max_possible_ratio=1.0
# min_possible_ratio=0.38666666666666666
# 58 0
# remaining_states=34
# max_possible_ratio=1.0
# min_possible_ratio=0.7733333333333333
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0026.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 57 1
# remaining_states=92
# max_possible_ratio=0.9933333333333333
# min_possible_ratio=0.38
# 56 2
# remaining_states=34
# max_possible_ratio=0.98
# min_possible_ratio=0.7533333333333333
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0027.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 86 1
# remaining_states=63
# max_possible_ratio=0.9933333333333333
# min_possible_ratio=0.5733333333333334
# 85 2
# remaining_states=-24
# max_possible_ratio=0.98
# min_possible_ratio=1.14
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0028.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 83 4
# remaining_states=63
# max_possible_ratio=0.9733333333333334
# min_possible_ratio=0.5533333333333333
# 83 4
# remaining_states=-24
# max_possible_ratio=0.9466666666666667
# min_possible_ratio=1.1066666666666667
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0029.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 29 0
# remaining_states=271
# max_possible_ratio=1.0
# min_possible_ratio=0.09666666666666666
# 28 1
# remaining_states=242
# max_possible_ratio=0.9966666666666667
# min_possible_ratio=0.19
# 29 0
# remaining_states=213
# max_possible_ratio=0.9966666666666667
# min_possible_ratio=0.2866666666666667
# 29 0
# remaining_states=184
# max_possible_ratio=0.9966666666666667
# min_possible_ratio=0.38333333333333336
# 28 1
# remaining_states=155
# max_possible_ratio=0.9933333333333333
# min_possible_ratio=0.4766666666666667
# 29 0
# remaining_states=126
# max_possible_ratio=0.9933333333333333
# min_possible_ratio=0.5733333333333334
# 28 1
# remaining_states=97
# max_possible_ratio=0.99
# min_possible_ratio=0.6666666666666666
# 29 0
# remaining_states=68
# max_possible_ratio=0.99
# min_possible_ratio=0.7633333333333333
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0030.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 28 1
# remaining_states=271
# max_possible_ratio=0.9966666666666667
# min_possible_ratio=0.09333333333333334
# 27 2
# remaining_states=242
# max_possible_ratio=0.99
# min_possible_ratio=0.18333333333333332
# 25 4
# remaining_states=213
# max_possible_ratio=0.9766666666666667
# min_possible_ratio=0.26666666666666666
# 24 5
# remaining_states=184
# max_possible_ratio=0.96
# min_possible_ratio=0.3466666666666667
# 26 3
# remaining_states=155
# max_possible_ratio=0.95
# min_possible_ratio=0.43333333333333335
# 28 1
# remaining_states=126
# max_possible_ratio=0.9466666666666667
# min_possible_ratio=0.5266666666666666
# 27 2
# remaining_states=97
# max_possible_ratio=0.94
# min_possible_ratio=0.6166666666666667
# 29 0
# remaining_states=68
# max_possible_ratio=0.94
# min_possible_ratio=0.7133333333333334
# 25 4
# remaining_states=39
# max_possible_ratio=0.9266666666666666
# min_possible_ratio=0.7966666666666666
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0031.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 55 3
# remaining_states=242
# max_possible_ratio=0.99
# min_possible_ratio=0.18333333333333332
# 58 0
# remaining_states=184
# max_possible_ratio=0.99
# min_possible_ratio=0.37666666666666665
# 58 0
# remaining_states=126
# max_possible_ratio=0.99
# min_possible_ratio=0.57
# 58 0
# remaining_states=68
# max_possible_ratio=0.99
# min_possible_ratio=0.7633333333333333
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0032.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 54 4
# remaining_states=242
# max_possible_ratio=0.9866666666666667
# min_possible_ratio=0.18
# 55 3
# remaining_states=184
# max_possible_ratio=0.9766666666666667
# min_possible_ratio=0.36333333333333334
# 55 3
# remaining_states=126
# max_possible_ratio=0.9666666666666667
# min_possible_ratio=0.5466666666666666
# 57 1
# remaining_states=68
# max_possible_ratio=0.9633333333333334
# min_possible_ratio=0.7366666666666667
# 55 3
# remaining_states=10
# max_possible_ratio=0.9533333333333334
# min_possible_ratio=0.92
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0033.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 87 0
# remaining_states=213
# max_possible_ratio=1.0
# min_possible_ratio=0.29
# 83 4
# remaining_states=126
# max_possible_ratio=0.9866666666666667
# min_possible_ratio=0.5666666666666667
# 84 3
# remaining_states=39
# max_possible_ratio=0.9766666666666667
# min_possible_ratio=0.8466666666666667
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0034.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 85 2
# remaining_states=213
# max_possible_ratio=0.9933333333333333
# min_possible_ratio=0.2833333333333333
# 84 3
# remaining_states=126
# max_possible_ratio=0.9833333333333333
# min_possible_ratio=0.5633333333333334
# 85 2
# remaining_states=39
# max_possible_ratio=0.9766666666666667
# min_possible_ratio=0.8466666666666667
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0035.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 9
# remaining_states=41
# max_possible_ratio=0.82
# min_possible_ratio=0.0
# 0 9
# remaining_states=32
# max_possible_ratio=0.64
# min_possible_ratio=0.0
# 0 9
# remaining_states=23
# max_possible_ratio=0.46
# min_possible_ratio=0.0
# 1 8
# remaining_states=14
# max_possible_ratio=0.3
# min_possible_ratio=0.02
# 0 9
# remaining_states=5
# max_possible_ratio=0.12
# min_possible_ratio=0.02
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0036.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 9
# remaining_states=41
# max_possible_ratio=0.82
# min_possible_ratio=0.0
# 0 9
# remaining_states=32
# max_possible_ratio=0.64
# min_possible_ratio=0.0
# 1 8
# remaining_states=23
# max_possible_ratio=0.48
# min_possible_ratio=0.02
# 0 9
# remaining_states=14
# max_possible_ratio=0.3
# min_possible_ratio=0.02
# 0 9
# remaining_states=5
# max_possible_ratio=0.12
# min_possible_ratio=0.02
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0037.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 18
# remaining_states=32
# max_possible_ratio=0.64
# min_possible_ratio=0.0
# 5 13
# remaining_states=14
# max_possible_ratio=0.38
# min_possible_ratio=0.1
# 0 18
# remaining_states=-4
# max_possible_ratio=0.02
# min_possible_ratio=0.1
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0038.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 16 2
# remaining_states=32
# max_possible_ratio=0.96
# min_possible_ratio=0.32
# 8 10
# remaining_states=14
# max_possible_ratio=0.76
# min_possible_ratio=0.48
# 12 6
# remaining_states=-4
# max_possible_ratio=0.64
# min_possible_ratio=0.72
# 10 8
# remaining_states=-22
# max_possible_ratio=0.48
# min_possible_ratio=0.92
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0039.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 27
# remaining_states=23
# max_possible_ratio=0.46
# min_possible_ratio=0.0
# 12 15
# remaining_states=-4
# max_possible_ratio=0.16
# min_possible_ratio=0.24
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0040.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 25 2
# remaining_states=23
# max_possible_ratio=0.96
# min_possible_ratio=0.5
# 22 5
# remaining_states=-4
# max_possible_ratio=0.86
# min_possible_ratio=0.94
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0041.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 1 8
# remaining_states=91
# max_possible_ratio=0.92
# min_possible_ratio=0.01
# 0 9
# remaining_states=82
# max_possible_ratio=0.83
# min_possible_ratio=0.01
# 7 2
# remaining_states=73
# max_possible_ratio=0.81
# min_possible_ratio=0.08
# 8 1
# remaining_states=64
# max_possible_ratio=0.8
# min_possible_ratio=0.16
# 1 8
# remaining_states=55
# max_possible_ratio=0.72
# min_possible_ratio=0.17
# 0 9
# remaining_states=46
# max_possible_ratio=0.63
# min_possible_ratio=0.17
# 0 9
# remaining_states=37
# max_possible_ratio=0.54
# min_possible_ratio=0.17
# 8 1
# remaining_states=28
# max_possible_ratio=0.53
# min_possible_ratio=0.25
# 4 5
# remaining_states=19
# max_possible_ratio=0.48
# min_possible_ratio=0.29
# 0 9
# remaining_states=10
# max_possible_ratio=0.39
# min_possible_ratio=0.29
# Dataset saved to data/MICHAŁ_METRICS/datasets/0042.csv (actual attractor ratio: 0.32)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0042.csv
#    Loaded dataset with shape: (100, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0042.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0042.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0042_MDL.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [MDL] Inferred 9 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 0 9
# remaining_states=91
# max_possible_ratio=0.91
# min_possible_ratio=0.0
# 0 9
# remaining_states=82
# max_possible_ratio=0.82
# min_possible_ratio=0.0
# 0 9
# remaining_states=73
# max_possible_ratio=0.73
# min_possible_ratio=0.0
# 0 9
# remaining_states=64
# max_possible_ratio=0.64
# min_possible_ratio=0.0
# 0 9
# remaining_states=55
# max_possible_ratio=0.55
# min_possible_ratio=0.0
# 0 9
# remaining_states=46
# max_possible_ratio=0.46
# min_possible_ratio=0.0
# 0 9
# remaining_states=37
# max_possible_ratio=0.37
# min_possible_ratio=0.0
# 1 8
# remaining_states=28
# max_possible_ratio=0.29
# min_possible_ratio=0.01
# 0 9
# remaining_states=19
# max_possible_ratio=0.2
# min_possible_ratio=0.01
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0043.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 18 0
# remaining_states=82
# max_possible_ratio=1.0
# min_possible_ratio=0.18
# 18 0
# remaining_states=64
# max_possible_ratio=1.0
# min_possible_ratio=0.36
# 18 0
# remaining_states=46
# max_possible_ratio=1.0
# min_possible_ratio=0.54
# 18 0
# remaining_states=28
# max_possible_ratio=1.0
# min_possible_ratio=0.72
# 18 0
# remaining_states=10
# max_possible_ratio=1.0
# min_possible_ratio=0.9
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0044.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 18 0
# remaining_states=82
# max_possible_ratio=1.0
# min_possible_ratio=0.18
# 13 5
# remaining_states=64
# max_possible_ratio=0.95
# min_possible_ratio=0.31
# 13 5
# remaining_states=46
# max_possible_ratio=0.9
# min_possible_ratio=0.44
# 4 14
# remaining_states=28
# max_possible_ratio=0.76
# min_possible_ratio=0.48
# 15 3
# remaining_states=10
# max_possible_ratio=0.73
# min_possible_ratio=0.63
# 18 0
# remaining_states=-8
# max_possible_ratio=0.73
# min_possible_ratio=0.81
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0045.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 26 1
# remaining_states=73
# max_possible_ratio=0.99
# min_possible_ratio=0.26
# 27 0
# remaining_states=46
# max_possible_ratio=0.99
# min_possible_ratio=0.53
# 27 0
# remaining_states=19
# max_possible_ratio=0.99
# min_possible_ratio=0.8
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0046.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 10 17
# remaining_states=73
# max_possible_ratio=0.83
# min_possible_ratio=0.1
# 18 9
# remaining_states=46
# max_possible_ratio=0.74
# min_possible_ratio=0.28
# 9 18
# remaining_states=19
# max_possible_ratio=0.56
# min_possible_ratio=0.37
# 7 20
# remaining_states=-8
# max_possible_ratio=0.36
# min_possible_ratio=0.44
# 16 11
# remaining_states=-35
# max_possible_ratio=0.25
# min_possible_ratio=0.6
# 22 5
# remaining_states=-62
# max_possible_ratio=0.2
# min_possible_ratio=0.82
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0047.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 17 2
# remaining_states=81
# max_possible_ratio=0.98
# min_possible_ratio=0.17
# 16 3
# remaining_states=62
# max_possible_ratio=0.95
# min_possible_ratio=0.33
# 0 19
# remaining_states=43
# max_possible_ratio=0.76
# min_possible_ratio=0.33
# 5 14
# remaining_states=24
# max_possible_ratio=0.62
# min_possible_ratio=0.38
# 19 0
# remaining_states=5
# max_possible_ratio=0.62
# min_possible_ratio=0.57
# Dataset saved to data/MICHAŁ_METRICS/datasets/0048.csv (actual attractor ratio: 0.60)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0048.csv
#    Loaded dataset with shape: (100, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0048.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0048.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0048_MDL.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [MDL] Inferred 12 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 6 13
# remaining_states=81
# max_possible_ratio=0.87
# min_possible_ratio=0.06
# 16 3
# remaining_states=62
# max_possible_ratio=0.84
# min_possible_ratio=0.22
# 14 5
# remaining_states=43
# max_possible_ratio=0.79
# min_possible_ratio=0.36
# 8 11
# remaining_states=24
# max_possible_ratio=0.68
# min_possible_ratio=0.44
# 0 19
# remaining_states=5
# max_possible_ratio=0.49
# min_possible_ratio=0.44
# Dataset saved to data/MICHAŁ_METRICS/datasets/0049.csv (actual attractor ratio: 0.46)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0049.csv
#    Loaded dataset with shape: (100, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0049.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0049.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0049_BDE.sif
# 3
# 3
# 3
# 3
# [BDE] Inferred 4 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 23 15
# remaining_states=62
# max_possible_ratio=0.85
# min_possible_ratio=0.23
# 37 1
# remaining_states=24
# max_possible_ratio=0.84
# min_possible_ratio=0.6
# 27 11
# remaining_states=-14
# max_possible_ratio=0.73
# min_possible_ratio=0.87
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0050.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 37 1
# remaining_states=62
# max_possible_ratio=0.99
# min_possible_ratio=0.37
# 27 11
# remaining_states=24
# max_possible_ratio=0.88
# min_possible_ratio=0.64
# 28 10
# remaining_states=-14
# max_possible_ratio=0.78
# min_possible_ratio=0.92
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0051.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 42 15
# remaining_states=43
# max_possible_ratio=0.85
# min_possible_ratio=0.42
# 45 12
# remaining_states=-14
# max_possible_ratio=0.73
# min_possible_ratio=0.87
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0052.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 56 1
# remaining_states=43
# max_possible_ratio=0.99
# min_possible_ratio=0.56
# 49 8
# remaining_states=-14
# max_possible_ratio=0.91
# min_possible_ratio=1.05
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0053.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 9 10
# remaining_states=181
# max_possible_ratio=0.95
# min_possible_ratio=0.045
# 15 4
# remaining_states=162
# max_possible_ratio=0.93
# min_possible_ratio=0.12
# 19 0
# remaining_states=143
# max_possible_ratio=0.93
# min_possible_ratio=0.215
# 18 1
# remaining_states=124
# max_possible_ratio=0.925
# min_possible_ratio=0.305
# 8 11
# remaining_states=105
# max_possible_ratio=0.87
# min_possible_ratio=0.345
# 8 11
# remaining_states=86
# max_possible_ratio=0.815
# min_possible_ratio=0.385
# 19 0
# remaining_states=67
# max_possible_ratio=0.815
# min_possible_ratio=0.48
# 16 3
# remaining_states=48
# max_possible_ratio=0.8
# min_possible_ratio=0.56
# 18 1
# remaining_states=29
# max_possible_ratio=0.795
# min_possible_ratio=0.65
# 10 9
# remaining_states=10
# max_possible_ratio=0.75
# min_possible_ratio=0.7
# Dataset saved to data/MICHAŁ_METRICS/datasets/0054.csv (actual attractor ratio: 0.74)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0054.csv
#    Loaded dataset with shape: (200, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0054.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0054.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0054_MDL.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [MDL] Inferred 8 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 10 9
# remaining_states=181
# max_possible_ratio=0.955
# min_possible_ratio=0.05
# 15 4
# remaining_states=162
# max_possible_ratio=0.935
# min_possible_ratio=0.125
# 17 2
# remaining_states=143
# max_possible_ratio=0.925
# min_possible_ratio=0.21
# 19 0
# remaining_states=124
# max_possible_ratio=0.925
# min_possible_ratio=0.305
# 6 13
# remaining_states=105
# max_possible_ratio=0.86
# min_possible_ratio=0.335
# 12 7
# remaining_states=86
# max_possible_ratio=0.825
# min_possible_ratio=0.395
# 0 19
# remaining_states=67
# max_possible_ratio=0.73
# min_possible_ratio=0.395
# 8 11
# remaining_states=48
# max_possible_ratio=0.675
# min_possible_ratio=0.435
# 15 4
# remaining_states=29
# max_possible_ratio=0.655
# min_possible_ratio=0.51
# 17 2
# remaining_states=10
# max_possible_ratio=0.645
# min_possible_ratio=0.595
# Dataset saved to data/MICHAŁ_METRICS/datasets/0055.csv (actual attractor ratio: 0.63)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0055.csv
#    Loaded dataset with shape: (200, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0055.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0055.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0055_BDE.sif
# 3
# 3
# 3
# [BDE] Inferred 3 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 38 0
# remaining_states=162
# max_possible_ratio=1.0
# min_possible_ratio=0.19
# 0 38
# remaining_states=124
# max_possible_ratio=0.81
# min_possible_ratio=0.19
# 38 0
# remaining_states=86
# max_possible_ratio=0.81
# min_possible_ratio=0.38
# 0 38
# remaining_states=48
# max_possible_ratio=0.62
# min_possible_ratio=0.38
# 38 0
# remaining_states=10
# max_possible_ratio=0.62
# min_possible_ratio=0.57
# 38 0
# remaining_states=-28
# max_possible_ratio=0.62
# min_possible_ratio=0.76
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0056.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 35 3
# remaining_states=162
# max_possible_ratio=0.985
# min_possible_ratio=0.175
# 38 0
# remaining_states=124
# max_possible_ratio=0.985
# min_possible_ratio=0.365
# 37 1
# remaining_states=86
# max_possible_ratio=0.98
# min_possible_ratio=0.55
# 35 3
# remaining_states=48
# max_possible_ratio=0.965
# min_possible_ratio=0.725
# 38 0
# remaining_states=10
# max_possible_ratio=0.965
# min_possible_ratio=0.915
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0057.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 57
# remaining_states=143
# max_possible_ratio=0.715
# min_possible_ratio=0.0
# 57 0
# remaining_states=86
# max_possible_ratio=0.715
# min_possible_ratio=0.285
# 26 31
# remaining_states=29
# max_possible_ratio=0.56
# min_possible_ratio=0.415
# 42 15
# remaining_states=-28
# max_possible_ratio=0.485
# min_possible_ratio=0.625
# 20 37
# remaining_states=-85
# max_possible_ratio=0.3
# min_possible_ratio=0.725
# 0 57
# remaining_states=-142
# max_possible_ratio=0.015
# min_possible_ratio=0.725
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0058.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 48 9
# remaining_states=143
# max_possible_ratio=0.955
# min_possible_ratio=0.24
# 44 13
# remaining_states=86
# max_possible_ratio=0.89
# min_possible_ratio=0.46
# 47 10
# remaining_states=29
# max_possible_ratio=0.84
# min_possible_ratio=0.695
# 57 0
# remaining_states=-28
# max_possible_ratio=0.84
# min_possible_ratio=0.98
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0059.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 23 6
# remaining_states=121
# max_possible_ratio=0.96
# min_possible_ratio=0.15333333333333332
# 23 6
# remaining_states=92
# max_possible_ratio=0.92
# min_possible_ratio=0.30666666666666664
# 24 5
# remaining_states=63
# max_possible_ratio=0.8866666666666667
# min_possible_ratio=0.4666666666666667
# 24 5
# remaining_states=34
# max_possible_ratio=0.8533333333333334
# min_possible_ratio=0.6266666666666667
# 18 11
# remaining_states=5
# max_possible_ratio=0.78
# min_possible_ratio=0.7466666666666667
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0060.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 4 25
# remaining_states=121
# max_possible_ratio=0.8333333333333334
# min_possible_ratio=0.02666666666666667
# 0 29
# remaining_states=92
# max_possible_ratio=0.64
# min_possible_ratio=0.02666666666666667
# 0 29
# remaining_states=63
# max_possible_ratio=0.44666666666666666
# min_possible_ratio=0.02666666666666667
# 17 12
# remaining_states=34
# max_possible_ratio=0.36666666666666664
# min_possible_ratio=0.14
# 15 14
# remaining_states=5
# max_possible_ratio=0.2733333333333333
# min_possible_ratio=0.24
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0061.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 54 4
# remaining_states=92
# max_possible_ratio=0.9733333333333334
# min_possible_ratio=0.36
# 46 12
# remaining_states=34
# max_possible_ratio=0.8933333333333333
# min_possible_ratio=0.6666666666666666
# 26 32
# remaining_states=-24
# max_possible_ratio=0.68
# min_possible_ratio=0.84
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0062.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 39 19
# remaining_states=92
# max_possible_ratio=0.8733333333333333
# min_possible_ratio=0.26
# 52 6
# remaining_states=34
# max_possible_ratio=0.8333333333333334
# min_possible_ratio=0.6066666666666667
# 55 3
# remaining_states=-24
# max_possible_ratio=0.8133333333333334
# min_possible_ratio=0.9733333333333334
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0063.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 72 15
# remaining_states=63
# max_possible_ratio=0.9
# min_possible_ratio=0.48
# 57 30
# remaining_states=-24
# max_possible_ratio=0.7
# min_possible_ratio=0.86
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0064.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 64 23
# remaining_states=63
# max_possible_ratio=0.8466666666666667
# min_possible_ratio=0.4266666666666667
# 63 24
# remaining_states=-24
# max_possible_ratio=0.6866666666666666
# min_possible_ratio=0.8466666666666667
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0065.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 9 20
# remaining_states=271
# max_possible_ratio=0.9333333333333333
# min_possible_ratio=0.03
# 0 29
# remaining_states=242
# max_possible_ratio=0.8366666666666667
# min_possible_ratio=0.03
# 7 22
# remaining_states=213
# max_possible_ratio=0.7633333333333333
# min_possible_ratio=0.05333333333333334
# 0 29
# remaining_states=184
# max_possible_ratio=0.6666666666666666
# min_possible_ratio=0.05333333333333334
# 0 29
# remaining_states=155
# max_possible_ratio=0.57
# min_possible_ratio=0.05333333333333334
# 28 1
# remaining_states=126
# max_possible_ratio=0.5666666666666667
# min_possible_ratio=0.14666666666666667
# 25 4
# remaining_states=97
# max_possible_ratio=0.5533333333333333
# min_possible_ratio=0.23
# 0 29
# remaining_states=68
# max_possible_ratio=0.45666666666666667
# min_possible_ratio=0.23
# 12 17
# remaining_states=39
# max_possible_ratio=0.4
# min_possible_ratio=0.27
# 0 29
# remaining_states=10
# max_possible_ratio=0.30333333333333334
# min_possible_ratio=0.27
# Dataset saved to data/MICHAŁ_METRICS/datasets/0066.csv (actual attractor ratio: 0.28)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0066.csv
#    Loaded dataset with shape: (300, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0066.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0066.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0066_MDL.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [MDL] Inferred 15 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 27 2
# remaining_states=271
# max_possible_ratio=0.9933333333333333
# min_possible_ratio=0.09
# 0 29
# remaining_states=242
# max_possible_ratio=0.8966666666666666
# min_possible_ratio=0.09
# 25 4
# remaining_states=213
# max_possible_ratio=0.8833333333333333
# min_possible_ratio=0.17333333333333334
# 10 19
# remaining_states=184
# max_possible_ratio=0.82
# min_possible_ratio=0.20666666666666667
# 22 7
# remaining_states=155
# max_possible_ratio=0.7966666666666666
# min_possible_ratio=0.28
# 0 29
# remaining_states=126
# max_possible_ratio=0.7
# min_possible_ratio=0.28
# 25 4
# remaining_states=97
# max_possible_ratio=0.6866666666666666
# min_possible_ratio=0.36333333333333334
# 18 11
# remaining_states=68
# max_possible_ratio=0.65
# min_possible_ratio=0.42333333333333334
# 26 3
# remaining_states=39
# max_possible_ratio=0.64
# min_possible_ratio=0.51
# 26 3
# remaining_states=10
# max_possible_ratio=0.63
# min_possible_ratio=0.5966666666666667
# Dataset saved to data/MICHAŁ_METRICS/datasets/0067.csv (actual attractor ratio: 0.62)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0067.csv
#    Loaded dataset with shape: (300, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0067.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0067.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0067_BDE.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [BDE] Inferred 14 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 9 49
# remaining_states=242
# max_possible_ratio=0.8366666666666667
# min_possible_ratio=0.03
# 55 3
# remaining_states=184
# max_possible_ratio=0.8266666666666667
# min_possible_ratio=0.21333333333333335
# 41 17
# remaining_states=126
# max_possible_ratio=0.77
# min_possible_ratio=0.35
# 38 20
# remaining_states=68
# max_possible_ratio=0.7033333333333334
# min_possible_ratio=0.4766666666666667
# 37 21
# remaining_states=10
# max_possible_ratio=0.6333333333333333
# min_possible_ratio=0.6
# 29 29
# remaining_states=-48
# max_possible_ratio=0.5366666666666666
# min_possible_ratio=0.6966666666666667
# 53 5
# remaining_states=-106
# max_possible_ratio=0.52
# min_possible_ratio=0.8733333333333333
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0068.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 34 24
# remaining_states=242
# max_possible_ratio=0.92
# min_possible_ratio=0.11333333333333333
# 51 7
# remaining_states=184
# max_possible_ratio=0.8966666666666666
# min_possible_ratio=0.2833333333333333
# 53 5
# remaining_states=126
# max_possible_ratio=0.88
# min_possible_ratio=0.46
# 52 6
# remaining_states=68
# max_possible_ratio=0.86
# min_possible_ratio=0.6333333333333333
# 46 12
# remaining_states=10
# max_possible_ratio=0.82
# min_possible_ratio=0.7866666666666666
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0069.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 72 15
# remaining_states=213
# max_possible_ratio=0.95
# min_possible_ratio=0.24
# 46 41
# remaining_states=126
# max_possible_ratio=0.8133333333333334
# min_possible_ratio=0.3933333333333333
# 58 29
# remaining_states=39
# max_possible_ratio=0.7166666666666667
# min_possible_ratio=0.5866666666666667
# 82 5
# remaining_states=-48
# max_possible_ratio=0.7
# min_possible_ratio=0.86
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0070.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 66 21
# remaining_states=213
# max_possible_ratio=0.93
# min_possible_ratio=0.22
# 63 24
# remaining_states=126
# max_possible_ratio=0.85
# min_possible_ratio=0.43
# 65 22
# remaining_states=39
# max_possible_ratio=0.7766666666666666
# min_possible_ratio=0.6466666666666666
# 80 7
# remaining_states=-48
# max_possible_ratio=0.7533333333333333
# min_possible_ratio=0.9133333333333333
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0071.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 6 3
# remaining_states=41
# max_possible_ratio=0.94
# min_possible_ratio=0.12
# 5 4
# remaining_states=32
# max_possible_ratio=0.86
# min_possible_ratio=0.22
# 9 0
# remaining_states=23
# max_possible_ratio=0.86
# min_possible_ratio=0.4
# 7 2
# remaining_states=14
# max_possible_ratio=0.82
# min_possible_ratio=0.54
# 7 2
# remaining_states=5
# max_possible_ratio=0.78
# min_possible_ratio=0.68
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0072.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 5 4
# remaining_states=41
# max_possible_ratio=0.92
# min_possible_ratio=0.1
# 9 0
# remaining_states=32
# max_possible_ratio=0.92
# min_possible_ratio=0.28
# 7 2
# remaining_states=23
# max_possible_ratio=0.88
# min_possible_ratio=0.42
# 5 4
# remaining_states=14
# max_possible_ratio=0.8
# min_possible_ratio=0.52
# 8 1
# remaining_states=5
# max_possible_ratio=0.78
# min_possible_ratio=0.68
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0073.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 17 1
# remaining_states=32
# max_possible_ratio=0.98
# min_possible_ratio=0.34
# 14 4
# remaining_states=14
# max_possible_ratio=0.9
# min_possible_ratio=0.62
# 17 1
# remaining_states=-4
# max_possible_ratio=0.88
# min_possible_ratio=0.96
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0074.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 15 3
# remaining_states=32
# max_possible_ratio=0.94
# min_possible_ratio=0.3
# 16 2
# remaining_states=14
# max_possible_ratio=0.9
# min_possible_ratio=0.62
# 16 2
# remaining_states=-4
# max_possible_ratio=0.86
# min_possible_ratio=0.94
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0075.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 21 6
# remaining_states=23
# max_possible_ratio=0.88
# min_possible_ratio=0.42
# 26 1
# remaining_states=-4
# max_possible_ratio=0.86
# min_possible_ratio=0.94
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0076.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 24 3
# remaining_states=23
# max_possible_ratio=0.94
# min_possible_ratio=0.48
# 26 1
# remaining_states=-4
# max_possible_ratio=0.92
# min_possible_ratio=1.0
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0077.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 8 1
# remaining_states=91
# max_possible_ratio=0.99
# min_possible_ratio=0.08
# 8 1
# remaining_states=82
# max_possible_ratio=0.98
# min_possible_ratio=0.16
# 9 0
# remaining_states=73
# max_possible_ratio=0.98
# min_possible_ratio=0.25
# 8 1
# remaining_states=64
# max_possible_ratio=0.97
# min_possible_ratio=0.33
# 8 1
# remaining_states=55
# max_possible_ratio=0.96
# min_possible_ratio=0.41
# 8 1
# remaining_states=46
# max_possible_ratio=0.95
# min_possible_ratio=0.49
# 4 5
# remaining_states=37
# max_possible_ratio=0.9
# min_possible_ratio=0.53
# 5 4
# remaining_states=28
# max_possible_ratio=0.86
# min_possible_ratio=0.58
# 8 1
# remaining_states=19
# max_possible_ratio=0.85
# min_possible_ratio=0.66
# 9 0
# remaining_states=10
# max_possible_ratio=0.85
# min_possible_ratio=0.75
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0078.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 8 1
# remaining_states=91
# max_possible_ratio=0.99
# min_possible_ratio=0.08
# 8 1
# remaining_states=82
# max_possible_ratio=0.98
# min_possible_ratio=0.16
# 8 1
# remaining_states=73
# max_possible_ratio=0.97
# min_possible_ratio=0.24
# 9 0
# remaining_states=64
# max_possible_ratio=0.97
# min_possible_ratio=0.33
# 8 1
# remaining_states=55
# max_possible_ratio=0.96
# min_possible_ratio=0.41
# 9 0
# remaining_states=46
# max_possible_ratio=0.96
# min_possible_ratio=0.5
# 9 0
# remaining_states=37
# max_possible_ratio=0.96
# min_possible_ratio=0.59
# 8 1
# remaining_states=28
# max_possible_ratio=0.95
# min_possible_ratio=0.67
# 8 1
# remaining_states=19
# max_possible_ratio=0.94
# min_possible_ratio=0.75
# 8 1
# remaining_states=10
# max_possible_ratio=0.93
# min_possible_ratio=0.83
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0079.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 16 2
# remaining_states=82
# max_possible_ratio=0.98
# min_possible_ratio=0.16
# 13 5
# remaining_states=64
# max_possible_ratio=0.93
# min_possible_ratio=0.29
# 15 3
# remaining_states=46
# max_possible_ratio=0.9
# min_possible_ratio=0.44
# 16 2
# remaining_states=28
# max_possible_ratio=0.88
# min_possible_ratio=0.6
# 16 2
# remaining_states=10
# max_possible_ratio=0.86
# min_possible_ratio=0.76
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0080.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 15 3
# ...
# Ratios
# 0.25
# 0.75
# 77 10
# remaining_states=63
# max_possible_ratio=0.9333333333333333
# min_possible_ratio=0.5133333333333333
# 35 52
# remaining_states=-24
# max_possible_ratio=0.5866666666666667
# min_possible_ratio=0.7466666666666667
# 65 22
# remaining_states=-111
# max_possible_ratio=0.44
# min_possible_ratio=1.18
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0137.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 29
# remaining_states=271
# max_possible_ratio=0.9033333333333333
# min_possible_ratio=0.0
# 23 6
# remaining_states=242
# max_possible_ratio=0.8833333333333333
# min_possible_ratio=0.07666666666666666
# 0 29
# remaining_states=213
# max_possible_ratio=0.7866666666666666
# min_possible_ratio=0.07666666666666666
# 10 19
# remaining_states=184
# max_possible_ratio=0.7233333333333334
# min_possible_ratio=0.11
# 9 20
# remaining_states=155
# max_possible_ratio=0.6566666666666666
# min_possible_ratio=0.14
# 23 6
# remaining_states=126
# max_possible_ratio=0.6366666666666667
# min_possible_ratio=0.21666666666666667
# 15 14
# remaining_states=97
# max_possible_ratio=0.59
# min_possible_ratio=0.26666666666666666
# 18 11
# remaining_states=68
# max_possible_ratio=0.5533333333333333
# min_possible_ratio=0.32666666666666666
# 14 15
# remaining_states=39
# max_possible_ratio=0.5033333333333333
# min_possible_ratio=0.37333333333333335
# 27 2
# remaining_states=10
# max_possible_ratio=0.49666666666666665
# min_possible_ratio=0.4633333333333333
# Dataset saved to data/MICHAŁ_METRICS/datasets/0138.csv (actual attractor ratio: 0.48)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0138.csv
#    Loaded dataset with shape: (300, 8)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0138.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0138.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0138_MDL.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [MDL] Inferred 21 edges.
# a
#    (Ground truth file found, evaluating metrics)
# b
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 0 29
# remaining_states=271
# max_possible_ratio=0.9033333333333333
# min_possible_ratio=0.0
# 23 6
# remaining_states=242
# max_possible_ratio=0.8833333333333333
# min_possible_ratio=0.07666666666666666
# 0 29
# remaining_states=213
# max_possible_ratio=0.7866666666666666
# min_possible_ratio=0.07666666666666666
# 0 29
# remaining_states=184
# max_possible_ratio=0.69
# min_possible_ratio=0.07666666666666666
# 0 29
# remaining_states=155
# max_possible_ratio=0.5933333333333334
# min_possible_ratio=0.07666666666666666
# 0 29
# remaining_states=126
# max_possible_ratio=0.49666666666666665
# min_possible_ratio=0.07666666666666666
# 0 29
# remaining_states=97
# max_possible_ratio=0.4
# min_possible_ratio=0.07666666666666666
# 14 15
# remaining_states=68
# max_possible_ratio=0.35
# min_possible_ratio=0.12333333333333334
# 9 20
# remaining_states=39
# max_possible_ratio=0.2833333333333333
# min_possible_ratio=0.15333333333333332
# 0 29
# remaining_states=10
# max_possible_ratio=0.18666666666666668
# min_possible_ratio=0.15333333333333332
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0139.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 39 19
# remaining_states=242
# max_possible_ratio=0.9366666666666666
# min_possible_ratio=0.13
# 27 31
# remaining_states=184
# max_possible_ratio=0.8333333333333334
# min_possible_ratio=0.22
# 39 19
# remaining_states=126
# max_possible_ratio=0.77
# min_possible_ratio=0.35
# 15 43
# remaining_states=68
# max_possible_ratio=0.6266666666666667
# min_possible_ratio=0.4
# 36 22
# remaining_states=10
# max_possible_ratio=0.5533333333333333
# min_possible_ratio=0.52
# 42 16
# remaining_states=-48
# max_possible_ratio=0.5
# min_possible_ratio=0.66
# 3 55
# remaining_states=-106
# max_possible_ratio=0.31666666666666665
# min_possible_ratio=0.67
# 40 18
# remaining_states=-164
# max_possible_ratio=0.25666666666666665
# min_possible_ratio=0.8033333333333333
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0140.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 42 16
# remaining_states=242
# max_possible_ratio=0.9466666666666667
# min_possible_ratio=0.14
# 31 27
# remaining_states=184
# max_possible_ratio=0.8566666666666667
# min_possible_ratio=0.24333333333333335
# 35 23
# remaining_states=126
# max_possible_ratio=0.78
# min_possible_ratio=0.36
# 4 54
# remaining_states=68
# max_possible_ratio=0.6
# min_possible_ratio=0.37333333333333335
# 47 11
# remaining_states=10
# max_possible_ratio=0.5633333333333334
# min_possible_ratio=0.53
# 45 13
# remaining_states=-48
# max_possible_ratio=0.52
# min_possible_ratio=0.68
# 41 17
# remaining_states=-106
# max_possible_ratio=0.4633333333333333
# min_possible_ratio=0.8166666666666667
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0141.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 71 16
# remaining_states=213
# max_possible_ratio=0.9466666666666667
# min_possible_ratio=0.23666666666666666
# 63 24
# remaining_states=126
# max_possible_ratio=0.8666666666666667
# min_possible_ratio=0.44666666666666666
# 82 5
# remaining_states=39
# max_possible_ratio=0.85
# min_possible_ratio=0.72
# 60 27
# remaining_states=-48
# max_possible_ratio=0.76
# min_possible_ratio=0.92
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0142.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 87 0
# remaining_states=213
# max_possible_ratio=1.0
# min_possible_ratio=0.29
# 87 0
# remaining_states=126
# max_possible_ratio=1.0
# min_possible_ratio=0.58
# 87 0
# remaining_states=39
# max_possible_ratio=1.0
# min_possible_ratio=0.87
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0143.csv NOT created (requirements not met). Skipping inference.
#
# [SUMMARY] Generated datasets: 11/144
# Zawartość katalogu eksperymentu:
# data/MICHAŁ_METRICS/datasets_bnfinder
# data/MICHAŁ_METRICS/results
# data/MICHAŁ_METRICS/bn_ground_truth
# data/MICHAŁ_METRICS/datasets
# data/MICHAŁ_METRICS/datasets_bnfinder/0061.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0001.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0048.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0126.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0073.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0036.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0060.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0042.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0078.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0006.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0127.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0066.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0055.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0115.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0133.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0067.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0049.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0054.txt
# data/MICHAŁ_METRICS/datasets_bnfinder/0138.txt
# data/MICHAŁ_METRICS/results/0133_BDE.sif
# data/MICHAŁ_METRICS/results/metadata.csv
# data/MICHAŁ_METRICS/results/0061_BDE_log.txt
# data/MICHAŁ_METRICS/results/0060_MDL.sif
# data/MICHAŁ_METRICS/results/0049_BDE.sif
# data/MICHAŁ_METRICS/results/0078_MDL_log.txt
# data/MICHAŁ_METRICS/results/0036_MDL_log.txt
# data/MICHAŁ_METRICS/results/0048_MDL_log.txt
# data/MICHAŁ_METRICS/results/0001_BDE.sif
# data/MICHAŁ_METRICS/results/0036_MDL.sif
# data/MICHAŁ_METRICS/results/0006_MDL_log.txt
# data/MICHAŁ_METRICS/results/0127_BDE_log.txt
# data/MICHAŁ_METRICS/results/0126_MDL_log.txt
# data/MICHAŁ_METRICS/results/0115_BDE.sif
# data/MICHAŁ_METRICS/results/0138_MDL.sif
# data/MICHAŁ_METRICS/results/0055_BDE.sif
# data/MICHAŁ_METRICS/results/0067_BDE.sif
# data/MICHAŁ_METRICS/results/0048_MDL.sif
# data/MICHAŁ_METRICS/results/0006_MDL.sif
# data/MICHAŁ_METRICS/results/0054_MDL.sif
# data/MICHAŁ_METRICS/results/0115_BDE_log.txt
# data/MICHAŁ_METRICS/results/0078_MDL.sif
# data/MICHAŁ_METRICS/results/0060_MDL_log.txt
# data/MICHAŁ_METRICS/results/0001_BDE_log.txt
# data/MICHAŁ_METRICS/results/0061_BDE.sif
# data/MICHAŁ_METRICS/results/0127_BDE.sif
# data/MICHAŁ_METRICS/results/0049_BDE_log.txt
# data/MICHAŁ_METRICS/results/0054_MDL_log.txt
# data/MICHAŁ_METRICS/results/0066_MDL.sif
# data/MICHAŁ_METRICS/results/0042_MDL_log.txt
# data/MICHAŁ_METRICS/results/0133_BDE_log.txt
# data/MICHAŁ_METRICS/results/0073_BDE.sif
# data/MICHAŁ_METRICS/results/joined_results_MICHAŁ_METRICS.csv
# data/MICHAŁ_METRICS/results/0073_BDE_log.txt
# data/MICHAŁ_METRICS/results/0066_MDL_log.txt
# data/MICHAŁ_METRICS/results/0067_BDE_log.txt
# data/MICHAŁ_METRICS/results/0055_BDE_log.txt
# data/MICHAŁ_METRICS/results/0042_MDL.sif
# data/MICHAŁ_METRICS/results/0126_MDL.sif
# data/MICHAŁ_METRICS/results/0138_MDL_log.txt
# data/MICHAŁ_METRICS/bn_ground_truth/0068.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0063.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0139.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0092.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0021.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0030.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0078.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0105.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0053.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0000.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0048.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0088.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0050.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0024.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0011.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0083.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0117.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0121.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0032.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0093.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0038.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0044.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0096.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0037.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0002.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0097.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0013.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0110.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0101.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0137.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0087.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0085.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0089.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0016.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0039.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0025.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0017.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0086.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0130.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0076.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0022.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0028.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0047.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0031.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0027.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0080.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0108.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0103.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0009.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0054.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0081.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0091.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0077.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0026.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0019.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0100.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0140.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0055.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0079.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0035.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0104.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0131.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0082.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0123.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0075.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0034.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0069.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0099.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0119.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0006.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0052.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0136.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0127.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0049.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0114.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0106.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0133.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0033.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0046.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0012.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0061.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0070.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0126.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0062.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0141.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0128.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0071.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0102.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0020.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0098.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0142.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0084.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0064.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0122.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0005.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0090.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0129.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0066.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0095.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0125.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0056.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0074.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0008.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0010.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0134.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0001.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0029.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0115.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0007.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0143.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0051.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0041.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0112.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0120.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0107.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0040.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0132.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0118.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0018.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0015.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0111.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0057.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0072.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0124.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0043.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0135.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0094.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0023.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0042.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0065.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0073.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0004.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0067.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0109.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0138.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0116.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0014.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0036.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0060.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0045.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0058.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0113.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0059.csv
# data/MICHAŁ_METRICS/bn_ground_truth/0003.csv
# data/MICHAŁ_METRICS/datasets/0078.csv
# data/MICHAŁ_METRICS/datasets/0048.csv
# data/MICHAŁ_METRICS/datasets/0054.csv
# data/MICHAŁ_METRICS/datasets/0055.csv
# data/MICHAŁ_METRICS/datasets/0006.csv
# data/MICHAŁ_METRICS/datasets/0127.csv
# data/MICHAŁ_METRICS/datasets/0049.csv
# data/MICHAŁ_METRICS/datasets/0133.csv
# data/MICHAŁ_METRICS/datasets/0061.csv
# data/MICHAŁ_METRICS/datasets/0126.csv
# data/MICHAŁ_METRICS/datasets/0066.csv
# data/MICHAŁ_METRICS/datasets/0001.csv
# data/MICHAŁ_METRICS/datasets/0115.csv
# data/MICHAŁ_METRICS/datasets/0042.csv
# data/MICHAŁ_METRICS/datasets/0073.csv
# data/MICHAŁ_METRICS/datasets/0067.csv
# data/MICHAŁ_METRICS/datasets/0138.csv
# data/MICHAŁ_METRICS/datasets/0036.csv
# data/MICHAŁ_METRICS/datasets/0060.csv

# %%
# TODO: REMOVE - only for fast test s
# create experiments:
## case: Relation between trajectory length and entering attractors
exp_trajectory_length = BooleanNetworkExperiment(
    # paths
    data_path=DATA_PATH,
    experiment_name='MICHAŁ_METRICS',
    # experiment values
    num_nodes=[6, 8, 12],
    update_mode=["synchronous", "asynchronous"], # , "asynchronous"
    trajectory_length=list(range(5, 10, 20)),
    n_trajectories=[10],
    sampling_frequency=[1, 3],
    score_functions=["MDL", "BDE"],
    # TODO - add metrics options 

    n_parents_per_node=[[1, 2, 3, 4]],
    # amount of samples per experiment 
    n_repetitions=1,
    simulate_trajectories_to_csv_kwargs = {
            # "sampling_frequency": 1,
            "target_attractor_ratio": 0.5,  # Approximate fraction of trajectory in attractor (0-1)
            "tolerance": 0.25,               # Allowed deviation from the calculated entrance step (0-1)
        }
) 
exp_trajectory_length.show_experiment_df()
# Out:
#     num_nodes   update_mode  trajectory_length  n_trajectories  \
# 0           6   synchronous                  5              10
# 1           6   synchronous                  5              10
# 2           6   synchronous                  5              10
# 3           6   synchronous                  5              10
# 4           6  asynchronous                  5              10
# 5           6  asynchronous                  5              10
# 6           6  asynchronous                  5              10
# 7           6  asynchronous                  5              10
# 8           8   synchronous                  5              10
# 9           8   synchronous                  5              10
# 10          8   synchronous                  5              10
# 11          8   synchronous                  5              10
# 12          8  asynchronous                  5              10
# 13          8  asynchronous                  5              10
# 14          8  asynchronous                  5              10
# 15          8  asynchronous                  5              10
# 16         12   synchronous                  5              10
# 17         12   synchronous                  5              10
# 18         12   synchronous                  5              10
# 19         12   synchronous                  5              10
# 20         12  asynchronous                  5              10
# 21         12  asynchronous                  5              10
# 22         12  asynchronous                  5              10
# 23         12  asynchronous                  5              10
#
#     sampling_frequency score_function n_parents_per_node  rep_id condition_id
# 0                    1            MDL       [1, 2, 3, 4]       0         0000
# 1                    1            BDE       [1, 2, 3, 4]       0         0001
# 2                    3            MDL       [1, 2, 3, 4]       0         0002
# 3                    3            BDE       [1, 2, 3, 4]       0         0003
# 4                    1            MDL       [1, 2, 3, 4]       0         0004
# 5                    1            BDE       [1, 2, 3, 4]       0         0005
# 6                    3            MDL       [1, 2, 3, 4]       0         0006
# 7                    3            BDE       [1, 2, 3, 4]       0         0007
# 8                    1            MDL       [1, 2, 3, 4]       0         0008
# 9                    1            BDE       [1, 2, 3, 4]       0         0009
# 10                   3            MDL       [1, 2, 3, 4]       0         0010
# 11                   3            BDE       [1, 2, 3, 4]       0         0011
# 12                   1            MDL       [1, 2, 3, 4]       0         0012
# 13                   1            BDE       [1, 2, 3, 4]       0         0013
# 14                   3            MDL       [1, 2, 3, 4]       0         0014
# 15                   3            BDE       [1, 2, 3, 4]       0         0015
# 16                   1            MDL       [1, 2, 3, 4]       0         0016
# 17                   1            BDE       [1, 2, 3, 4]       0         0017
# 18                   3            MDL       [1, 2, 3, 4]       0         0018
# 19                   3            BDE       [1, 2, 3, 4]       0         0019
# 20                   1            MDL       [1, 2, 3, 4]       0         0020
# 21                   1            BDE       [1, 2, 3, 4]       0         0021
# 22                   3            MDL       [1, 2, 3, 4]       0         0022
# 23                   3            BDE       [1, 2, 3, 4]       0         0023

# %%
# Uruchomienie pełnego eksperymentu (test całego pipeline'u)
exp_trajectory_length.run_experiment(n_jobs=1)

# Sprawdzenie, jakie pliki zostały wygenerowane
from pathlib import Path
import os

experiment_dir = Path("data/MICHAŁ_METRICS")
print("Zawartość katalogu eksperymentu:")
for path in experiment_dir.rglob("*"):
    print(path)
# Out:
# Ratios
# 0.25
# 0.75
# 4 0
# remaining_states=46
# max_possible_ratio=1.0
# min_possible_ratio=0.08
# 4 0
# remaining_states=42
# max_possible_ratio=1.0
# min_possible_ratio=0.16
# 4 0
# remaining_states=38
# max_possible_ratio=1.0
# min_possible_ratio=0.24
# 3 1
# remaining_states=34
# max_possible_ratio=0.98
# min_possible_ratio=0.3
# 4 0
# remaining_states=30
# max_possible_ratio=0.98
# min_possible_ratio=0.38
# 4 0
# remaining_states=26
# max_possible_ratio=0.98
# min_possible_ratio=0.46
# 4 0
# remaining_states=22
# max_possible_ratio=0.98
# min_possible_ratio=0.54
# 4 0
# remaining_states=18
# max_possible_ratio=0.98
# min_possible_ratio=0.62
# 4 0
# remaining_states=14
# max_possible_ratio=0.98
# min_possible_ratio=0.7
# 4 0
# remaining_states=10
# max_possible_ratio=0.98
# min_possible_ratio=0.78
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0000.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 3 1
# remaining_states=46
# max_possible_ratio=0.98
# min_possible_ratio=0.06
# 1 3
# remaining_states=42
# max_possible_ratio=0.92
# min_possible_ratio=0.08
# 1 3
# remaining_states=38
# max_possible_ratio=0.86
# min_possible_ratio=0.1
# 2 2
# remaining_states=34
# max_possible_ratio=0.82
# min_possible_ratio=0.14
# 2 2
# remaining_states=30
# max_possible_ratio=0.78
# min_possible_ratio=0.18
# 3 1
# remaining_states=26
# max_possible_ratio=0.76
# min_possible_ratio=0.24
# 3 1
# remaining_states=22
# max_possible_ratio=0.74
# min_possible_ratio=0.3
# 2 2
# remaining_states=18
# max_possible_ratio=0.7
# min_possible_ratio=0.34
# 3 1
# remaining_states=14
# max_possible_ratio=0.68
# min_possible_ratio=0.4
# 2 2
# remaining_states=10
# max_possible_ratio=0.64
# min_possible_ratio=0.44
# Dataset saved to data/MICHAŁ_METRICS/datasets/0001.csv (actual attractor ratio: 0.55)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0001.csv
#    Loaded dataset with shape: (50, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0001.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0001.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0001_BDE.sif
# ['G4', '-', 'G2']
# ['G5', '-', 'G2']
# [BDE] Inferred 2 edges.
#    (Ground truth file found, evaluating metrics)
# [BDE] Failed: 'tuple' object has no attribute 'split'
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 12 0
# remaining_states=38
# max_possible_ratio=1.0
# min_possible_ratio=0.24
# 12 0
# remaining_states=26
# max_possible_ratio=1.0
# min_possible_ratio=0.48
# 11 1
# remaining_states=14
# max_possible_ratio=0.98
# min_possible_ratio=0.7
# 8 4
# remaining_states=2
# max_possible_ratio=0.9
# min_possible_ratio=0.86
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0002.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 12 0
# remaining_states=38
# max_possible_ratio=1.0
# min_possible_ratio=0.24
# 12 0
# remaining_states=26
# max_possible_ratio=1.0
# min_possible_ratio=0.48
# 12 0
# remaining_states=14
# max_possible_ratio=1.0
# min_possible_ratio=0.72
# 12 0
# remaining_states=2
# max_possible_ratio=1.0
# min_possible_ratio=0.96
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0003.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 4
# remaining_states=46
# max_possible_ratio=0.92
# min_possible_ratio=0.0
# 0 4
# remaining_states=42
# max_possible_ratio=0.84
# min_possible_ratio=0.0
# 0 4
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 3 1
# remaining_states=34
# max_possible_ratio=0.74
# min_possible_ratio=0.06
# 4 0
# remaining_states=30
# max_possible_ratio=0.74
# min_possible_ratio=0.14
# 0 4
# remaining_states=26
# max_possible_ratio=0.66
# min_possible_ratio=0.14
# 4 0
# remaining_states=22
# max_possible_ratio=0.66
# min_possible_ratio=0.22
# 0 4
# remaining_states=18
# max_possible_ratio=0.58
# min_possible_ratio=0.22
# 4 0
# remaining_states=14
# max_possible_ratio=0.58
# min_possible_ratio=0.3
# 0 4
# remaining_states=10
# max_possible_ratio=0.5
# min_possible_ratio=0.3
# Dataset saved to data/MICHAŁ_METRICS/datasets/0004.csv (actual attractor ratio: 0.38)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0004.csv
#    Loaded dataset with shape: (50, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0004.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0004.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0004_MDL.sif
# ['G2', '-', 'G4']
# ['G3', '-', 'G4']
# ['G4', '-', 'G3']
# ['G5', '-', 'G1']
# ['G5', '-', 'G6']
# [MDL] Inferred 5 edges.
#    (Ground truth file found, evaluating metrics)
# [MDL] Failed: 'tuple' object has no attribute 'split'
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 0 4
# remaining_states=46
# max_possible_ratio=0.92
# min_possible_ratio=0.0
# 0 4
# remaining_states=42
# max_possible_ratio=0.84
# min_possible_ratio=0.0
# 0 4
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 0 4
# remaining_states=34
# max_possible_ratio=0.68
# min_possible_ratio=0.0
# 0 4
# remaining_states=30
# max_possible_ratio=0.6
# min_possible_ratio=0.0
# 0 4
# remaining_states=26
# max_possible_ratio=0.52
# min_possible_ratio=0.0
# 0 4
# remaining_states=22
# max_possible_ratio=0.44
# min_possible_ratio=0.0
# 3 1
# remaining_states=18
# max_possible_ratio=0.42
# min_possible_ratio=0.06
# 0 4
# remaining_states=14
# max_possible_ratio=0.34
# min_possible_ratio=0.06
# 0 4
# remaining_states=10
# max_possible_ratio=0.26
# min_possible_ratio=0.06
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0005.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 1 11
# remaining_states=38
# max_possible_ratio=0.78
# min_possible_ratio=0.02
# 10 2
# remaining_states=26
# max_possible_ratio=0.74
# min_possible_ratio=0.22
# 7 5
# remaining_states=14
# max_possible_ratio=0.64
# min_possible_ratio=0.36
# 9 3
# remaining_states=2
# max_possible_ratio=0.58
# min_possible_ratio=0.54
# 1 11
# remaining_states=-10
# max_possible_ratio=0.36
# min_possible_ratio=0.56
# 3 9
# remaining_states=-22
# max_possible_ratio=0.18
# min_possible_ratio=0.62
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0006.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 12
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 11 1
# remaining_states=26
# max_possible_ratio=0.74
# min_possible_ratio=0.22
# 12 0
# remaining_states=14
# max_possible_ratio=0.74
# min_possible_ratio=0.46
# 0 12
# remaining_states=2
# max_possible_ratio=0.5
# min_possible_ratio=0.46
# 0 12
# remaining_states=-10
# max_possible_ratio=0.26
# min_possible_ratio=0.46
# 12 0
# remaining_states=-22
# max_possible_ratio=0.26
# min_possible_ratio=0.7
# 0 12
# remaining_states=-34
# max_possible_ratio=0.02
# min_possible_ratio=0.7
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0007.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 2 2
# remaining_states=46
# max_possible_ratio=0.96
# min_possible_ratio=0.04
# 0 4
# remaining_states=42
# max_possible_ratio=0.88
# min_possible_ratio=0.04
# 0 4
# remaining_states=38
# max_possible_ratio=0.8
# min_possible_ratio=0.04
# 0 4
# remaining_states=34
# max_possible_ratio=0.72
# min_possible_ratio=0.04
# 0 4
# remaining_states=30
# max_possible_ratio=0.64
# min_possible_ratio=0.04
# 0 4
# remaining_states=26
# max_possible_ratio=0.56
# min_possible_ratio=0.04
# 0 4
# remaining_states=22
# max_possible_ratio=0.48
# min_possible_ratio=0.04
# 2 2
# remaining_states=18
# max_possible_ratio=0.44
# min_possible_ratio=0.08
# 0 4
# remaining_states=14
# max_possible_ratio=0.36
# min_possible_ratio=0.08
# 0 4
# remaining_states=10
# max_possible_ratio=0.28
# min_possible_ratio=0.08
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0008.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 1 3
# remaining_states=46
# max_possible_ratio=0.94
# min_possible_ratio=0.02
# 3 1
# remaining_states=42
# max_possible_ratio=0.92
# min_possible_ratio=0.08
# 1 3
# remaining_states=38
# max_possible_ratio=0.86
# min_possible_ratio=0.1
# 0 4
# remaining_states=34
# max_possible_ratio=0.78
# min_possible_ratio=0.1
# 1 3
# remaining_states=30
# max_possible_ratio=0.72
# min_possible_ratio=0.12
# 1 3
# remaining_states=26
# max_possible_ratio=0.66
# min_possible_ratio=0.14
# 3 1
# remaining_states=22
# max_possible_ratio=0.64
# min_possible_ratio=0.2
# 1 3
# remaining_states=18
# max_possible_ratio=0.58
# min_possible_ratio=0.22
# 0 4
# remaining_states=14
# max_possible_ratio=0.5
# min_possible_ratio=0.22
# 1 3
# remaining_states=10
# max_possible_ratio=0.44
# min_possible_ratio=0.24
# Dataset saved to data/MICHAŁ_METRICS/datasets/0009.csv (actual attractor ratio: 0.30)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0009.csv
#    Loaded dataset with shape: (50, 8)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0009.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0009.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0009_BDE.sif
# ['G1', '+', 'G3']
# ['G1', '-', 'G5']
# ['G1', '+', 'G8']
# ['G3', '-', 'G2']
# ['G3', '-', 'G4']
# ['G6', '-', 'G8']
# ['G7', '-', 'G1']
# ['G8', '+', 'G3']
# ['G8', '+', 'G5']
# [BDE] Inferred 9 edges.
#    (Ground truth file found, evaluating metrics)
# [BDE] Failed: 'tuple' object has no attribute 'split'
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 11 1
# remaining_states=38
# max_possible_ratio=0.98
# min_possible_ratio=0.22
# 11 1
# remaining_states=26
# max_possible_ratio=0.96
# min_possible_ratio=0.44
# 10 2
# remaining_states=14
# max_possible_ratio=0.92
# min_possible_ratio=0.64
# 10 2
# remaining_states=2
# max_possible_ratio=0.88
# min_possible_ratio=0.84
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0010.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 10 2
# remaining_states=38
# max_possible_ratio=0.96
# min_possible_ratio=0.2
# 12 0
# remaining_states=26
# max_possible_ratio=0.96
# min_possible_ratio=0.44
# 9 3
# remaining_states=14
# max_possible_ratio=0.9
# min_possible_ratio=0.62
# 8 4
# remaining_states=2
# max_possible_ratio=0.82
# min_possible_ratio=0.78
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0011.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 4 0
# remaining_states=46
# max_possible_ratio=1.0
# min_possible_ratio=0.08
# 4 0
# remaining_states=42
# max_possible_ratio=1.0
# min_possible_ratio=0.16
# 0 4
# remaining_states=38
# max_possible_ratio=0.92
# min_possible_ratio=0.16
# 0 4
# remaining_states=34
# max_possible_ratio=0.84
# min_possible_ratio=0.16
# 0 4
# remaining_states=30
# max_possible_ratio=0.76
# min_possible_ratio=0.16
# 4 0
# remaining_states=26
# max_possible_ratio=0.76
# min_possible_ratio=0.24
# 4 0
# remaining_states=22
# max_possible_ratio=0.76
# min_possible_ratio=0.32
# 4 0
# remaining_states=18
# max_possible_ratio=0.76
# min_possible_ratio=0.4
# 4 0
# remaining_states=14
# max_possible_ratio=0.76
# min_possible_ratio=0.48
# 4 0
# remaining_states=10
# max_possible_ratio=0.76
# min_possible_ratio=0.56
# Dataset saved to data/MICHAŁ_METRICS/datasets/0012.csv (actual attractor ratio: 0.70)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0012.csv
#    Loaded dataset with shape: (50, 8)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0012.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0012.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0012_MDL.sif
# ['G2', '-', 'G6']
# ['G4', '+', 'G7']
# ['G5', '-', 'G4']
# ['G5', '+', 'G8']
# ['G6', '-', 'G7']
# ['G7', '+', 'G8']
# ['G8', '+', 'G6']
# [MDL] Inferred 7 edges.
#    (Ground truth file found, evaluating metrics)
# [MDL] Failed: 'tuple' object has no attribute 'split'
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 0 4
# remaining_states=46
# max_possible_ratio=0.92
# min_possible_ratio=0.0
# 0 4
# remaining_states=42
# max_possible_ratio=0.84
# min_possible_ratio=0.0
# 0 4
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 0 4
# remaining_states=34
# max_possible_ratio=0.68
# min_possible_ratio=0.0
# 0 4
# remaining_states=30
# max_possible_ratio=0.6
# min_possible_ratio=0.0
# 0 4
# remaining_states=26
# max_possible_ratio=0.52
# min_possible_ratio=0.0
# 0 4
# remaining_states=22
# max_possible_ratio=0.44
# min_possible_ratio=0.0
# 0 4
# remaining_states=18
# max_possible_ratio=0.36
# min_possible_ratio=0.0
# 0 4
# remaining_states=14
# max_possible_ratio=0.28
# min_possible_ratio=0.0
# 0 4
# remaining_states=10
# max_possible_ratio=0.2
# min_possible_ratio=0.0
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0013.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 12
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 0 12
# remaining_states=26
# max_possible_ratio=0.52
# min_possible_ratio=0.0
# 2 10
# remaining_states=14
# max_possible_ratio=0.32
# min_possible_ratio=0.04
# 0 12
# remaining_states=2
# max_possible_ratio=0.08
# min_possible_ratio=0.04
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0014.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 12
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 0 12
# remaining_states=26
# max_possible_ratio=0.52
# min_possible_ratio=0.0
# 0 12
# remaining_states=14
# max_possible_ratio=0.28
# min_possible_ratio=0.0
# 0 12
# remaining_states=2
# max_possible_ratio=0.04
# min_possible_ratio=0.0
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0015.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 4
# remaining_states=46
# max_possible_ratio=0.92
# min_possible_ratio=0.0
# 1 3
# remaining_states=42
# max_possible_ratio=0.86
# min_possible_ratio=0.02
# 2 2
# remaining_states=38
# max_possible_ratio=0.82
# min_possible_ratio=0.06
# 1 3
# remaining_states=34
# max_possible_ratio=0.76
# min_possible_ratio=0.08
# 0 4
# remaining_states=30
# max_possible_ratio=0.68
# min_possible_ratio=0.08
# 0 4
# remaining_states=26
# max_possible_ratio=0.6
# min_possible_ratio=0.08
# 1 3
# remaining_states=22
# max_possible_ratio=0.54
# min_possible_ratio=0.1
# 0 4
# remaining_states=18
# max_possible_ratio=0.46
# min_possible_ratio=0.1
# 0 4
# remaining_states=14
# max_possible_ratio=0.38
# min_possible_ratio=0.1
# 1 3
# remaining_states=10
# max_possible_ratio=0.32
# min_possible_ratio=0.12
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0016.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 2 2
# remaining_states=46
# max_possible_ratio=0.96
# min_possible_ratio=0.04
# 2 2
# remaining_states=42
# max_possible_ratio=0.92
# min_possible_ratio=0.08
# 3 1
# remaining_states=38
# max_possible_ratio=0.9
# min_possible_ratio=0.14
# 3 1
# remaining_states=34
# max_possible_ratio=0.88
# min_possible_ratio=0.2
# 3 1
# remaining_states=30
# max_possible_ratio=0.86
# min_possible_ratio=0.26
# 0 4
# remaining_states=26
# max_possible_ratio=0.78
# min_possible_ratio=0.26
# 2 2
# remaining_states=22
# max_possible_ratio=0.74
# min_possible_ratio=0.3
# 0 4
# remaining_states=18
# max_possible_ratio=0.66
# min_possible_ratio=0.3
# 0 4
# remaining_states=14
# max_possible_ratio=0.58
# min_possible_ratio=0.3
# 3 1
# remaining_states=10
# max_possible_ratio=0.56
# min_possible_ratio=0.36
# Dataset saved to data/MICHAŁ_METRICS/datasets/0017.csv (actual attractor ratio: 0.45)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0017.csv
#    Loaded dataset with shape: (50, 12)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0017.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0017.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0017_BDE.sif
# ['G1', '-', 'G6']
# ['G1', '-', 'G9']
# ['G2', '+', 'G11']
# ['G9', '-', 'G5']
# ['G10', '+', 'G2']
# ['G10', '+', 'G4']
# ['G12', '-', 'G5']
# [BDE] Inferred 7 edges.
#    (Ground truth file found, evaluating metrics)
# [BDE] Failed: 'tuple' object has no attribute 'split'
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 7 5
# remaining_states=38
# max_possible_ratio=0.9
# min_possible_ratio=0.14
# 9 3
# remaining_states=26
# max_possible_ratio=0.84
# min_possible_ratio=0.32
# 7 5
# remaining_states=14
# max_possible_ratio=0.74
# min_possible_ratio=0.46
# 9 3
# remaining_states=2
# max_possible_ratio=0.68
# min_possible_ratio=0.64
# 8 4
# remaining_states=-10
# max_possible_ratio=0.6
# min_possible_ratio=0.8
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0018.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 7 5
# remaining_states=38
# max_possible_ratio=0.9
# min_possible_ratio=0.14
# 10 2
# remaining_states=26
# max_possible_ratio=0.86
# min_possible_ratio=0.34
# 9 3
# remaining_states=14
# max_possible_ratio=0.8
# min_possible_ratio=0.52
# 7 5
# remaining_states=2
# max_possible_ratio=0.7
# min_possible_ratio=0.66
# 7 5
# remaining_states=-10
# max_possible_ratio=0.6
# min_possible_ratio=0.8
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0019.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 4
# remaining_states=46
# max_possible_ratio=0.92
# min_possible_ratio=0.0
# 0 4
# remaining_states=42
# max_possible_ratio=0.84
# min_possible_ratio=0.0
# 0 4
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 0 4
# remaining_states=34
# max_possible_ratio=0.68
# min_possible_ratio=0.0
# 0 4
# remaining_states=30
# max_possible_ratio=0.6
# min_possible_ratio=0.0
# 0 4
# remaining_states=26
# max_possible_ratio=0.52
# min_possible_ratio=0.0
# 0 4
# remaining_states=22
# max_possible_ratio=0.44
# min_possible_ratio=0.0
# 4 0
# remaining_states=18
# max_possible_ratio=0.44
# min_possible_ratio=0.08
# 0 4
# remaining_states=14
# max_possible_ratio=0.36
# min_possible_ratio=0.08
# 0 4
# remaining_states=10
# max_possible_ratio=0.28
# min_possible_ratio=0.08
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0020.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 4
# remaining_states=46
# max_possible_ratio=0.92
# min_possible_ratio=0.0
# 0 4
# remaining_states=42
# max_possible_ratio=0.84
# min_possible_ratio=0.0
# 0 4
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 0 4
# remaining_states=34
# max_possible_ratio=0.68
# min_possible_ratio=0.0
# 4 0
# remaining_states=30
# max_possible_ratio=0.68
# min_possible_ratio=0.08
# 0 4
# remaining_states=26
# max_possible_ratio=0.6
# min_possible_ratio=0.08
# 4 0
# remaining_states=22
# max_possible_ratio=0.6
# min_possible_ratio=0.16
# 0 4
# remaining_states=18
# max_possible_ratio=0.52
# min_possible_ratio=0.16
# 0 4
# remaining_states=14
# max_possible_ratio=0.44
# min_possible_ratio=0.16
# 0 4
# remaining_states=10
# max_possible_ratio=0.36
# min_possible_ratio=0.16
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0021.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 9 3
# remaining_states=38
# max_possible_ratio=0.94
# min_possible_ratio=0.18
# 0 12
# remaining_states=26
# max_possible_ratio=0.7
# min_possible_ratio=0.18
# 0 12
# remaining_states=14
# max_possible_ratio=0.46
# min_possible_ratio=0.18
# 0 12
# remaining_states=2
# max_possible_ratio=0.22
# min_possible_ratio=0.18
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0022.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 12 0
# remaining_states=38
# max_possible_ratio=1.0
# min_possible_ratio=0.24
# 12 0
# remaining_states=26
# max_possible_ratio=1.0
# min_possible_ratio=0.48
# 0 12
# remaining_states=14
# max_possible_ratio=0.76
# min_possible_ratio=0.48
# 12 0
# remaining_states=2
# max_possible_ratio=0.76
# min_possible_ratio=0.72
# 12 0
# remaining_states=-10
# max_possible_ratio=0.76
# min_possible_ratio=0.96
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0023.csv NOT created (requirements not met). Skipping inference.
#
# [SUMMARY] Generated datasets: 5/24
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Uruchomienie pełnego eksperymentu (test całego pipeline'u)
# ----> 2 exp_trajectory_length.run_experiment(n_jobs=1)
#       4 # Sprawdzenie, jakie pliki zostały wygenerowane
#       5 from pathlib import Path
#
# File ~/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/analysis/experiment.py:280, in BooleanNetworkExperiment.run_experiment(self, n_jobs, subset)
#     277 print(f"\n[SUMMARY] Generated datasets: {success_count}/{len(rows)}")
#     279 # merge all csv
# --> 280 self._merge_csv()
#     281 # obtain metadata
#     282 self.save_experiment_df_to_csv()
#
# File ~/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/analysis/experiment.py:162, in BooleanNetworkExperiment._merge_csv(self, csv_dir)
#     160 csv_files = sorted(csv_dir.glob("*.csv"))
#     161 if not csv_files:
# --> 162     raise RuntimeError("No CSV files to merge")
#     163 # join pdfs
#     164 df = pd.concat(
#     165     (pd.read_csv(f) for f in csv_files),
#     166     ignore_index=True
#     167 )
#
# RuntimeError: No CSV files to merge
