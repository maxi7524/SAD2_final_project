# %%
# boolean network packages
from sad2_final_project.analysis import BooleanNetworkExperiment
# system packages
import os
from pathlib import Path


# paths
## set global dir
cwd=Path.cwd()
if cwd.name == "notebooks":
    os.chdir(cwd.parent) 
print(os.getcwd())
## create paths 
DATA_PATH = Path('data')
# # TODO OBSOLETE 
# DATASET_PATH = DATA_PATH / 'datasets'
# BN_TRUE_PATH = DATA_PATH / 'bn_ground_truth'
# BN_DATASET_BNFINDER_FORMAT_PATH = DATA_PATH / 'datasets_bnfinder_format'
# BN_RESULT_PATH = DATA_PATH / "result"
## create directories
# !mkdir {DATA_PATH}
# TODO OBSOLETE
# !mkdir -p {DATASET_PATH}
# !mkdir -p {BN_TRUE_PATH}
# !mkdir -p {BN_DATASET_BNFINDER_FORMAT_PATH}
# !mkdir -p {BN_RESULT_PATH}
# Out:
# /home/maxi7524/repositories/SAD2_final_project
# mkdir: cannot create directory ‘data’: File exists

# %%
# TODO: REMOVE - only for fast test s
# create experiments:
## case: Relation between trajectory length and entering attractors
exp_trajectory_length = BooleanNetworkExperiment(
    # paths
    data_path=DATA_PATH,
    experiment_name='MICHAŁ_METRICS',
    # experiment values
    num_nodes=[4],
    update_mode=["synchronous", "asynchronous"], # , "asynchronous"
    trajectory_length=list(range(50, 60, 10)),
    n_trajectories=[1000],
    sampling_frequency=[1],
    score_functions=["MDL", "BDE"],
    # TODO - add metrics options 

    n_parents_per_node=[[1, 2, 3, 4]],
    # amount of samples per experiment 
    n_repetitions=1,
    simulate_trajectories_to_csv_kwargs = {
            # "sampling_frequency": 1,
            "target_attractor_ratio": 0.5,  # Approximate fraction of trajectory in attractor (0-1)
            "tolerance": 0.25,               # Allowed deviation from the calculated entrance step (0-1)
        }
) 
exp_trajectory_length.show_experiment_df()
# Out:
#    num_nodes   update_mode  trajectory_length  n_trajectories  \
# 0          4   synchronous                 50            1000
# 1          4   synchronous                 50            1000
# 2          4  asynchronous                 50            1000
# 3          4  asynchronous                 50            1000
#
#    sampling_frequency score_function n_parents_per_node  rep_id condition_id
# 0                   1            MDL       [1, 2, 3, 4]       0         0000
# 1                   1            BDE       [1, 2, 3, 4]       0         0001
# 2                   1            MDL       [1, 2, 3, 4]       0         0002
# 3                   1            BDE       [1, 2, 3, 4]       0         0003

# %%
# Uruchomienie pełnego eksperymentu (test całego pipeline'u)
exp_trajectory_length.run_experiment(n_jobs=1)

# Sprawdzenie, jakie pliki zostały wygenerowane
from pathlib import Path
import os

experiment_dir = Path("data/MICHAŁ_METRICS")
print("Zawartość katalogu eksperymentu:")
for path in experiment_dir.rglob("*"):
    print(path)
# Out:
# Ratios
# 0.25
# 0.75
# 49 0
# remaining_states=49951
# max_possible_ratio=1.0
# min_possible_ratio=0.00098
# 49 0
# remaining_states=49902
# max_possible_ratio=1.0
# min_possible_ratio=0.00196
# 48 1
# remaining_states=49853
# max_possible_ratio=0.99998
# min_possible_ratio=0.00292
# 49 0
# remaining_states=49804
# max_possible_ratio=0.99998
# min_possible_ratio=0.0039
# 49 0
# remaining_states=49755
# max_possible_ratio=0.99998
# min_possible_ratio=0.00488
# 48 1
# remaining_states=49706
# max_possible_ratio=0.99996
# min_possible_ratio=0.00584
# 49 0
# remaining_states=49657
# max_possible_ratio=0.99996
# min_possible_ratio=0.00682
# 49 0
# remaining_states=49608
# max_possible_ratio=0.99996
# min_possible_ratio=0.0078
# 47 2
# remaining_states=49559
# max_possible_ratio=0.99992
# min_possible_ratio=0.00874
# 49 0
# remaining_states=49510
# max_possible_ratio=0.99992
# min_possible_ratio=0.00972
# 49 0
# remaining_states=49461
# max_possible_ratio=0.99992
# min_possible_ratio=0.0107
# 47 2
# remaining_states=49412
# max_possible_ratio=0.99988
# min_possible_ratio=0.01164
# 46 3
# remaining_states=49363
# max_possible_ratio=0.99982
# min_possible_ratio=0.01256
# 49 0
# remaining_states=49314
# max_possible_ratio=0.99982
# min_possible_ratio=0.01354
# 49 0
# remaining_states=49265
# max_possible_ratio=0.99982
# min_possible_ratio=0.01452
# 49 0
# remaining_states=49216
# max_possible_ratio=0.99982
# min_possible_ratio=0.0155
# 46 3
# remaining_states=49167
# max_possible_ratio=0.99976
# min_possible_ratio=0.01642
# 49 0
# remaining_states=49118
# max_possible_ratio=0.99976
# min_possible_ratio=0.0174
# 49 0
# remaining_states=49069
# max_possible_ratio=0.99976
# min_possible_ratio=0.01838
# 49 0
# remaining_states=49020
# max_possible_ratio=0.99976
# min_possible_ratio=0.01936
# 48 1
# remaining_states=48971
# max_possible_ratio=0.99974
# min_possible_ratio=0.02032
# 49 0
# remaining_states=48922
# max_possible_ratio=0.99974
# min_possible_ratio=0.0213
# 49 0
# remaining_states=48873
# max_possible_ratio=0.99974
# min_possible_ratio=0.02228
# 49 0
# remaining_states=48824
# max_possible_ratio=0.99974
# min_possible_ratio=0.02326
# 49 0
# remaining_states=48775
# max_possible_ratio=0.99974
# min_possible_ratio=0.02424
# 46 3
# remaining_states=48726
# max_possible_ratio=0.99968
# min_possible_ratio=0.02516
# 47 2
# remaining_states=48677
# max_possible_ratio=0.99964
# min_possible_ratio=0.0261
# 47 2
# remaining_states=48628
# max_possible_ratio=0.9996
# min_possible_ratio=0.02704
# 49 0
# remaining_states=48579
# max_possible_ratio=0.9996
# min_possible_ratio=0.02802
# 48 1
# remaining_states=48530
# max_possible_ratio=0.99958
# min_possible_ratio=0.02898
# 49 0
# remaining_states=48481
# max_possible_ratio=0.99958
# min_possible_ratio=0.02996
# 47 2
# remaining_states=48432
# max_possible_ratio=0.99954
# min_possible_ratio=0.0309
# 48 1
# remaining_states=48383
# max_possible_ratio=0.99952
# min_possible_ratio=0.03186
# 47 2
# remaining_states=48334
# max_possible_ratio=0.99948
# min_possible_ratio=0.0328
# 48 1
# remaining_states=48285
# max_possible_ratio=0.99946
# min_possible_ratio=0.03376
# 49 0
# remaining_states=48236
# max_possible_ratio=0.99946
# min_possible_ratio=0.03474
# 48 1
# remaining_states=48187
# max_possible_ratio=0.99944
# min_possible_ratio=0.0357
# 49 0
# remaining_states=48138
# max_possible_ratio=0.99944
# min_possible_ratio=0.03668
# 46 3
# remaining_states=48089
# max_possible_ratio=0.99938
# min_possible_ratio=0.0376
# 49 0
# remaining_states=48040
# max_possible_ratio=0.99938
# min_possible_ratio=0.03858
# 49 0
# remaining_states=47991
# max_possible_ratio=0.99938
# min_possible_ratio=0.03956
# 49 0
# remaining_states=47942
# max_possible_ratio=0.99938
# min_possible_ratio=0.04054
# 47 2
# remaining_states=47893
# max_possible_ratio=0.99934
# min_possible_ratio=0.04148
# 47 2
# remaining_states=47844
# max_possible_ratio=0.9993
# min_possible_ratio=0.04242
# 48 1
# remaining_states=47795
# max_possible_ratio=0.99928
# min_possible_ratio=0.04338
# 49 0
# remaining_states=47746
# max_possible_ratio=0.99928
# min_possible_ratio=0.04436
# 47 2
# remaining_states=47697
# max_possible_ratio=0.99924
# min_possible_ratio=0.0453
# 49 0
# remaining_states=47648
# max_possible_ratio=0.99924
# min_possible_ratio=0.04628
# 48 1
# remaining_states=47599
# max_possible_ratio=0.99922
# min_possible_ratio=0.04724
# 48 1
# remaining_states=47550
# max_possible_ratio=0.9992
# min_possible_ratio=0.0482
# 48 1
# remaining_states=47501
# max_possible_ratio=0.99918
# min_possible_ratio=0.04916
# 48 1
# remaining_states=47452
# max_possible_ratio=0.99916
# min_possible_ratio=0.05012
# 49 0
# remaining_states=47403
# max_possible_ratio=0.99916
# min_possible_ratio=0.0511
# 46 3
# remaining_states=47354
# max_possible_ratio=0.9991
# min_possible_ratio=0.05202
# 49 0
# remaining_states=47305
# max_possible_ratio=0.9991
# min_possible_ratio=0.053
# 49 0
# remaining_states=47256
# max_possible_ratio=0.9991
# min_possible_ratio=0.05398
# 48 1
# remaining_states=47207
# max_possible_ratio=0.99908
# min_possible_ratio=0.05494
# 46 3
# remaining_states=47158
# max_possible_ratio=0.99902
# min_possible_ratio=0.05586
# 46 3
# remaining_states=47109
# max_possible_ratio=0.99896
# min_possible_ratio=0.05678
# 49 0
# remaining_states=47060
# max_possible_ratio=0.99896
# min_possible_ratio=0.05776
# 49 0
# remaining_states=47011
# max_possible_ratio=0.99896
# min_possible_ratio=0.05874
# 48 1
# remaining_states=46962
# max_possible_ratio=0.99894
# min_possible_ratio=0.0597
# 49 0
# remaining_states=46913
# max_possible_ratio=0.99894
# min_possible_ratio=0.06068
# 49 0
# remaining_states=46864
# max_possible_ratio=0.99894
# min_possible_ratio=0.06166
# 49 0
# remaining_states=46815
# max_possible_ratio=0.99894
# min_possible_ratio=0.06264
# 49 0
# remaining_states=46766
# max_possible_ratio=0.99894
# min_possible_ratio=0.06362
# 49 0
# remaining_states=46717
# max_possible_ratio=0.99894
# min_possible_ratio=0.0646
# 49 0
# remaining_states=46668
# max_possible_ratio=0.99894
# min_possible_ratio=0.06558
# 49 0
# remaining_states=46619
# max_possible_ratio=0.99894
# min_possible_ratio=0.06656
# 49 0
# remaining_states=46570
# max_possible_ratio=0.99894
# min_possible_ratio=0.06754
# 47 2
# remaining_states=46521
# max_possible_ratio=0.9989
# min_possible_ratio=0.06848
# 49 0
# remaining_states=46472
# max_possible_ratio=0.9989
# min_possible_ratio=0.06946
# 49 0
# remaining_states=46423
# max_possible_ratio=0.9989
# min_possible_ratio=0.07044
# 49 0
# remaining_states=46374
# max_possible_ratio=0.9989
# min_possible_ratio=0.07142
# 49 0
# remaining_states=46325
# max_possible_ratio=0.9989
# min_possible_ratio=0.0724
# 49 0
# remaining_states=46276
# max_possible_ratio=0.9989
# min_possible_ratio=0.07338
# 48 1
# remaining_states=46227
# max_possible_ratio=0.99888
# min_possible_ratio=0.07434
# 49 0
# remaining_states=46178
# max_possible_ratio=0.99888
# min_possible_ratio=0.07532
# 49 0
# remaining_states=46129
# max_possible_ratio=0.99888
# min_possible_ratio=0.0763
# 49 0
# remaining_states=46080
# max_possible_ratio=0.99888
# min_possible_ratio=0.07728
# 48 1
# remaining_states=46031
# max_possible_ratio=0.99886
# min_possible_ratio=0.07824
# 49 0
# remaining_states=45982
# max_possible_ratio=0.99886
# min_possible_ratio=0.07922
# 49 0
# remaining_states=45933
# max_possible_ratio=0.99886
# min_possible_ratio=0.0802
# 48 1
# remaining_states=45884
# max_possible_ratio=0.99884
# min_possible_ratio=0.08116
# 46 3
# remaining_states=45835
# max_possible_ratio=0.99878
# min_possible_ratio=0.08208
# 49 0
# remaining_states=45786
# max_possible_ratio=0.99878
# min_possible_ratio=0.08306
# 48 1
# remaining_states=45737
# max_possible_ratio=0.99876
# min_possible_ratio=0.08402
# 49 0
# remaining_states=45688
# max_possible_ratio=0.99876
# min_possible_ratio=0.085
# 46 3
# remaining_states=45639
# max_possible_ratio=0.9987
# min_possible_ratio=0.08592
# 48 1
# remaining_states=45590
# max_possible_ratio=0.99868
# min_possible_ratio=0.08688
# 49 0
# remaining_states=45541
# max_possible_ratio=0.99868
# min_possible_ratio=0.08786
# 49 0
# remaining_states=45492
# max_possible_ratio=0.99868
# min_possible_ratio=0.08884
# 48 1
# remaining_states=45443
# max_possible_ratio=0.99866
# min_possible_ratio=0.0898
# 47 2
# remaining_states=45394
# max_possible_ratio=0.99862
# min_possible_ratio=0.09074
# 47 2
# remaining_states=45345
# max_possible_ratio=0.99858
# min_possible_ratio=0.09168
# 47 2
# remaining_states=45296
# max_possible_ratio=0.99854
# min_possible_ratio=0.09262
# 48 1
# remaining_states=45247
# max_possible_ratio=0.99852
# min_possible_ratio=0.09358
# 49 0
# remaining_states=45198
# max_possible_ratio=0.99852
# min_possible_ratio=0.09456
# 49 0
# remaining_states=45149
# max_possible_ratio=0.99852
# min_possible_ratio=0.09554
# 46 3
# remaining_states=45100
# max_possible_ratio=0.99846
# min_possible_ratio=0.09646
# 49 0
# remaining_states=45051
# max_possible_ratio=0.99846
# min_possible_ratio=0.09744
# 49 0
# remaining_states=45002
# max_possible_ratio=0.99846
# min_possible_ratio=0.09842
# 46 3
# remaining_states=44953
# max_possible_ratio=0.9984
# min_possible_ratio=0.09934
# 49 0
# remaining_states=44904
# max_possible_ratio=0.9984
# min_possible_ratio=0.10032
# 46 3
# remaining_states=44855
# max_possible_ratio=0.99834
# min_possible_ratio=0.10124
# 49 0
# remaining_states=44806
# max_possible_ratio=0.99834
# min_possible_ratio=0.10222
# 49 0
# remaining_states=44757
# max_possible_ratio=0.99834
# min_possible_ratio=0.1032
# 48 1
# remaining_states=44708
# max_possible_ratio=0.99832
# min_possible_ratio=0.10416
# 49 0
# remaining_states=44659
# max_possible_ratio=0.99832
# min_possible_ratio=0.10514
# 49 0
# remaining_states=44610
# max_possible_ratio=0.99832
# min_possible_ratio=0.10612
# 47 2
# remaining_states=44561
# max_possible_ratio=0.99828
# min_possible_ratio=0.10706
# 47 2
# remaining_states=44512
# max_possible_ratio=0.99824
# min_possible_ratio=0.108
# 48 1
# remaining_states=44463
# max_possible_ratio=0.99822
# min_possible_ratio=0.10896
# 49 0
# remaining_states=44414
# max_possible_ratio=0.99822
# min_possible_ratio=0.10994
# 49 0
# remaining_states=44365
# max_possible_ratio=0.99822
# min_possible_ratio=0.11092
# 49 0
# remaining_states=44316
# max_possible_ratio=0.99822
# min_possible_ratio=0.1119
# 47 2
# remaining_states=44267
# max_possible_ratio=0.99818
# min_possible_ratio=0.11284
# 49 0
# remaining_states=44218
# max_possible_ratio=0.99818
# min_possible_ratio=0.11382
# 46 3
# remaining_states=44169
# max_possible_ratio=0.99812
# min_possible_ratio=0.11474
# 49 0
# remaining_states=44120
# max_possible_ratio=0.99812
# min_possible_ratio=0.11572
# 48 1
# remaining_states=44071
# max_possible_ratio=0.9981
# min_possible_ratio=0.11668
# 49 0
# remaining_states=44022
# max_possible_ratio=0.9981
# min_possible_ratio=0.11766
# 47 2
# remaining_states=43973
# max_possible_ratio=0.99806
# min_possible_ratio=0.1186
# 47 2
# remaining_states=43924
# max_possible_ratio=0.99802
# min_possible_ratio=0.11954
# 49 0
# remaining_states=43875
# max_possible_ratio=0.99802
# min_possible_ratio=0.12052
# 49 0
# remaining_states=43826
# max_possible_ratio=0.99802
# min_possible_ratio=0.1215
# 49 0
# remaining_states=43777
# max_possible_ratio=0.99802
# min_possible_ratio=0.12248
# 49 0
# remaining_states=43728
# max_possible_ratio=0.99802
# min_possible_ratio=0.12346
# 48 1
# remaining_states=43679
# max_possible_ratio=0.998
# min_possible_ratio=0.12442
# 49 0
# remaining_states=43630
# max_possible_ratio=0.998
# min_possible_ratio=0.1254
# 49 0
# remaining_states=43581
# max_possible_ratio=0.998
# min_possible_ratio=0.12638
# 49 0
# remaining_states=43532
# max_possible_ratio=0.998
# min_possible_ratio=0.12736
# 46 3
# remaining_states=43483
# max_possible_ratio=0.99794
# min_possible_ratio=0.12828
# 49 0
# remaining_states=43434
# max_possible_ratio=0.99794
# min_possible_ratio=0.12926
# 46 3
# remaining_states=43385
# max_possible_ratio=0.99788
# min_possible_ratio=0.13018
# 48 1
# remaining_states=43336
# max_possible_ratio=0.99786
# min_possible_ratio=0.13114
# 48 1
# remaining_states=43287
# max_possible_ratio=0.99784
# min_possible_ratio=0.1321
# 47 2
# remaining_states=43238
# max_possible_ratio=0.9978
# min_possible_ratio=0.13304
# 49 0
# remaining_states=43189
# max_possible_ratio=0.9978
# min_possible_ratio=0.13402
# 49 0
# remaining_states=43140
# max_possible_ratio=0.9978
# min_possible_ratio=0.135
# 48 1
# remaining_states=43091
# max_possible_ratio=0.99778
# min_possible_ratio=0.13596
# 49 0
# remaining_states=43042
# max_possible_ratio=0.99778
# min_possible_ratio=0.13694
# 49 0
# remaining_states=42993
# max_possible_ratio=0.99778
# min_possible_ratio=0.13792
# 49 0
# remaining_states=42944
# max_possible_ratio=0.99778
# min_possible_ratio=0.1389
# 47 2
# remaining_states=42895
# max_possible_ratio=0.99774
# min_possible_ratio=0.13984
# 47 2
# remaining_states=42846
# max_possible_ratio=0.9977
# min_possible_ratio=0.14078
# 48 1
# remaining_states=42797
# max_possible_ratio=0.99768
# min_possible_ratio=0.14174
# 49 0
# remaining_states=42748
# max_possible_ratio=0.99768
# min_possible_ratio=0.14272
# 49 0
# remaining_states=42699
# max_possible_ratio=0.99768
# min_possible_ratio=0.1437
# 48 1
# remaining_states=42650
# max_possible_ratio=0.99766
# min_possible_ratio=0.14466
# 49 0
# remaining_states=42601
# max_possible_ratio=0.99766
# min_possible_ratio=0.14564
# 49 0
# remaining_states=42552
# max_possible_ratio=0.99766
# min_possible_ratio=0.14662
# 49 0
# remaining_states=42503
# max_possible_ratio=0.99766
# min_possible_ratio=0.1476
# 49 0
# remaining_states=42454
# max_possible_ratio=0.99766
# min_possible_ratio=0.14858
# 49 0
# remaining_states=42405
# max_possible_ratio=0.99766
# min_possible_ratio=0.14956
# 47 2
# remaining_states=42356
# max_possible_ratio=0.99762
# min_possible_ratio=0.1505
# 48 1
# remaining_states=42307
# max_possible_ratio=0.9976
# min_possible_ratio=0.15146
# 49 0
# remaining_states=42258
# max_possible_ratio=0.9976
# min_possible_ratio=0.15244
# 49 0
# remaining_states=42209
# max_possible_ratio=0.9976
# min_possible_ratio=0.15342
# 48 1
# remaining_states=42160
# max_possible_ratio=0.99758
# min_possible_ratio=0.15438
# 48 1
# remaining_states=42111
# max_possible_ratio=0.99756
# min_possible_ratio=0.15534
# 48 1
# remaining_states=42062
# max_possible_ratio=0.99754
# min_possible_ratio=0.1563
# 49 0
# remaining_states=42013
# max_possible_ratio=0.99754
# min_possible_ratio=0.15728
# 49 0
# remaining_states=41964
# max_possible_ratio=0.99754
# min_possible_ratio=0.15826
# 48 1
# remaining_states=41915
# max_possible_ratio=0.99752
# min_possible_ratio=0.15922
# 49 0
# remaining_states=41866
# max_possible_ratio=0.99752
# min_possible_ratio=0.1602
# 48 1
# remaining_states=41817
# max_possible_ratio=0.9975
# min_possible_ratio=0.16116
# 49 0
# remaining_states=41768
# max_possible_ratio=0.9975
# min_possible_ratio=0.16214
# 48 1
# remaining_states=41719
# max_possible_ratio=0.99748
# min_possible_ratio=0.1631
# 48 1
# remaining_states=41670
# max_possible_ratio=0.99746
# min_possible_ratio=0.16406
# 49 0
# remaining_states=41621
# max_possible_ratio=0.99746
# min_possible_ratio=0.16504
# 49 0
# remaining_states=41572
# max_possible_ratio=0.99746
# min_possible_ratio=0.16602
# 46 3
# remaining_states=41523
# max_possible_ratio=0.9974
# min_possible_ratio=0.16694
# 49 0
# remaining_states=41474
# max_possible_ratio=0.9974
# min_possible_ratio=0.16792
# 47 2
# remaining_states=41425
# max_possible_ratio=0.99736
# min_possible_ratio=0.16886
# 49 0
# remaining_states=41376
# max_possible_ratio=0.99736
# min_possible_ratio=0.16984
# 49 0
# remaining_states=41327
# max_possible_ratio=0.99736
# min_possible_ratio=0.17082
# 49 0
# remaining_states=41278
# max_possible_ratio=0.99736
# min_possible_ratio=0.1718
# 49 0
# remaining_states=41229
# max_possible_ratio=0.99736
# min_possible_ratio=0.17278
# 49 0
# remaining_states=41180
# max_possible_ratio=0.99736
# min_possible_ratio=0.17376
# 49 0
# remaining_states=41131
# max_possible_ratio=0.99736
# min_possible_ratio=0.17474
# 47 2
# remaining_states=41082
# max_possible_ratio=0.99732
# min_possible_ratio=0.17568
# 49 0
# remaining_states=41033
# max_possible_ratio=0.99732
# min_possible_ratio=0.17666
# 48 1
# remaining_states=40984
# max_possible_ratio=0.9973
# min_possible_ratio=0.17762
# 48 1
# remaining_states=40935
# max_possible_ratio=0.99728
# min_possible_ratio=0.17858
# 49 0
# remaining_states=40886
# max_possible_ratio=0.99728
# min_possible_ratio=0.17956
# 49 0
# remaining_states=40837
# max_possible_ratio=0.99728
# min_possible_ratio=0.18054
# 49 0
# remaining_states=40788
# max_possible_ratio=0.99728
# min_possible_ratio=0.18152
# 49 0
# remaining_states=40739
# max_possible_ratio=0.99728
# min_possible_ratio=0.1825
# 49 0
# remaining_states=40690
# max_possible_ratio=0.99728
# min_possible_ratio=0.18348
# 46 3
# remaining_states=40641
# max_possible_ratio=0.99722
# min_possible_ratio=0.1844
# 48 1
# remaining_states=40592
# max_possible_ratio=0.9972
# min_possible_ratio=0.18536
# 47 2
# remaining_states=40543
# max_possible_ratio=0.99716
# min_possible_ratio=0.1863
# 49 0
# remaining_states=40494
# max_possible_ratio=0.99716
# min_possible_ratio=0.18728
# 49 0
# remaining_states=40445
# max_possible_ratio=0.99716
# min_possible_ratio=0.18826
# 49 0
# remaining_states=40396
# max_possible_ratio=0.99716
# min_possible_ratio=0.18924
# 47 2
# remaining_states=40347
# max_possible_ratio=0.99712
# min_possible_ratio=0.19018
# 49 0
# remaining_states=40298
# max_possible_ratio=0.99712
# min_possible_ratio=0.19116
# 46 3
# remaining_states=40249
# max_possible_ratio=0.99706
# min_possible_ratio=0.19208
# 48 1
# remaining_states=40200
# max_possible_ratio=0.99704
# min_possible_ratio=0.19304
# 47 2
# remaining_states=40151
# max_possible_ratio=0.997
# min_possible_ratio=0.19398
# 49 0
# remaining_states=40102
# max_possible_ratio=0.997
# min_possible_ratio=0.19496
# 49 0
# remaining_states=40053
# max_possible_ratio=0.997
# min_possible_ratio=0.19594
# 49 0
# remaining_states=40004
# max_possible_ratio=0.997
# min_possible_ratio=0.19692
# 49 0
# remaining_states=39955
# max_possible_ratio=0.997
# min_possible_ratio=0.1979
# 49 0
# remaining_states=39906
# max_possible_ratio=0.997
# min_possible_ratio=0.19888
# 48 1
# remaining_states=39857
# max_possible_ratio=0.99698
# min_possible_ratio=0.19984
# 49 0
# remaining_states=39808
# max_possible_ratio=0.99698
# min_possible_ratio=0.20082
# 47 2
# remaining_states=39759
# max_possible_ratio=0.99694
# min_possible_ratio=0.20176
# 47 2
# remaining_states=39710
# max_possible_ratio=0.9969
# min_possible_ratio=0.2027
# 48 1
# remaining_states=39661
# max_possible_ratio=0.99688
# min_possible_ratio=0.20366
# 48 1
# remaining_states=39612
# max_possible_ratio=0.99686
# min_possible_ratio=0.20462
# 49 0
# remaining_states=39563
# max_possible_ratio=0.99686
# min_possible_ratio=0.2056
# 46 3
# remaining_states=39514
# max_possible_ratio=0.9968
# min_possible_ratio=0.20652
# 49 0
# remaining_states=39465
# max_possible_ratio=0.9968
# min_possible_ratio=0.2075
# 48 1
# remaining_states=39416
# max_possible_ratio=0.99678
# min_possible_ratio=0.20846
# 49 0
# remaining_states=39367
# max_possible_ratio=0.99678
# min_possible_ratio=0.20944
# 49 0
# remaining_states=39318
# max_possible_ratio=0.99678
# min_possible_ratio=0.21042
# 47 2
# remaining_states=39269
# max_possible_ratio=0.99674
# min_possible_ratio=0.21136
# 48 1
# remaining_states=39220
# max_possible_ratio=0.99672
# min_possible_ratio=0.21232
# 47 2
# remaining_states=39171
# max_possible_ratio=0.99668
# min_possible_ratio=0.21326
# 49 0
# remaining_states=39122
# max_possible_ratio=0.99668
# min_possible_ratio=0.21424
# 48 1
# remaining_states=39073
# max_possible_ratio=0.99666
# min_possible_ratio=0.2152
# 48 1
# remaining_states=39024
# max_possible_ratio=0.99664
# min_possible_ratio=0.21616
# 49 0
# remaining_states=38975
# max_possible_ratio=0.99664
# min_possible_ratio=0.21714
# 49 0
# remaining_states=38926
# max_possible_ratio=0.99664
# min_possible_ratio=0.21812
# 48 1
# remaining_states=38877
# max_possible_ratio=0.99662
# min_possible_ratio=0.21908
# 48 1
# remaining_states=38828
# max_possible_ratio=0.9966
# min_possible_ratio=0.22004
# 49 0
# remaining_states=38779
# max_possible_ratio=0.9966
# min_possible_ratio=0.22102
# 49 0
# remaining_states=38730
# max_possible_ratio=0.9966
# min_possible_ratio=0.222
# 49 0
# remaining_states=38681
# max_possible_ratio=0.9966
# min_possible_ratio=0.22298
# 48 1
# remaining_states=38632
# max_possible_ratio=0.99658
# min_possible_ratio=0.22394
# 49 0
# remaining_states=38583
# max_possible_ratio=0.99658
# min_possible_ratio=0.22492
# 47 2
# remaining_states=38534
# max_possible_ratio=0.99654
# min_possible_ratio=0.22586
# 49 0
# remaining_states=38485
# max_possible_ratio=0.99654
# min_possible_ratio=0.22684
# 49 0
# remaining_states=38436
# max_possible_ratio=0.99654
# min_possible_ratio=0.22782
# 49 0
# remaining_states=38387
# max_possible_ratio=0.99654
# min_possible_ratio=0.2288
# 49 0
# remaining_states=38338
# max_possible_ratio=0.99654
# min_possible_ratio=0.22978
# 49 0
# remaining_states=38289
# max_possible_ratio=0.99654
# min_possible_ratio=0.23076
# 48 1
# remaining_states=38240
# max_possible_ratio=0.99652
# min_possible_ratio=0.23172
# 47 2
# remaining_states=38191
# max_possible_ratio=0.99648
# min_possible_ratio=0.23266
# 46 3
# remaining_states=38142
# max_possible_ratio=0.99642
# min_possible_ratio=0.23358
# 46 3
# remaining_states=38093
# max_possible_ratio=0.99636
# min_possible_ratio=0.2345
# 49 0
# remaining_states=38044
# max_possible_ratio=0.99636
# min_possible_ratio=0.23548
# 49 0
# remaining_states=37995
# max_possible_ratio=0.99636
# min_possible_ratio=0.23646
# 49 0
# remaining_states=37946
# max_possible_ratio=0.99636
# min_possible_ratio=0.23744
# 49 0
# remaining_states=37897
# max_possible_ratio=0.99636
# min_possible_ratio=0.23842
# 48 1
# remaining_states=37848
# max_possible_ratio=0.99634
# min_possible_ratio=0.23938
# 47 2
# remaining_states=37799
# max_possible_ratio=0.9963
# min_possible_ratio=0.24032
# 49 0
# remaining_states=37750
# max_possible_ratio=0.9963
# min_possible_ratio=0.2413
# 48 1
# remaining_states=37701
# max_possible_ratio=0.99628
# min_possible_ratio=0.24226
# 46 3
# remaining_states=37652
# max_possible_ratio=0.99622
# min_possible_ratio=0.24318
# 49 0
# remaining_states=37603
# max_possible_ratio=0.99622
# min_possible_ratio=0.24416
# 48 1
# remaining_states=37554
# max_possible_ratio=0.9962
# min_possible_ratio=0.24512
# 47 2
# remaining_states=37505
# max_possible_ratio=0.99616
# min_possible_ratio=0.24606
# 49 0
# remaining_states=37456
# max_possible_ratio=0.99616
# min_possible_ratio=0.24704
# 49 0
# remaining_states=37407
# max_possible_ratio=0.99616
# min_possible_ratio=0.24802
# 47 2
# remaining_states=37358
# max_possible_ratio=0.99612
# min_possible_ratio=0.24896
# 49 0
# remaining_states=37309
# max_possible_ratio=0.99612
# min_possible_ratio=0.24994
# 48 1
# remaining_states=37260
# max_possible_ratio=0.9961
# min_possible_ratio=0.2509
# 49 0
# remaining_states=37211
# max_possible_ratio=0.9961
# min_possible_ratio=0.25188
# 49 0
# remaining_states=37162
# max_possible_ratio=0.9961
# min_possible_ratio=0.25286
# 48 1
# remaining_states=37113
# max_possible_ratio=0.99608
# min_possible_ratio=0.25382
# 49 0
# remaining_states=37064
# max_possible_ratio=0.99608
# min_possible_ratio=0.2548
# 48 1
# remaining_states=37015
# max_possible_ratio=0.99606
# min_possible_ratio=0.25576
# 46 3
# remaining_states=36966
# max_possible_ratio=0.996
# min_possible_ratio=0.25668
# 48 1
# remaining_states=36917
# max_possible_ratio=0.99598
# min_possible_ratio=0.25764
# 49 0
# remaining_states=36868
# max_possible_ratio=0.99598
# min_possible_ratio=0.25862
# 48 1
# remaining_states=36819
# max_possible_ratio=0.99596
# min_possible_ratio=0.25958
# 49 0
# remaining_states=36770
# max_possible_ratio=0.99596
# min_possible_ratio=0.26056
# 49 0
# remaining_states=36721
# max_possible_ratio=0.99596
# min_possible_ratio=0.26154
# 49 0
# remaining_states=36672
# max_possible_ratio=0.99596
# min_possible_ratio=0.26252
# 49 0
# remaining_states=36623
# max_possible_ratio=0.99596
# min_possible_ratio=0.2635
# 49 0
# remaining_states=36574
# max_possible_ratio=0.99596
# min_possible_ratio=0.26448
# 49 0
# remaining_states=36525
# max_possible_ratio=0.99596
# min_possible_ratio=0.26546
# 48 1
# remaining_states=36476
# max_possible_ratio=0.99594
# min_possible_ratio=0.26642
# 48 1
# remaining_states=36427
# max_possible_ratio=0.99592
# min_possible_ratio=0.26738
# 49 0
# remaining_states=36378
# max_possible_ratio=0.99592
# min_possible_ratio=0.26836
# 46 3
# remaining_states=36329
# max_possible_ratio=0.99586
# min_possible_ratio=0.26928
# 49 0
# remaining_states=36280
# max_possible_ratio=0.99586
# min_possible_ratio=0.27026
# 48 1
# remaining_states=36231
# max_possible_ratio=0.99584
# min_possible_ratio=0.27122
# 49 0
# remaining_states=36182
# max_possible_ratio=0.99584
# min_possible_ratio=0.2722
# 49 0
# remaining_states=36133
# max_possible_ratio=0.99584
# min_possible_ratio=0.27318
# 48 1
# remaining_states=36084
# max_possible_ratio=0.99582
# min_possible_ratio=0.27414
# 48 1
# remaining_states=36035
# max_possible_ratio=0.9958
# min_possible_ratio=0.2751
# 48 1
# remaining_states=35986
# max_possible_ratio=0.99578
# min_possible_ratio=0.27606
# 46 3
# remaining_states=35937
# max_possible_ratio=0.99572
# min_possible_ratio=0.27698
# 48 1
# remaining_states=35888
# max_possible_ratio=0.9957
# min_possible_ratio=0.27794
# 48 1
# remaining_states=35839
# max_possible_ratio=0.99568
# min_possible_ratio=0.2789
# 48 1
# remaining_states=35790
# max_possible_ratio=0.99566
# min_possible_ratio=0.27986
# 48 1
# remaining_states=35741
# max_possible_ratio=0.99564
# min_possible_ratio=0.28082
# 47 2
# remaining_states=35692
# max_possible_ratio=0.9956
# min_possible_ratio=0.28176
# 49 0
# remaining_states=35643
# max_possible_ratio=0.9956
# min_possible_ratio=0.28274
# 48 1
# remaining_states=35594
# max_possible_ratio=0.99558
# min_possible_ratio=0.2837
# 47 2
# remaining_states=35545
# max_possible_ratio=0.99554
# min_possible_ratio=0.28464
# 46 3
# remaining_states=35496
# max_possible_ratio=0.99548
# min_possible_ratio=0.28556
# 49 0
# remaining_states=35447
# max_possible_ratio=0.99548
# min_possible_ratio=0.28654
# 47 2
# remaining_states=35398
# max_possible_ratio=0.99544
# min_possible_ratio=0.28748
# 48 1
# remaining_states=35349
# max_possible_ratio=0.99542
# min_possible_ratio=0.28844
# 48 1
# remaining_states=35300
# max_possible_ratio=0.9954
# min_possible_ratio=0.2894
# 49 0
# remaining_states=35251
# max_possible_ratio=0.9954
# min_possible_ratio=0.29038
# 48 1
# remaining_states=35202
# max_possible_ratio=0.99538
# min_possible_ratio=0.29134
# 48 1
# remaining_states=35153
# max_possible_ratio=0.99536
# min_possible_ratio=0.2923
# 48 1
# remaining_states=35104
# max_possible_ratio=0.99534
# min_possible_ratio=0.29326
# 46 3
# remaining_states=35055
# max_possible_ratio=0.99528
# min_possible_ratio=0.29418
# 49 0
# remaining_states=35006
# max_possible_ratio=0.99528
# min_possible_ratio=0.29516
# 49 0
# remaining_states=34957
# max_possible_ratio=0.99528
# min_possible_ratio=0.29614
# 49 0
# remaining_states=34908
# max_possible_ratio=0.99528
# min_possible_ratio=0.29712
# 48 1
# remaining_states=34859
# max_possible_ratio=0.99526
# min_possible_ratio=0.29808
# 47 2
# remaining_states=34810
# max_possible_ratio=0.99522
# min_possible_ratio=0.29902
# 49 0
# remaining_states=34761
# max_possible_ratio=0.99522
# min_possible_ratio=0.3
# 48 1
# remaining_states=34712
# max_possible_ratio=0.9952
# min_possible_ratio=0.30096
# 49 0
# remaining_states=34663
# max_possible_ratio=0.9952
# min_possible_ratio=0.30194
# 46 3
# remaining_states=34614
# max_possible_ratio=0.99514
# min_possible_ratio=0.30286
# 47 2
# remaining_states=34565
# max_possible_ratio=0.9951
# min_possible_ratio=0.3038
# 48 1
# remaining_states=34516
# max_possible_ratio=0.99508
# min_possible_ratio=0.30476
# 49 0
# remaining_states=34467
# max_possible_ratio=0.99508
# min_possible_ratio=0.30574
# 49 0
# remaining_states=34418
# max_possible_ratio=0.99508
# min_possible_ratio=0.30672
# 49 0
# remaining_states=34369
# max_possible_ratio=0.99508
# min_possible_ratio=0.3077
# 48 1
# remaining_states=34320
# max_possible_ratio=0.99506
# min_possible_ratio=0.30866
# 48 1
# remaining_states=34271
# max_possible_ratio=0.99504
# min_possible_ratio=0.30962
# 49 0
# remaining_states=34222
# max_possible_ratio=0.99504
# min_possible_ratio=0.3106
# 49 0
# remaining_states=34173
# max_possible_ratio=0.99504
# min_possible_ratio=0.31158
# 49 0
# remaining_states=34124
# max_possible_ratio=0.99504
# min_possible_ratio=0.31256
# 49 0
# remaining_states=34075
# max_possible_ratio=0.99504
# min_possible_ratio=0.31354
# 48 1
# remaining_states=34026
# max_possible_ratio=0.99502
# min_possible_ratio=0.3145
# 49 0
# remaining_states=33977
# max_possible_ratio=0.99502
# min_possible_ratio=0.31548
# 49 0
# remaining_states=33928
# max_possible_ratio=0.99502
# min_possible_ratio=0.31646
# 49 0
# remaining_states=33879
# max_possible_ratio=0.99502
# min_possible_ratio=0.31744
# 48 1
# remaining_states=33830
# max_possible_ratio=0.995
# min_possible_ratio=0.3184
# 47 2
# remaining_states=33781
# max_possible_ratio=0.99496
# min_possible_ratio=0.31934
# 49 0
# remaining_states=33732
# max_possible_ratio=0.99496
# min_possible_ratio=0.32032
# 49 0
# remaining_states=33683
# max_possible_ratio=0.99496
# min_possible_ratio=0.3213
# 48 1
# remaining_states=33634
# max_possible_ratio=0.99494
# min_possible_ratio=0.32226
# 49 0
# remaining_states=33585
# max_possible_ratio=0.99494
# min_possible_ratio=0.32324
# 49 0
# remaining_states=33536
# max_possible_ratio=0.99494
# min_possible_ratio=0.32422
# 46 3
# remaining_states=33487
# max_possible_ratio=0.99488
# min_possible_ratio=0.32514
# 48 1
# remaining_states=33438
# max_possible_ratio=0.99486
# min_possible_ratio=0.3261
# 49 0
# remaining_states=33389
# max_possible_ratio=0.99486
# min_possible_ratio=0.32708
# 49 0
# remaining_states=33340
# max_possible_ratio=0.99486
# min_possible_ratio=0.32806
# 48 1
# remaining_states=33291
# max_possible_ratio=0.99484
# min_possible_ratio=0.32902
# 48 1
# remaining_states=33242
# max_possible_ratio=0.99482
# min_possible_ratio=0.32998
# 49 0
# remaining_states=33193
# max_possible_ratio=0.99482
# min_possible_ratio=0.33096
# 49 0
# remaining_states=33144
# max_possible_ratio=0.99482
# min_possible_ratio=0.33194
# 49 0
# remaining_states=33095
# max_possible_ratio=0.99482
# min_possible_ratio=0.33292
# 48 1
# remaining_states=33046
# max_possible_ratio=0.9948
# min_possible_ratio=0.33388
# 49 0
# remaining_states=32997
# max_possible_ratio=0.9948
# min_possible_ratio=0.33486
# 48 1
# remaining_states=32948
# max_possible_ratio=0.99478
# min_possible_ratio=0.33582
# 49 0
# remaining_states=32899
# max_possible_ratio=0.99478
# min_possible_ratio=0.3368
# 48 1
# remaining_states=32850
# max_possible_ratio=0.99476
# min_possible_ratio=0.33776
# 49 0
# remaining_states=32801
# max_possible_ratio=0.99476
# min_possible_ratio=0.33874
# 49 0
# remaining_states=32752
# max_possible_ratio=0.99476
# min_possible_ratio=0.33972
# 47 2
# remaining_states=32703
# max_possible_ratio=0.99472
# min_possible_ratio=0.34066
# 49 0
# remaining_states=32654
# max_possible_ratio=0.99472
# min_possible_ratio=0.34164
# 49 0
# remaining_states=32605
# max_possible_ratio=0.99472
# min_possible_ratio=0.34262
# 49 0
# remaining_states=32556
# max_possible_ratio=0.99472
# min_possible_ratio=0.3436
# 48 1
# remaining_states=32507
# max_possible_ratio=0.9947
# min_possible_ratio=0.34456
# 48 1
# remaining_states=32458
# max_possible_ratio=0.99468
# min_possible_ratio=0.34552
# 48 1
# remaining_states=32409
# max_possible_ratio=0.99466
# min_possible_ratio=0.34648
# 49 0
# remaining_states=32360
# max_possible_ratio=0.99466
# min_possible_ratio=0.34746
# 49 0
# remaining_states=32311
# max_possible_ratio=0.99466
# min_possible_ratio=0.34844
# 49 0
# remaining_states=32262
# max_possible_ratio=0.99466
# min_possible_ratio=0.34942
# 48 1
# remaining_states=32213
# max_possible_ratio=0.99464
# min_possible_ratio=0.35038
# 49 0
# remaining_states=32164
# max_possible_ratio=0.99464
# min_possible_ratio=0.35136
# 47 2
# remaining_states=32115
# max_possible_ratio=0.9946
# min_possible_ratio=0.3523
# 48 1
# remaining_states=32066
# max_possible_ratio=0.99458
# min_possible_ratio=0.35326
# 49 0
# remaining_states=32017
# max_possible_ratio=0.99458
# min_possible_ratio=0.35424
# 48 1
# remaining_states=31968
# max_possible_ratio=0.99456
# min_possible_ratio=0.3552
# 49 0
# remaining_states=31919
# max_possible_ratio=0.99456
# min_possible_ratio=0.35618
# 49 0
# remaining_states=31870
# max_possible_ratio=0.99456
# min_possible_ratio=0.35716
# 49 0
# remaining_states=31821
# max_possible_ratio=0.99456
# min_possible_ratio=0.35814
# 49 0
# remaining_states=31772
# max_possible_ratio=0.99456
# min_possible_ratio=0.35912
# 49 0
# remaining_states=31723
# max_possible_ratio=0.99456
# min_possible_ratio=0.3601
# 48 1
# remaining_states=31674
# max_possible_ratio=0.99454
# min_possible_ratio=0.36106
# 49 0
# remaining_states=31625
# max_possible_ratio=0.99454
# min_possible_ratio=0.36204
# 49 0
# remaining_states=31576
# max_possible_ratio=0.99454
# min_possible_ratio=0.36302
# 47 2
# remaining_states=31527
# max_possible_ratio=0.9945
# min_possible_ratio=0.36396
# 48 1
# remaining_states=31478
# max_possible_ratio=0.99448
# min_possible_ratio=0.36492
# 49 0
# remaining_states=31429
# max_possible_ratio=0.99448
# min_possible_ratio=0.3659
# 48 1
# remaining_states=31380
# max_possible_ratio=0.99446
# min_possible_ratio=0.36686
# 49 0
# remaining_states=31331
# max_possible_ratio=0.99446
# min_possible_ratio=0.36784
# 49 0
# remaining_states=31282
# max_possible_ratio=0.99446
# min_possible_ratio=0.36882
# 49 0
# remaining_states=31233
# max_possible_ratio=0.99446
# min_possible_ratio=0.3698
# 48 1
# remaining_states=31184
# max_possible_ratio=0.99444
# min_possible_ratio=0.37076
# 49 0
# remaining_states=31135
# max_possible_ratio=0.99444
# min_possible_ratio=0.37174
# 49 0
# remaining_states=31086
# max_possible_ratio=0.99444
# min_possible_ratio=0.37272
# 49 0
# remaining_states=31037
# max_possible_ratio=0.99444
# min_possible_ratio=0.3737
# 49 0
# remaining_states=30988
# max_possible_ratio=0.99444
# min_possible_ratio=0.37468
# 48 1
# remaining_states=30939
# max_possible_ratio=0.99442
# min_possible_ratio=0.37564
# 49 0
# remaining_states=30890
# max_possible_ratio=0.99442
# min_possible_ratio=0.37662
# 49 0
# remaining_states=30841
# max_possible_ratio=0.99442
# min_possible_ratio=0.3776
# 49 0
# remaining_states=30792
# max_possible_ratio=0.99442
# min_possible_ratio=0.37858
# 46 3
# remaining_states=30743
# max_possible_ratio=0.99436
# min_possible_ratio=0.3795
# 48 1
# remaining_states=30694
# max_possible_ratio=0.99434
# min_possible_ratio=0.38046
# 48 1
# remaining_states=30645
# max_possible_ratio=0.99432
# min_possible_ratio=0.38142
# 48 1
# remaining_states=30596
# max_possible_ratio=0.9943
# min_possible_ratio=0.38238
# 49 0
# remaining_states=30547
# max_possible_ratio=0.9943
# min_possible_ratio=0.38336
# 49 0
# remaining_states=30498
# max_possible_ratio=0.9943
# min_possible_ratio=0.38434
# 49 0
# remaining_states=30449
# max_possible_ratio=0.9943
# min_possible_ratio=0.38532
# 49 0
# remaining_states=30400
# max_possible_ratio=0.9943
# min_possible_ratio=0.3863
# 49 0
# remaining_states=30351
# max_possible_ratio=0.9943
# min_possible_ratio=0.38728
# 49 0
# remaining_states=30302
# max_possible_ratio=0.9943
# min_possible_ratio=0.38826
# 49 0
# remaining_states=30253
# max_possible_ratio=0.9943
# min_possible_ratio=0.38924
# 48 1
# remaining_states=30204
# max_possible_ratio=0.99428
# min_possible_ratio=0.3902
# 48 1
# remaining_states=30155
# max_possible_ratio=0.99426
# min_possible_ratio=0.39116
# 48 1
# remaining_states=30106
# max_possible_ratio=0.99424
# min_possible_ratio=0.39212
# 49 0
# remaining_states=30057
# max_possible_ratio=0.99424
# min_possible_ratio=0.3931
# 47 2
# remaining_states=30008
# max_possible_ratio=0.9942
# min_possible_ratio=0.39404
# 48 1
# remaining_states=29959
# max_possible_ratio=0.99418
# min_possible_ratio=0.395
# 48 1
# remaining_states=29910
# max_possible_ratio=0.99416
# min_possible_ratio=0.39596
# 48 1
# remaining_states=29861
# max_possible_ratio=0.99414
# min_possible_ratio=0.39692
# 48 1
# remaining_states=29812
# max_possible_ratio=0.99412
# min_possible_ratio=0.39788
# 49 0
# remaining_states=29763
# max_possible_ratio=0.99412
# min_possible_ratio=0.39886
# 49 0
# remaining_states=29714
# max_possible_ratio=0.99412
# min_possible_ratio=0.39984
# 46 3
# remaining_states=29665
# max_possible_ratio=0.99406
# min_possible_ratio=0.40076
# 46 3
# remaining_states=29616
# max_possible_ratio=0.994
# min_possible_ratio=0.40168
# 49 0
# remaining_states=29567
# max_possible_ratio=0.994
# min_possible_ratio=0.40266
# 48 1
# remaining_states=29518
# max_possible_ratio=0.99398
# min_possible_ratio=0.40362
# 48 1
# remaining_states=29469
# max_possible_ratio=0.99396
# min_possible_ratio=0.40458
# 49 0
# remaining_states=29420
# max_possible_ratio=0.99396
# min_possible_ratio=0.40556
# 49 0
# remaining_states=29371
# max_possible_ratio=0.99396
# min_possible_ratio=0.40654
# 49 0
# remaining_states=29322
# max_possible_ratio=0.99396
# min_possible_ratio=0.40752
# 49 0
# remaining_states=29273
# max_possible_ratio=0.99396
# min_possible_ratio=0.4085
# 48 1
# remaining_states=29224
# max_possible_ratio=0.99394
# min_possible_ratio=0.40946
# 49 0
# remaining_states=29175
# max_possible_ratio=0.99394
# min_possible_ratio=0.41044
# 46 3
# remaining_states=29126
# max_possible_ratio=0.99388
# min_possible_ratio=0.41136
# 47 2
# remaining_states=29077
# max_possible_ratio=0.99384
# min_possible_ratio=0.4123
# 49 0
# remaining_states=29028
# max_possible_ratio=0.99384
# min_possible_ratio=0.41328
# 47 2
# remaining_states=28979
# max_possible_ratio=0.9938
# min_possible_ratio=0.41422
# 49 0
# remaining_states=28930
# max_possible_ratio=0.9938
# min_possible_ratio=0.4152
# 48 1
# remaining_states=28881
# max_possible_ratio=0.99378
# min_possible_ratio=0.41616
# 47 2
# remaining_states=28832
# max_possible_ratio=0.99374
# min_possible_ratio=0.4171
# 48 1
# remaining_states=28783
# max_possible_ratio=0.99372
# min_possible_ratio=0.41806
# 47 2
# remaining_states=28734
# max_possible_ratio=0.99368
# min_possible_ratio=0.419
# 47 2
# remaining_states=28685
# max_possible_ratio=0.99364
# min_possible_ratio=0.41994
# 49 0
# remaining_states=28636
# max_possible_ratio=0.99364
# min_possible_ratio=0.42092
# 49 0
# remaining_states=28587
# max_possible_ratio=0.99364
# min_possible_ratio=0.4219
# 48 1
# remaining_states=28538
# max_possible_ratio=0.99362
# min_possible_ratio=0.42286
# 49 0
# remaining_states=28489
# max_possible_ratio=0.99362
# min_possible_ratio=0.42384
# 47 2
# remaining_states=28440
# max_possible_ratio=0.99358
# min_possible_ratio=0.42478
# 49 0
# remaining_states=28391
# max_possible_ratio=0.99358
# min_possible_ratio=0.42576
# 49 0
# remaining_states=28342
# max_possible_ratio=0.99358
# min_possible_ratio=0.42674
# 49 0
# remaining_states=28293
# max_possible_ratio=0.99358
# min_possible_ratio=0.42772
# 48 1
# remaining_states=28244
# max_possible_ratio=0.99356
# min_possible_ratio=0.42868
# 49 0
# remaining_states=28195
# max_possible_ratio=0.99356
# min_possible_ratio=0.42966
# 47 2
# remaining_states=28146
# max_possible_ratio=0.99352
# min_possible_ratio=0.4306
# 49 0
# remaining_states=28097
# max_possible_ratio=0.99352
# min_possible_ratio=0.43158
# 49 0
# remaining_states=28048
# max_possible_ratio=0.99352
# min_possible_ratio=0.43256
# 48 1
# remaining_states=27999
# max_possible_ratio=0.9935
# min_possible_ratio=0.43352
# 49 0
# remaining_states=27950
# max_possible_ratio=0.9935
# min_possible_ratio=0.4345
# 49 0
# remaining_states=27901
# max_possible_ratio=0.9935
# min_possible_ratio=0.43548
# 49 0
# remaining_states=27852
# max_possible_ratio=0.9935
# min_possible_ratio=0.43646
# 49 0
# remaining_states=27803
# max_possible_ratio=0.9935
# min_possible_ratio=0.43744
# 47 2
# remaining_states=27754
# max_possible_ratio=0.99346
# min_possible_ratio=0.43838
# 48 1
# remaining_states=27705
# max_possible_ratio=0.99344
# min_possible_ratio=0.43934
# 48 1
# remaining_states=27656
# max_possible_ratio=0.99342
# min_possible_ratio=0.4403
# 49 0
# remaining_states=27607
# max_possible_ratio=0.99342
# min_possible_ratio=0.44128
# 49 0
# remaining_states=27558
# max_possible_ratio=0.99342
# min_possible_ratio=0.44226
# 49 0
# remaining_states=27509
# max_possible_ratio=0.99342
# min_possible_ratio=0.44324
# 49 0
# remaining_states=27460
# max_possible_ratio=0.99342
# min_possible_ratio=0.44422
# 49 0
# remaining_states=27411
# max_possible_ratio=0.99342
# min_possible_ratio=0.4452
# 48 1
# remaining_states=27362
# max_possible_ratio=0.9934
# min_possible_ratio=0.44616
# 49 0
# remaining_states=27313
# max_possible_ratio=0.9934
# min_possible_ratio=0.44714
# 49 0
# remaining_states=27264
# max_possible_ratio=0.9934
# min_possible_ratio=0.44812
# 49 0
# remaining_states=27215
# max_possible_ratio=0.9934
# min_possible_ratio=0.4491
# 47 2
# remaining_states=27166
# max_possible_ratio=0.99336
# min_possible_ratio=0.45004
# 48 1
# remaining_states=27117
# max_possible_ratio=0.99334
# min_possible_ratio=0.451
# 48 1
# remaining_states=27068
# max_possible_ratio=0.99332
# min_possible_ratio=0.45196
# 47 2
# remaining_states=27019
# max_possible_ratio=0.99328
# min_possible_ratio=0.4529
# 47 2
# remaining_states=26970
# max_possible_ratio=0.99324
# min_possible_ratio=0.45384
# 49 0
# remaining_states=26921
# max_possible_ratio=0.99324
# min_possible_ratio=0.45482
# 49 0
# remaining_states=26872
# max_possible_ratio=0.99324
# min_possible_ratio=0.4558
# 47 2
# remaining_states=26823
# max_possible_ratio=0.9932
# min_possible_ratio=0.45674
# 46 3
# remaining_states=26774
# max_possible_ratio=0.99314
# min_possible_ratio=0.45766
# 47 2
# remaining_states=26725
# max_possible_ratio=0.9931
# min_possible_ratio=0.4586
# 47 2
# remaining_states=26676
# max_possible_ratio=0.99306
# min_possible_ratio=0.45954
# 49 0
# remaining_states=26627
# max_possible_ratio=0.99306
# min_possible_ratio=0.46052
# 47 2
# remaining_states=26578
# max_possible_ratio=0.99302
# min_possible_ratio=0.46146
# 48 1
# remaining_states=26529
# max_possible_ratio=0.993
# min_possible_ratio=0.46242
# 48 1
# remaining_states=26480
# max_possible_ratio=0.99298
# min_possible_ratio=0.46338
# 48 1
# remaining_states=26431
# max_possible_ratio=0.99296
# min_possible_ratio=0.46434
# 48 1
# remaining_states=26382
# max_possible_ratio=0.99294
# min_possible_ratio=0.4653
# 48 1
# remaining_states=26333
# max_possible_ratio=0.99292
# min_possible_ratio=0.46626
# 48 1
# remaining_states=26284
# max_possible_ratio=0.9929
# min_possible_ratio=0.46722
# 49 0
# remaining_states=26235
# max_possible_ratio=0.9929
# min_possible_ratio=0.4682
# 49 0
# remaining_states=26186
# max_possible_ratio=0.9929
# min_possible_ratio=0.46918
# 49 0
# remaining_states=26137
# max_possible_ratio=0.9929
# min_possible_ratio=0.47016
# 48 1
# remaining_states=26088
# max_possible_ratio=0.99288
# min_possible_ratio=0.47112
# 46 3
# remaining_states=26039
# max_possible_ratio=0.99282
# min_possible_ratio=0.47204
# 47 2
# remaining_states=25990
# max_possible_ratio=0.99278
# min_possible_ratio=0.47298
# 47 2
# remaining_states=25941
# max_possible_ratio=0.99274
# min_possible_ratio=0.47392
# 47 2
# remaining_states=25892
# max_possible_ratio=0.9927
# min_possible_ratio=0.47486
# 47 2
# remaining_states=25843
# max_possible_ratio=0.99266
# min_possible_ratio=0.4758
# 46 3
# remaining_states=25794
# max_possible_ratio=0.9926
# min_possible_ratio=0.47672
# 49 0
# remaining_states=25745
# max_possible_ratio=0.9926
# min_possible_ratio=0.4777
# 49 0
# remaining_states=25696
# max_possible_ratio=0.9926
# min_possible_ratio=0.47868
# 48 1
# remaining_states=25647
# max_possible_ratio=0.99258
# min_possible_ratio=0.47964
# 47 2
# remaining_states=25598
# max_possible_ratio=0.99254
# min_possible_ratio=0.48058
# 48 1
# remaining_states=25549
# max_possible_ratio=0.99252
# min_possible_ratio=0.48154
# 47 2
# remaining_states=25500
# max_possible_ratio=0.99248
# min_possible_ratio=0.48248
# 49 0
# remaining_states=25451
# max_possible_ratio=0.99248
# min_possible_ratio=0.48346
# 47 2
# remaining_states=25402
# max_possible_ratio=0.99244
# min_possible_ratio=0.4844
# 49 0
# remaining_states=25353
# max_possible_ratio=0.99244
# min_possible_ratio=0.48538
# 48 1
# remaining_states=25304
# max_possible_ratio=0.99242
# min_possible_ratio=0.48634
# 47 2
# remaining_states=25255
# max_possible_ratio=0.99238
# min_possible_ratio=0.48728
# 47 2
# remaining_states=25206
# max_possible_ratio=0.99234
# min_possible_ratio=0.48822
# 49 0
# remaining_states=25157
# max_possible_ratio=0.99234
# min_possible_ratio=0.4892
# 47 2
# remaining_states=25108
# max_possible_ratio=0.9923
# min_possible_ratio=0.49014
# 48 1
# remaining_states=25059
# max_possible_ratio=0.99228
# min_possible_ratio=0.4911
# 49 0
# remaining_states=25010
# max_possible_ratio=0.99228
# min_possible_ratio=0.49208
# 49 0
# remaining_states=24961
# max_possible_ratio=0.99228
# min_possible_ratio=0.49306
# 47 2
# remaining_states=24912
# max_possible_ratio=0.99224
# min_possible_ratio=0.494
# 49 0
# remaining_states=24863
# max_possible_ratio=0.99224
# min_possible_ratio=0.49498
# 49 0
# remaining_states=24814
# max_possible_ratio=0.99224
# min_possible_ratio=0.49596
# 49 0
# remaining_states=24765
# max_possible_ratio=0.99224
# min_possible_ratio=0.49694
# 49 0
# remaining_states=24716
# max_possible_ratio=0.99224
# min_possible_ratio=0.49792
# 47 2
# remaining_states=24667
# max_possible_ratio=0.9922
# min_possible_ratio=0.49886
# 49 0
# remaining_states=24618
# max_possible_ratio=0.9922
# min_possible_ratio=0.49984
# 49 0
# remaining_states=24569
# max_possible_ratio=0.9922
# min_possible_ratio=0.50082
# 49 0
# remaining_states=24520
# max_possible_ratio=0.9922
# min_possible_ratio=0.5018
# 49 0
# remaining_states=24471
# max_possible_ratio=0.9922
# min_possible_ratio=0.50278
# 49 0
# remaining_states=24422
# max_possible_ratio=0.9922
# min_possible_ratio=0.50376
# 49 0
# remaining_states=24373
# max_possible_ratio=0.9922
# min_possible_ratio=0.50474
# 48 1
# remaining_states=24324
# max_possible_ratio=0.99218
# min_possible_ratio=0.5057
# 49 0
# remaining_states=24275
# max_possible_ratio=0.99218
# min_possible_ratio=0.50668
# 48 1
# remaining_states=24226
# max_possible_ratio=0.99216
# min_possible_ratio=0.50764
# 47 2
# remaining_states=24177
# max_possible_ratio=0.99212
# min_possible_ratio=0.50858
# 49 0
# remaining_states=24128
# max_possible_ratio=0.99212
# min_possible_ratio=0.50956
# 49 0
# remaining_states=24079
# max_possible_ratio=0.99212
# min_possible_ratio=0.51054
# 46 3
# remaining_states=24030
# max_possible_ratio=0.99206
# min_possible_ratio=0.51146
# 47 2
# remaining_states=23981
# max_possible_ratio=0.99202
# min_possible_ratio=0.5124
# 49 0
# remaining_states=23932
# max_possible_ratio=0.99202
# min_possible_ratio=0.51338
# 49 0
# remaining_states=23883
# max_possible_ratio=0.99202
# min_possible_ratio=0.51436
# 48 1
# remaining_states=23834
# max_possible_ratio=0.992
# min_possible_ratio=0.51532
# 49 0
# remaining_states=23785
# max_possible_ratio=0.992
# min_possible_ratio=0.5163
# 47 2
# remaining_states=23736
# max_possible_ratio=0.99196
# min_possible_ratio=0.51724
# 47 2
# remaining_states=23687
# max_possible_ratio=0.99192
# min_possible_ratio=0.51818
# 49 0
# remaining_states=23638
# max_possible_ratio=0.99192
# min_possible_ratio=0.51916
# 49 0
# remaining_states=23589
# max_possible_ratio=0.99192
# min_possible_ratio=0.52014
# 48 1
# remaining_states=23540
# max_possible_ratio=0.9919
# min_possible_ratio=0.5211
# 48 1
# remaining_states=23491
# max_possible_ratio=0.99188
# min_possible_ratio=0.52206
# 49 0
# remaining_states=23442
# max_possible_ratio=0.99188
# min_possible_ratio=0.52304
# 49 0
# remaining_states=23393
# max_possible_ratio=0.99188
# min_possible_ratio=0.52402
# 48 1
# remaining_states=23344
# max_possible_ratio=0.99186
# min_possible_ratio=0.52498
# 47 2
# remaining_states=23295
# max_possible_ratio=0.99182
# min_possible_ratio=0.52592
# 48 1
# remaining_states=23246
# max_possible_ratio=0.9918
# min_possible_ratio=0.52688
# 49 0
# remaining_states=23197
# max_possible_ratio=0.9918
# min_possible_ratio=0.52786
# 48 1
# remaining_states=23148
# max_possible_ratio=0.99178
# min_possible_ratio=0.52882
# 48 1
# remaining_states=23099
# max_possible_ratio=0.99176
# min_possible_ratio=0.52978
# 48 1
# remaining_states=23050
# max_possible_ratio=0.99174
# min_possible_ratio=0.53074
# 46 3
# remaining_states=23001
# max_possible_ratio=0.99168
# min_possible_ratio=0.53166
# 48 1
# remaining_states=22952
# max_possible_ratio=0.99166
# min_possible_ratio=0.53262
# 49 0
# remaining_states=22903
# max_possible_ratio=0.99166
# min_possible_ratio=0.5336
# 47 2
# remaining_states=22854
# max_possible_ratio=0.99162
# min_possible_ratio=0.53454
# 49 0
# remaining_states=22805
# max_possible_ratio=0.99162
# min_possible_ratio=0.53552
# 49 0
# remaining_states=22756
# max_possible_ratio=0.99162
# min_possible_ratio=0.5365
# 49 0
# remaining_states=22707
# max_possible_ratio=0.99162
# min_possible_ratio=0.53748
# 49 0
# remaining_states=22658
# max_possible_ratio=0.99162
# min_possible_ratio=0.53846
# 48 1
# remaining_states=22609
# max_possible_ratio=0.9916
# min_possible_ratio=0.53942
# 49 0
# remaining_states=22560
# max_possible_ratio=0.9916
# min_possible_ratio=0.5404
# 48 1
# remaining_states=22511
# max_possible_ratio=0.99158
# min_possible_ratio=0.54136
# 48 1
# remaining_states=22462
# max_possible_ratio=0.99156
# min_possible_ratio=0.54232
# 49 0
# remaining_states=22413
# max_possible_ratio=0.99156
# min_possible_ratio=0.5433
# 49 0
# remaining_states=22364
# max_possible_ratio=0.99156
# min_possible_ratio=0.54428
# 49 0
# remaining_states=22315
# max_possible_ratio=0.99156
# min_possible_ratio=0.54526
# 49 0
# remaining_states=22266
# max_possible_ratio=0.99156
# min_possible_ratio=0.54624
# 49 0
# remaining_states=22217
# max_possible_ratio=0.99156
# min_possible_ratio=0.54722
# 49 0
# remaining_states=22168
# max_possible_ratio=0.99156
# min_possible_ratio=0.5482
# 48 1
# remaining_states=22119
# max_possible_ratio=0.99154
# min_possible_ratio=0.54916
# 49 0
# remaining_states=22070
# max_possible_ratio=0.99154
# min_possible_ratio=0.55014
# 46 3
# remaining_states=22021
# max_possible_ratio=0.99148
# min_possible_ratio=0.55106
# 49 0
# remaining_states=21972
# max_possible_ratio=0.99148
# min_possible_ratio=0.55204
# 47 2
# remaining_states=21923
# max_possible_ratio=0.99144
# min_possible_ratio=0.55298
# 49 0
# remaining_states=21874
# max_possible_ratio=0.99144
# min_possible_ratio=0.55396
# 47 2
# remaining_states=21825
# max_possible_ratio=0.9914
# min_possible_ratio=0.5549
# 48 1
# remaining_states=21776
# max_possible_ratio=0.99138
# min_possible_ratio=0.55586
# 47 2
# remaining_states=21727
# max_possible_ratio=0.99134
# min_possible_ratio=0.5568
# 47 2
# remaining_states=21678
# max_possible_ratio=0.9913
# min_possible_ratio=0.55774
# 49 0
# remaining_states=21629
# max_possible_ratio=0.9913
# min_possible_ratio=0.55872
# 49 0
# remaining_states=21580
# max_possible_ratio=0.9913
# min_possible_ratio=0.5597
# 49 0
# remaining_states=21531
# max_possible_ratio=0.9913
# min_possible_ratio=0.56068
# 46 3
# remaining_states=21482
# max_possible_ratio=0.99124
# min_possible_ratio=0.5616
# 49 0
# remaining_states=21433
# max_possible_ratio=0.99124
# min_possible_ratio=0.56258
# 49 0
# remaining_states=21384
# max_possible_ratio=0.99124
# min_possible_ratio=0.56356
# 49 0
# remaining_states=21335
# max_possible_ratio=0.99124
# min_possible_ratio=0.56454
# 48 1
# remaining_states=21286
# max_possible_ratio=0.99122
# min_possible_ratio=0.5655
# 49 0
# remaining_states=21237
# max_possible_ratio=0.99122
# min_possible_ratio=0.56648
# 49 0
# remaining_states=21188
# max_possible_ratio=0.99122
# min_possible_ratio=0.56746
# 49 0
# remaining_states=21139
# ...
# max_possible_ratio=0.98566
# min_possible_ratio=0.57856
# 49 0
# remaining_states=20306
# max_possible_ratio=0.98566
# min_possible_ratio=0.57954
# 49 0
# remaining_states=20257
# max_possible_ratio=0.98566
# min_possible_ratio=0.58052
# 48 1
# remaining_states=20208
# max_possible_ratio=0.98564
# min_possible_ratio=0.58148
# 49 0
# remaining_states=20159
# max_possible_ratio=0.98564
# min_possible_ratio=0.58246
# 48 1
# remaining_states=20110
# max_possible_ratio=0.98562
# min_possible_ratio=0.58342
# 49 0
# remaining_states=20061
# max_possible_ratio=0.98562
# min_possible_ratio=0.5844
# 49 0
# remaining_states=20012
# max_possible_ratio=0.98562
# min_possible_ratio=0.58538
# 49 0
# remaining_states=19963
# max_possible_ratio=0.98562
# min_possible_ratio=0.58636
# 43 6
# remaining_states=19914
# max_possible_ratio=0.9855
# min_possible_ratio=0.58722
# 49 0
# remaining_states=19865
# max_possible_ratio=0.9855
# min_possible_ratio=0.5882
# 45 4
# remaining_states=19816
# max_possible_ratio=0.98542
# min_possible_ratio=0.5891
# 49 0
# remaining_states=19767
# max_possible_ratio=0.98542
# min_possible_ratio=0.59008
# 46 3
# remaining_states=19718
# max_possible_ratio=0.98536
# min_possible_ratio=0.591
# 49 0
# remaining_states=19669
# max_possible_ratio=0.98536
# min_possible_ratio=0.59198
# 49 0
# remaining_states=19620
# max_possible_ratio=0.98536
# min_possible_ratio=0.59296
# 49 0
# remaining_states=19571
# max_possible_ratio=0.98536
# min_possible_ratio=0.59394
# 49 0
# remaining_states=19522
# max_possible_ratio=0.98536
# min_possible_ratio=0.59492
# 49 0
# remaining_states=19473
# max_possible_ratio=0.98536
# min_possible_ratio=0.5959
# 49 0
# remaining_states=19424
# max_possible_ratio=0.98536
# min_possible_ratio=0.59688
# 49 0
# remaining_states=19375
# max_possible_ratio=0.98536
# min_possible_ratio=0.59786
# 45 4
# remaining_states=19326
# max_possible_ratio=0.98528
# min_possible_ratio=0.59876
# 40 9
# remaining_states=19277
# max_possible_ratio=0.9851
# min_possible_ratio=0.59956
# 46 3
# remaining_states=19228
# max_possible_ratio=0.98504
# min_possible_ratio=0.60048
# 49 0
# remaining_states=19179
# max_possible_ratio=0.98504
# min_possible_ratio=0.60146
# 48 1
# remaining_states=19130
# max_possible_ratio=0.98502
# min_possible_ratio=0.60242
# 49 0
# remaining_states=19081
# max_possible_ratio=0.98502
# min_possible_ratio=0.6034
# 49 0
# remaining_states=19032
# max_possible_ratio=0.98502
# min_possible_ratio=0.60438
# 46 3
# remaining_states=18983
# max_possible_ratio=0.98496
# min_possible_ratio=0.6053
# 49 0
# remaining_states=18934
# max_possible_ratio=0.98496
# min_possible_ratio=0.60628
# 40 9
# remaining_states=18885
# max_possible_ratio=0.98478
# min_possible_ratio=0.60708
# 48 1
# remaining_states=18836
# max_possible_ratio=0.98476
# min_possible_ratio=0.60804
# 49 0
# remaining_states=18787
# max_possible_ratio=0.98476
# min_possible_ratio=0.60902
# 49 0
# remaining_states=18738
# max_possible_ratio=0.98476
# min_possible_ratio=0.61
# 44 5
# remaining_states=18689
# max_possible_ratio=0.98466
# min_possible_ratio=0.61088
# 49 0
# remaining_states=18640
# max_possible_ratio=0.98466
# min_possible_ratio=0.61186
# 49 0
# remaining_states=18591
# max_possible_ratio=0.98466
# min_possible_ratio=0.61284
# 49 0
# remaining_states=18542
# max_possible_ratio=0.98466
# min_possible_ratio=0.61382
# 48 1
# remaining_states=18493
# max_possible_ratio=0.98464
# min_possible_ratio=0.61478
# 43 6
# remaining_states=18444
# max_possible_ratio=0.98452
# min_possible_ratio=0.61564
# 49 0
# remaining_states=18395
# max_possible_ratio=0.98452
# min_possible_ratio=0.61662
# 49 0
# remaining_states=18346
# max_possible_ratio=0.98452
# min_possible_ratio=0.6176
# 49 0
# remaining_states=18297
# max_possible_ratio=0.98452
# min_possible_ratio=0.61858
# 49 0
# remaining_states=18248
# max_possible_ratio=0.98452
# min_possible_ratio=0.61956
# 49 0
# remaining_states=18199
# max_possible_ratio=0.98452
# min_possible_ratio=0.62054
# 49 0
# remaining_states=18150
# max_possible_ratio=0.98452
# min_possible_ratio=0.62152
# 49 0
# remaining_states=18101
# max_possible_ratio=0.98452
# min_possible_ratio=0.6225
# 48 1
# remaining_states=18052
# max_possible_ratio=0.9845
# min_possible_ratio=0.62346
# 49 0
# remaining_states=18003
# max_possible_ratio=0.9845
# min_possible_ratio=0.62444
# 49 0
# remaining_states=17954
# max_possible_ratio=0.9845
# min_possible_ratio=0.62542
# 49 0
# remaining_states=17905
# max_possible_ratio=0.9845
# min_possible_ratio=0.6264
# 49 0
# remaining_states=17856
# max_possible_ratio=0.9845
# min_possible_ratio=0.62738
# 49 0
# remaining_states=17807
# max_possible_ratio=0.9845
# min_possible_ratio=0.62836
# 49 0
# remaining_states=17758
# max_possible_ratio=0.9845
# min_possible_ratio=0.62934
# 49 0
# remaining_states=17709
# max_possible_ratio=0.9845
# min_possible_ratio=0.63032
# 49 0
# remaining_states=17660
# max_possible_ratio=0.9845
# min_possible_ratio=0.6313
# 49 0
# remaining_states=17611
# max_possible_ratio=0.9845
# min_possible_ratio=0.63228
# 49 0
# remaining_states=17562
# max_possible_ratio=0.9845
# min_possible_ratio=0.63326
# 49 0
# remaining_states=17513
# max_possible_ratio=0.9845
# min_possible_ratio=0.63424
# 41 8
# remaining_states=17464
# max_possible_ratio=0.98434
# min_possible_ratio=0.63506
# 49 0
# remaining_states=17415
# max_possible_ratio=0.98434
# min_possible_ratio=0.63604
# 49 0
# remaining_states=17366
# max_possible_ratio=0.98434
# min_possible_ratio=0.63702
# 49 0
# remaining_states=17317
# max_possible_ratio=0.98434
# min_possible_ratio=0.638
# 49 0
# remaining_states=17268
# max_possible_ratio=0.98434
# min_possible_ratio=0.63898
# 49 0
# remaining_states=17219
# max_possible_ratio=0.98434
# min_possible_ratio=0.63996
# 49 0
# remaining_states=17170
# max_possible_ratio=0.98434
# min_possible_ratio=0.64094
# 49 0
# remaining_states=17121
# max_possible_ratio=0.98434
# min_possible_ratio=0.64192
# 49 0
# remaining_states=17072
# max_possible_ratio=0.98434
# min_possible_ratio=0.6429
# 49 0
# remaining_states=17023
# max_possible_ratio=0.98434
# min_possible_ratio=0.64388
# 49 0
# remaining_states=16974
# max_possible_ratio=0.98434
# min_possible_ratio=0.64486
# 49 0
# remaining_states=16925
# max_possible_ratio=0.98434
# min_possible_ratio=0.64584
# 48 1
# remaining_states=16876
# max_possible_ratio=0.98432
# min_possible_ratio=0.6468
# 44 5
# remaining_states=16827
# max_possible_ratio=0.98422
# min_possible_ratio=0.64768
# 43 6
# remaining_states=16778
# max_possible_ratio=0.9841
# min_possible_ratio=0.64854
# 47 2
# remaining_states=16729
# max_possible_ratio=0.98406
# min_possible_ratio=0.64948
# 49 0
# remaining_states=16680
# max_possible_ratio=0.98406
# min_possible_ratio=0.65046
# 49 0
# remaining_states=16631
# max_possible_ratio=0.98406
# min_possible_ratio=0.65144
# 49 0
# remaining_states=16582
# max_possible_ratio=0.98406
# min_possible_ratio=0.65242
# 46 3
# remaining_states=16533
# max_possible_ratio=0.984
# min_possible_ratio=0.65334
# 49 0
# remaining_states=16484
# max_possible_ratio=0.984
# min_possible_ratio=0.65432
# 48 1
# remaining_states=16435
# max_possible_ratio=0.98398
# min_possible_ratio=0.65528
# 49 0
# remaining_states=16386
# max_possible_ratio=0.98398
# min_possible_ratio=0.65626
# 49 0
# remaining_states=16337
# max_possible_ratio=0.98398
# min_possible_ratio=0.65724
# 48 1
# remaining_states=16288
# max_possible_ratio=0.98396
# min_possible_ratio=0.6582
# 49 0
# remaining_states=16239
# max_possible_ratio=0.98396
# min_possible_ratio=0.65918
# 49 0
# remaining_states=16190
# max_possible_ratio=0.98396
# min_possible_ratio=0.66016
# 49 0
# remaining_states=16141
# max_possible_ratio=0.98396
# min_possible_ratio=0.66114
# 49 0
# remaining_states=16092
# max_possible_ratio=0.98396
# min_possible_ratio=0.66212
# 49 0
# remaining_states=16043
# max_possible_ratio=0.98396
# min_possible_ratio=0.6631
# 46 3
# remaining_states=15994
# max_possible_ratio=0.9839
# min_possible_ratio=0.66402
# 48 1
# remaining_states=15945
# max_possible_ratio=0.98388
# min_possible_ratio=0.66498
# 49 0
# remaining_states=15896
# max_possible_ratio=0.98388
# min_possible_ratio=0.66596
# 47 2
# remaining_states=15847
# max_possible_ratio=0.98384
# min_possible_ratio=0.6669
# 49 0
# remaining_states=15798
# max_possible_ratio=0.98384
# min_possible_ratio=0.66788
# 49 0
# remaining_states=15749
# max_possible_ratio=0.98384
# min_possible_ratio=0.66886
# 48 1
# remaining_states=15700
# max_possible_ratio=0.98382
# min_possible_ratio=0.66982
# 48 1
# remaining_states=15651
# max_possible_ratio=0.9838
# min_possible_ratio=0.67078
# 49 0
# remaining_states=15602
# max_possible_ratio=0.9838
# min_possible_ratio=0.67176
# 49 0
# remaining_states=15553
# max_possible_ratio=0.9838
# min_possible_ratio=0.67274
# 49 0
# remaining_states=15504
# max_possible_ratio=0.9838
# min_possible_ratio=0.67372
# 49 0
# remaining_states=15455
# max_possible_ratio=0.9838
# min_possible_ratio=0.6747
# 49 0
# remaining_states=15406
# max_possible_ratio=0.9838
# min_possible_ratio=0.67568
# 42 7
# remaining_states=15357
# max_possible_ratio=0.98366
# min_possible_ratio=0.67652
# 49 0
# remaining_states=15308
# max_possible_ratio=0.98366
# min_possible_ratio=0.6775
# 48 1
# remaining_states=15259
# max_possible_ratio=0.98364
# min_possible_ratio=0.67846
# 49 0
# remaining_states=15210
# max_possible_ratio=0.98364
# min_possible_ratio=0.67944
# 49 0
# remaining_states=15161
# max_possible_ratio=0.98364
# min_possible_ratio=0.68042
# 35 14
# remaining_states=15112
# max_possible_ratio=0.98336
# min_possible_ratio=0.68112
# 49 0
# remaining_states=15063
# max_possible_ratio=0.98336
# min_possible_ratio=0.6821
# 49 0
# remaining_states=15014
# max_possible_ratio=0.98336
# min_possible_ratio=0.68308
# 49 0
# remaining_states=14965
# max_possible_ratio=0.98336
# min_possible_ratio=0.68406
# 49 0
# remaining_states=14916
# max_possible_ratio=0.98336
# min_possible_ratio=0.68504
# 49 0
# remaining_states=14867
# max_possible_ratio=0.98336
# min_possible_ratio=0.68602
# 49 0
# remaining_states=14818
# max_possible_ratio=0.98336
# min_possible_ratio=0.687
# 48 1
# remaining_states=14769
# max_possible_ratio=0.98334
# min_possible_ratio=0.68796
# 41 8
# remaining_states=14720
# max_possible_ratio=0.98318
# min_possible_ratio=0.68878
# 49 0
# remaining_states=14671
# max_possible_ratio=0.98318
# min_possible_ratio=0.68976
# 49 0
# remaining_states=14622
# max_possible_ratio=0.98318
# min_possible_ratio=0.69074
# 49 0
# remaining_states=14573
# max_possible_ratio=0.98318
# min_possible_ratio=0.69172
# 49 0
# remaining_states=14524
# max_possible_ratio=0.98318
# min_possible_ratio=0.6927
# 48 1
# remaining_states=14475
# max_possible_ratio=0.98316
# min_possible_ratio=0.69366
# 44 5
# remaining_states=14426
# max_possible_ratio=0.98306
# min_possible_ratio=0.69454
# 49 0
# remaining_states=14377
# max_possible_ratio=0.98306
# min_possible_ratio=0.69552
# 49 0
# remaining_states=14328
# max_possible_ratio=0.98306
# min_possible_ratio=0.6965
# 41 8
# remaining_states=14279
# max_possible_ratio=0.9829
# min_possible_ratio=0.69732
# 49 0
# remaining_states=14230
# max_possible_ratio=0.9829
# min_possible_ratio=0.6983
# 44 5
# remaining_states=14181
# max_possible_ratio=0.9828
# min_possible_ratio=0.69918
# 49 0
# remaining_states=14132
# max_possible_ratio=0.9828
# min_possible_ratio=0.70016
# 49 0
# remaining_states=14083
# max_possible_ratio=0.9828
# min_possible_ratio=0.70114
# 49 0
# remaining_states=14034
# max_possible_ratio=0.9828
# min_possible_ratio=0.70212
# 48 1
# remaining_states=13985
# max_possible_ratio=0.98278
# min_possible_ratio=0.70308
# 45 4
# remaining_states=13936
# max_possible_ratio=0.9827
# min_possible_ratio=0.70398
# 49 0
# remaining_states=13887
# max_possible_ratio=0.9827
# min_possible_ratio=0.70496
# 48 1
# remaining_states=13838
# max_possible_ratio=0.98268
# min_possible_ratio=0.70592
# 49 0
# remaining_states=13789
# max_possible_ratio=0.98268
# min_possible_ratio=0.7069
# 49 0
# remaining_states=13740
# max_possible_ratio=0.98268
# min_possible_ratio=0.70788
# 49 0
# remaining_states=13691
# max_possible_ratio=0.98268
# min_possible_ratio=0.70886
# 49 0
# remaining_states=13642
# max_possible_ratio=0.98268
# min_possible_ratio=0.70984
# 47 2
# remaining_states=13593
# max_possible_ratio=0.98264
# min_possible_ratio=0.71078
# 49 0
# remaining_states=13544
# max_possible_ratio=0.98264
# min_possible_ratio=0.71176
# 43 6
# remaining_states=13495
# max_possible_ratio=0.98252
# min_possible_ratio=0.71262
# 49 0
# remaining_states=13446
# max_possible_ratio=0.98252
# min_possible_ratio=0.7136
# 46 3
# remaining_states=13397
# max_possible_ratio=0.98246
# min_possible_ratio=0.71452
# 49 0
# remaining_states=13348
# max_possible_ratio=0.98246
# min_possible_ratio=0.7155
# 48 1
# remaining_states=13299
# max_possible_ratio=0.98244
# min_possible_ratio=0.71646
# 49 0
# remaining_states=13250
# max_possible_ratio=0.98244
# min_possible_ratio=0.71744
# 49 0
# remaining_states=13201
# max_possible_ratio=0.98244
# min_possible_ratio=0.71842
# 49 0
# remaining_states=13152
# max_possible_ratio=0.98244
# min_possible_ratio=0.7194
# 49 0
# remaining_states=13103
# max_possible_ratio=0.98244
# min_possible_ratio=0.72038
# 48 1
# remaining_states=13054
# max_possible_ratio=0.98242
# min_possible_ratio=0.72134
# 49 0
# remaining_states=13005
# max_possible_ratio=0.98242
# min_possible_ratio=0.72232
# 49 0
# remaining_states=12956
# max_possible_ratio=0.98242
# min_possible_ratio=0.7233
# 49 0
# remaining_states=12907
# max_possible_ratio=0.98242
# min_possible_ratio=0.72428
# 49 0
# remaining_states=12858
# max_possible_ratio=0.98242
# min_possible_ratio=0.72526
# 49 0
# remaining_states=12809
# max_possible_ratio=0.98242
# min_possible_ratio=0.72624
# 46 3
# remaining_states=12760
# max_possible_ratio=0.98236
# min_possible_ratio=0.72716
# 49 0
# remaining_states=12711
# max_possible_ratio=0.98236
# min_possible_ratio=0.72814
# 49 0
# remaining_states=12662
# max_possible_ratio=0.98236
# min_possible_ratio=0.72912
# 48 1
# remaining_states=12613
# max_possible_ratio=0.98234
# min_possible_ratio=0.73008
# 49 0
# remaining_states=12564
# max_possible_ratio=0.98234
# min_possible_ratio=0.73106
# 49 0
# remaining_states=12515
# max_possible_ratio=0.98234
# min_possible_ratio=0.73204
# 49 0
# remaining_states=12466
# max_possible_ratio=0.98234
# min_possible_ratio=0.73302
# 49 0
# remaining_states=12417
# max_possible_ratio=0.98234
# min_possible_ratio=0.734
# 49 0
# remaining_states=12368
# max_possible_ratio=0.98234
# min_possible_ratio=0.73498
# 49 0
# remaining_states=12319
# max_possible_ratio=0.98234
# min_possible_ratio=0.73596
# 49 0
# remaining_states=12270
# max_possible_ratio=0.98234
# min_possible_ratio=0.73694
# 49 0
# remaining_states=12221
# max_possible_ratio=0.98234
# min_possible_ratio=0.73792
# 36 13
# remaining_states=12172
# max_possible_ratio=0.98208
# min_possible_ratio=0.73864
# 49 0
# remaining_states=12123
# max_possible_ratio=0.98208
# min_possible_ratio=0.73962
# 49 0
# remaining_states=12074
# max_possible_ratio=0.98208
# min_possible_ratio=0.7406
# 49 0
# remaining_states=12025
# max_possible_ratio=0.98208
# min_possible_ratio=0.74158
# 49 0
# remaining_states=11976
# max_possible_ratio=0.98208
# min_possible_ratio=0.74256
# 49 0
# remaining_states=11927
# max_possible_ratio=0.98208
# min_possible_ratio=0.74354
# 48 1
# remaining_states=11878
# max_possible_ratio=0.98206
# min_possible_ratio=0.7445
# 49 0
# remaining_states=11829
# max_possible_ratio=0.98206
# min_possible_ratio=0.74548
# 48 1
# remaining_states=11780
# max_possible_ratio=0.98204
# min_possible_ratio=0.74644
# 42 7
# remaining_states=11731
# max_possible_ratio=0.9819
# min_possible_ratio=0.74728
# 47 2
# remaining_states=11682
# max_possible_ratio=0.98186
# min_possible_ratio=0.74822
# 49 0
# remaining_states=11633
# max_possible_ratio=0.98186
# min_possible_ratio=0.7492
# 43 6
# remaining_states=11584
# max_possible_ratio=0.98174
# min_possible_ratio=0.75006
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0003.csv NOT created (requirements not met). Skipping inference.
#
# [SUMMARY] Generated datasets: 0/4
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Uruchomienie pełnego eksperymentu (test całego pipeline'u)
# ----> 2 exp_trajectory_length.run_experiment(n_jobs=1)
#       4 # Sprawdzenie, jakie pliki zostały wygenerowane
#       5 from pathlib import Path
#
# File ~/repositories/SAD2_final_project/src/sad2_final_project/analysis/experiment.py:280, in BooleanNetworkExperiment.run_experiment(self, n_jobs, subset)
#     277 print(f"\n[SUMMARY] Generated datasets: {success_count}/{len(rows)}")
#     279 # merge all csv
# --> 280 self._merge_csv()
#     281 # obtain metadata
#     282 self.save_experiment_df_to_csv()
#
# File ~/repositories/SAD2_final_project/src/sad2_final_project/analysis/experiment.py:162, in BooleanNetworkExperiment._merge_csv(self, csv_dir)
#     160 csv_files = sorted(csv_dir.glob("*.csv"))
#     161 if not csv_files:
# --> 162     raise RuntimeError("No CSV files to merge")
#     163 # join pdfs
#     164 df = pd.concat(
#     165     (pd.read_csv(f) for f in csv_files),
#     166     ignore_index=True
#     167 )
#
# RuntimeError: No CSV files to merge
