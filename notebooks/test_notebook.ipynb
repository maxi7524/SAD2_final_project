# %%
# boolean network packages
from sad2_final_project.analysis import BooleanNetworkExperiment
# system packages
import os
from pathlib import Path


# paths
## set global dir
cwd=Path.cwd()
if cwd.name == "notebooks":
    os.chdir(cwd.parent) 
print(os.getcwd())
## create paths 
DATA_PATH = Path('data')
# # TODO OBSOLETE 
# DATASET_PATH = DATA_PATH / 'datasets'
# BN_TRUE_PATH = DATA_PATH / 'bn_ground_truth'
# BN_DATASET_BNFINDER_FORMAT_PATH = DATA_PATH / 'datasets_bnfinder_format'
# BN_RESULT_PATH = DATA_PATH / "result"
## create directories
# !mkdir {DATA_PATH}
# TODO OBSOLETE
# !mkdir -p {DATASET_PATH}
# !mkdir -p {BN_TRUE_PATH}
# !mkdir -p {BN_DATASET_BNFINDER_FORMAT_PATH}
# !mkdir -p {BN_RESULT_PATH}
# Out:
# /home/maxi7524/repositories/SAD2_final_project
# mkdir: cannot create directory ‘data’: File exists

# %%
# TODO: REMOVE - only for fast test s
# create experiments:
## case: Relation between trajectory length and entering attractors
exp_trajectory_length = BooleanNetworkExperiment(
    # paths
    data_path=DATA_PATH,
    experiment_name='MICHAŁ_METRICS',
    # experiment values
    num_nodes=[6, 8],
    update_mode=["synchronous", "asynchronous"], # , "asynchronous"
    trajectory_length=list(range(10, 40, 10)),
    n_trajectories=[5, 10],
    sampling_frequency=[1, 2, 3],
    score_functions=["MDL", "BDE"],
    # TODO - add metrics options 

    n_parents_per_node=[[2, 3, 4]],
    # amount of samples per experiment 
    n_repetitions=1,
    simulate_trajectories_to_csv_kwargs = {
            # "sampling_frequency": 1,
            "target_attractor_ratio": 0.5,  # Approximate fraction of trajectory in attractor (0-1)
            "tolerance": 0.25,               # Allowed deviation from the calculated entrance step (0-1)
        }
) 
exp_trajectory_length.show_experiment_df()
# Out:
#      num_nodes   update_mode  trajectory_length  n_trajectories  \
# 0            6   synchronous                 10               5
# 1            6   synchronous                 10               5
# 2            6   synchronous                 10               5
# 3            6   synchronous                 10               5
# 4            6   synchronous                 10               5
# ..         ...           ...                ...             ...
# 139          8  asynchronous                 30              10
# 140          8  asynchronous                 30              10
# 141          8  asynchronous                 30              10
# 142          8  asynchronous                 30              10
# 143          8  asynchronous                 30              10
#
#      sampling_frequency score_function n_parents_per_node  rep_id condition_id
# 0                     1            MDL          [2, 3, 4]       0         0000
# 1                     1            BDE          [2, 3, 4]       0         0001
# 2                     2            MDL          [2, 3, 4]       0         0002
# 3                     2            BDE          [2, 3, 4]       0         0003
# 4                     3            MDL          [2, 3, 4]       0         0004
# ..                  ...            ...                ...     ...          ...
# 139                   1            BDE          [2, 3, 4]       0         0139
# 140                   2            MDL          [2, 3, 4]       0         0140
# 141                   2            BDE          [2, 3, 4]       0         0141
# 142                   3            MDL          [2, 3, 4]       0         0142
# 143                   3            BDE          [2, 3, 4]       0         0143
#
# [144 rows x 9 columns]

# %%
# Uruchomienie pełnego eksperymentu (test całego pipeline'u)
exp_trajectory_length.run_experiment(n_jobs=1)

# Sprawdzenie, jakie pliki zostały wygenerowane
from pathlib import Path
import os

experiment_dir = Path("data/MICHAŁ_METRICS")
print("Zawartość katalogu eksperymentu:")
for path in experiment_dir.rglob("*"):
    print(path)
# Out:
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0000.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0001.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0002.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0003.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0004.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0005.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0006.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0007.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0008.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0009.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0010.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0011.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0012.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0013.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0014.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0015.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0016.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0017.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0018.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0019.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0020.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0021.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0022.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0023.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0024.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0025.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0026.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0027.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0028.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0029.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0030.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0031.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0032.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0033.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0034.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0035.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0036.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0037.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0038.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0039.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0040.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0041.csv NOT created (requirements not met). Skipping inference.
# Dataset saved to data/MICHAŁ_METRICS/datasets/0042.csv (actual attractor ratio: 0.41)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0042.csv
#    Loaded dataset with shape: (100, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0042.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0042.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0042_MDL.sif
# 3
# 3
# 3
# 3
# 3
# 3
# [MDL] Inferred 6 edges.
# a
#    (Ground truth file found, evaluating metrics)
# [MDL] Failed: string index out of range
#
# === DONE ===
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0043.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0044.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0045.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0046.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0047.csv NOT created (requirements not met). Skipping inference.
# Dataset saved to data/MICHAŁ_METRICS/datasets/0048.csv (actual attractor ratio: 0.67)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0048.csv
#    Loaded dataset with shape: (100, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0048.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0048.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0048_MDL.sif
# 3
# 3
# 3
# 3
# 3
# [MDL] Inferred 5 edges.
# a
#    (Ground truth file found, evaluating metrics)
# [MDL] Failed: string index out of range
#
# === DONE ===
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0049.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0050.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0051.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0052.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0053.csv NOT created (requirements not met). Skipping inference.
# Dataset saved to data/MICHAŁ_METRICS/datasets/0054.csv (actual attractor ratio: 0.53)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0054.csv
#    Loaded dataset with shape: (200, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0054.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0054.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0054_MDL.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [MDL] Inferred 12 edges.
# a
#    (Ground truth file found, evaluating metrics)
# [MDL] Failed: string index out of range
#
# === DONE ===
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0055.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0056.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0057.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0058.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0059.csv NOT created (requirements not met). Skipping inference.
# Dataset saved to data/MICHAŁ_METRICS/datasets/0060.csv (actual attractor ratio: 0.74)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0060.csv
#    Loaded dataset with shape: (150, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0060.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0060.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0060_MDL.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [MDL] Inferred 7 edges.
# a
#    (Ground truth file found, evaluating metrics)
# [MDL] Failed: string index out of range
#
# === DONE ===
# Dataset saved to data/MICHAŁ_METRICS/datasets/0061.csv (actual attractor ratio: 0.52)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0061.csv
#    Loaded dataset with shape: (150, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0061.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0061.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0061_BDE.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [BDE] Inferred 10 edges.
# a
#    (Ground truth file found, evaluating metrics)
# [BDE] Failed: string index out of range
#
# === DONE ===
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0062.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0063.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0064.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0065.csv NOT created (requirements not met). Skipping inference.
# Dataset saved to data/MICHAŁ_METRICS/datasets/0066.csv (actual attractor ratio: 0.55)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0066.csv
#    Loaded dataset with shape: (300, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0066.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0066.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0066_MDL.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [MDL] Inferred 13 edges.
# a
#    (Ground truth file found, evaluating metrics)
# [MDL] Failed: string index out of range
#
# === DONE ===
# Dataset saved to data/MICHAŁ_METRICS/datasets/0067.csv (actual attractor ratio: 0.71)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0067.csv
#    Loaded dataset with shape: (300, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0067.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0067.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0067_BDE.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [BDE] Inferred 10 edges.
# a
#    (Ground truth file found, evaluating metrics)
# [BDE] Failed: string index out of range
#
# === DONE ===
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0068.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0069.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0070.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0071.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0072.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0073.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0074.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0075.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0076.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0077.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0078.csv NOT created (requirements not met). Skipping inference.
# Dataset saved to data/MICHAŁ_METRICS/datasets/0079.csv (actual attractor ratio: 0.68)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0079.csv
#    Loaded dataset with shape: (100, 8)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0079.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0079.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0079_BDE.sif
# 3
# 3
# 3
# 3
# 3
# [BDE] Inferred 5 edges.
# a
#    (Ground truth file found, evaluating metrics)
# [BDE] Failed: string index out of range
#
# === DONE ===
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0080.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0081.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0082.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0083.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0084.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0085.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0086.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0087.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0088.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0089.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0090.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0091.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0092.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0093.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0094.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0095.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0096.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0097.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0098.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0099.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0100.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0101.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0102.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0103.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0104.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0105.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0106.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0107.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0108.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0109.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0110.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0111.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0112.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0113.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0114.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0115.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0116.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0117.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0118.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0119.csv NOT created (requirements not met). Skipping inference.
# Dataset saved to data/MICHAŁ_METRICS/datasets/0120.csv (actual attractor ratio: 0.29)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0120.csv
#    Loaded dataset with shape: (100, 8)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0120.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0120.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0120_MDL.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [MDL] Inferred 14 edges.
# a
#    (Ground truth file found, evaluating metrics)
# [MDL] Failed: string index out of range
#
# === DONE ===
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0121.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0122.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0123.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0124.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0125.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0126.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0127.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0128.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0129.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0130.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0131.csv NOT created (requirements not met). Skipping inference.
# Dataset saved to data/MICHAŁ_METRICS/datasets/0132.csv (actual attractor ratio: 0.45)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0132.csv
#    Loaded dataset with shape: (150, 8)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0132.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0132.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0132_MDL.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [MDL] Inferred 14 edges.
# a
#    (Ground truth file found, evaluating metrics)
# [MDL] Failed: string index out of range
#
# === DONE ===
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0133.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0134.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0135.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0136.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0137.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0138.csv NOT created (requirements not met). Skipping inference.
# Dataset saved to data/MICHAŁ_METRICS/datasets/0139.csv (actual attractor ratio: 0.27)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0139.csv
#    Loaded dataset with shape: (300, 8)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0139.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0139.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
#    Success! Output saved to data/MICHAŁ_METRICS/results/0139_BDE.sif
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# [BDE] Inferred 25 edges.
# a
#    (Ground truth file found, evaluating metrics)
# [BDE] Failed: string index out of range
#
# === DONE ===
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0140.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0141.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0142.csv NOT created (requirements not met). Skipping inference.
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0143.csv NOT created (requirements not met). Skipping inference.
#
# [SUMMARY] Generated datasets: 11/144
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Uruchomienie pełnego eksperymentu (test całego pipeline'u)
# ----> 2 exp_trajectory_length.run_experiment(n_jobs=1)
#       4 # Sprawdzenie, jakie pliki zostały wygenerowane
#       5 from pathlib import Path
#
# File ~/repositories/SAD2_final_project/src/sad2_final_project/analysis/experiment.py:279, in BooleanNetworkExperiment.run_experiment(self, n_jobs, subset)
#     276 print(f"\n[SUMMARY] Generated datasets: {success_count}/{len(rows)}")
#     278 # merge all csv
# --> 279 self._merge_csv()
#     280 # obtain metadata
#     281 self.save_experiment_df_to_csv()
#
# File ~/repositories/SAD2_final_project/src/sad2_final_project/analysis/experiment.py:161, in BooleanNetworkExperiment._merge_csv(self, csv_dir)
#     159 csv_files = sorted(csv_dir.glob("*.csv"))
#     160 if not csv_files:
# --> 161     raise RuntimeError("No CSV files to merge")
#     162 # join pdfs
#     163 df = pd.concat(
#     164     (pd.read_csv(f) for f in csv_files),
#     165     ignore_index=True
#     166 )
#
# RuntimeError: No CSV files to merge

# %%
# TODO: REMOVE - only for fast test s
# create experiments:
## case: Relation between trajectory length and entering attractors
exp_trajectory_length = BooleanNetworkExperiment(
    # paths
    data_path=DATA_PATH,
    experiment_name='MICHAŁ_METRICS',
    # experiment values
    num_nodes=[6, 8, 12],
    update_mode=["synchronous", "asynchronous"], # , "asynchronous"
    trajectory_length=list(range(5, 10, 20)),
    n_trajectories=[10],
    sampling_frequency=[1, 3],
    score_functions=["MDL", "BDE"],
    # TODO - add metrics options 

    n_parents_per_node=[[1, 2, 3, 4]],
    # amount of samples per experiment 
    n_repetitions=1,
    simulate_trajectories_to_csv_kwargs = {
            # "sampling_frequency": 1,
            "target_attractor_ratio": 0.5,  # Approximate fraction of trajectory in attractor (0-1)
            "tolerance": 0.25,               # Allowed deviation from the calculated entrance step (0-1)
        }
) 
exp_trajectory_length.show_experiment_df()
# Out:
#     num_nodes   update_mode  trajectory_length  n_trajectories  \
# 0           6   synchronous                  5              10
# 1           6   synchronous                  5              10
# 2           6   synchronous                  5              10
# 3           6   synchronous                  5              10
# 4           6  asynchronous                  5              10
# 5           6  asynchronous                  5              10
# 6           6  asynchronous                  5              10
# 7           6  asynchronous                  5              10
# 8           8   synchronous                  5              10
# 9           8   synchronous                  5              10
# 10          8   synchronous                  5              10
# 11          8   synchronous                  5              10
# 12          8  asynchronous                  5              10
# 13          8  asynchronous                  5              10
# 14          8  asynchronous                  5              10
# 15          8  asynchronous                  5              10
# 16         12   synchronous                  5              10
# 17         12   synchronous                  5              10
# 18         12   synchronous                  5              10
# 19         12   synchronous                  5              10
# 20         12  asynchronous                  5              10
# 21         12  asynchronous                  5              10
# 22         12  asynchronous                  5              10
# 23         12  asynchronous                  5              10
#
#     sampling_frequency score_function n_parents_per_node  rep_id condition_id
# 0                    1            MDL       [1, 2, 3, 4]       0         0000
# 1                    1            BDE       [1, 2, 3, 4]       0         0001
# 2                    3            MDL       [1, 2, 3, 4]       0         0002
# 3                    3            BDE       [1, 2, 3, 4]       0         0003
# 4                    1            MDL       [1, 2, 3, 4]       0         0004
# 5                    1            BDE       [1, 2, 3, 4]       0         0005
# 6                    3            MDL       [1, 2, 3, 4]       0         0006
# 7                    3            BDE       [1, 2, 3, 4]       0         0007
# 8                    1            MDL       [1, 2, 3, 4]       0         0008
# 9                    1            BDE       [1, 2, 3, 4]       0         0009
# 10                   3            MDL       [1, 2, 3, 4]       0         0010
# 11                   3            BDE       [1, 2, 3, 4]       0         0011
# 12                   1            MDL       [1, 2, 3, 4]       0         0012
# 13                   1            BDE       [1, 2, 3, 4]       0         0013
# 14                   3            MDL       [1, 2, 3, 4]       0         0014
# 15                   3            BDE       [1, 2, 3, 4]       0         0015
# 16                   1            MDL       [1, 2, 3, 4]       0         0016
# 17                   1            BDE       [1, 2, 3, 4]       0         0017
# 18                   3            MDL       [1, 2, 3, 4]       0         0018
# 19                   3            BDE       [1, 2, 3, 4]       0         0019
# 20                   1            MDL       [1, 2, 3, 4]       0         0020
# 21                   1            BDE       [1, 2, 3, 4]       0         0021
# 22                   3            MDL       [1, 2, 3, 4]       0         0022
# 23                   3            BDE       [1, 2, 3, 4]       0         0023

# %%
# Uruchomienie pełnego eksperymentu (test całego pipeline'u)
exp_trajectory_length.run_experiment(n_jobs=1)

# Sprawdzenie, jakie pliki zostały wygenerowane
from pathlib import Path
import os

experiment_dir = Path("data/MICHAŁ_METRICS")
print("Zawartość katalogu eksperymentu:")
for path in experiment_dir.rglob("*"):
    print(path)
# Out:
# Ratios
# 0.25
# 0.75
# 4 0
# remaining_states=46
# max_possible_ratio=1.0
# min_possible_ratio=0.08
# 4 0
# remaining_states=42
# max_possible_ratio=1.0
# min_possible_ratio=0.16
# 4 0
# remaining_states=38
# max_possible_ratio=1.0
# min_possible_ratio=0.24
# 3 1
# remaining_states=34
# max_possible_ratio=0.98
# min_possible_ratio=0.3
# 4 0
# remaining_states=30
# max_possible_ratio=0.98
# min_possible_ratio=0.38
# 4 0
# remaining_states=26
# max_possible_ratio=0.98
# min_possible_ratio=0.46
# 4 0
# remaining_states=22
# max_possible_ratio=0.98
# min_possible_ratio=0.54
# 4 0
# remaining_states=18
# max_possible_ratio=0.98
# min_possible_ratio=0.62
# 4 0
# remaining_states=14
# max_possible_ratio=0.98
# min_possible_ratio=0.7
# 4 0
# remaining_states=10
# max_possible_ratio=0.98
# min_possible_ratio=0.78
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0000.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 3 1
# remaining_states=46
# max_possible_ratio=0.98
# min_possible_ratio=0.06
# 1 3
# remaining_states=42
# max_possible_ratio=0.92
# min_possible_ratio=0.08
# 1 3
# remaining_states=38
# max_possible_ratio=0.86
# min_possible_ratio=0.1
# 2 2
# remaining_states=34
# max_possible_ratio=0.82
# min_possible_ratio=0.14
# 2 2
# remaining_states=30
# max_possible_ratio=0.78
# min_possible_ratio=0.18
# 3 1
# remaining_states=26
# max_possible_ratio=0.76
# min_possible_ratio=0.24
# 3 1
# remaining_states=22
# max_possible_ratio=0.74
# min_possible_ratio=0.3
# 2 2
# remaining_states=18
# max_possible_ratio=0.7
# min_possible_ratio=0.34
# 3 1
# remaining_states=14
# max_possible_ratio=0.68
# min_possible_ratio=0.4
# 2 2
# remaining_states=10
# max_possible_ratio=0.64
# min_possible_ratio=0.44
# Dataset saved to data/MICHAŁ_METRICS/datasets/0001.csv (actual attractor ratio: 0.55)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0001.csv
#    Loaded dataset with shape: (50, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0001.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0001.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0001_BDE.sif
# ['G4', '-', 'G2']
# ['G5', '-', 'G2']
# [BDE] Inferred 2 edges.
#    (Ground truth file found, evaluating metrics)
# [BDE] Failed: 'tuple' object has no attribute 'split'
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 12 0
# remaining_states=38
# max_possible_ratio=1.0
# min_possible_ratio=0.24
# 12 0
# remaining_states=26
# max_possible_ratio=1.0
# min_possible_ratio=0.48
# 11 1
# remaining_states=14
# max_possible_ratio=0.98
# min_possible_ratio=0.7
# 8 4
# remaining_states=2
# max_possible_ratio=0.9
# min_possible_ratio=0.86
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0002.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 12 0
# remaining_states=38
# max_possible_ratio=1.0
# min_possible_ratio=0.24
# 12 0
# remaining_states=26
# max_possible_ratio=1.0
# min_possible_ratio=0.48
# 12 0
# remaining_states=14
# max_possible_ratio=1.0
# min_possible_ratio=0.72
# 12 0
# remaining_states=2
# max_possible_ratio=1.0
# min_possible_ratio=0.96
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0003.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 4
# remaining_states=46
# max_possible_ratio=0.92
# min_possible_ratio=0.0
# 0 4
# remaining_states=42
# max_possible_ratio=0.84
# min_possible_ratio=0.0
# 0 4
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 3 1
# remaining_states=34
# max_possible_ratio=0.74
# min_possible_ratio=0.06
# 4 0
# remaining_states=30
# max_possible_ratio=0.74
# min_possible_ratio=0.14
# 0 4
# remaining_states=26
# max_possible_ratio=0.66
# min_possible_ratio=0.14
# 4 0
# remaining_states=22
# max_possible_ratio=0.66
# min_possible_ratio=0.22
# 0 4
# remaining_states=18
# max_possible_ratio=0.58
# min_possible_ratio=0.22
# 4 0
# remaining_states=14
# max_possible_ratio=0.58
# min_possible_ratio=0.3
# 0 4
# remaining_states=10
# max_possible_ratio=0.5
# min_possible_ratio=0.3
# Dataset saved to data/MICHAŁ_METRICS/datasets/0004.csv (actual attractor ratio: 0.38)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0004.csv
#    Loaded dataset with shape: (50, 6)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0004.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0004.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0004_MDL.sif
# ['G2', '-', 'G4']
# ['G3', '-', 'G4']
# ['G4', '-', 'G3']
# ['G5', '-', 'G1']
# ['G5', '-', 'G6']
# [MDL] Inferred 5 edges.
#    (Ground truth file found, evaluating metrics)
# [MDL] Failed: 'tuple' object has no attribute 'split'
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 0 4
# remaining_states=46
# max_possible_ratio=0.92
# min_possible_ratio=0.0
# 0 4
# remaining_states=42
# max_possible_ratio=0.84
# min_possible_ratio=0.0
# 0 4
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 0 4
# remaining_states=34
# max_possible_ratio=0.68
# min_possible_ratio=0.0
# 0 4
# remaining_states=30
# max_possible_ratio=0.6
# min_possible_ratio=0.0
# 0 4
# remaining_states=26
# max_possible_ratio=0.52
# min_possible_ratio=0.0
# 0 4
# remaining_states=22
# max_possible_ratio=0.44
# min_possible_ratio=0.0
# 3 1
# remaining_states=18
# max_possible_ratio=0.42
# min_possible_ratio=0.06
# 0 4
# remaining_states=14
# max_possible_ratio=0.34
# min_possible_ratio=0.06
# 0 4
# remaining_states=10
# max_possible_ratio=0.26
# min_possible_ratio=0.06
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0005.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 1 11
# remaining_states=38
# max_possible_ratio=0.78
# min_possible_ratio=0.02
# 10 2
# remaining_states=26
# max_possible_ratio=0.74
# min_possible_ratio=0.22
# 7 5
# remaining_states=14
# max_possible_ratio=0.64
# min_possible_ratio=0.36
# 9 3
# remaining_states=2
# max_possible_ratio=0.58
# min_possible_ratio=0.54
# 1 11
# remaining_states=-10
# max_possible_ratio=0.36
# min_possible_ratio=0.56
# 3 9
# remaining_states=-22
# max_possible_ratio=0.18
# min_possible_ratio=0.62
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0006.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 12
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 11 1
# remaining_states=26
# max_possible_ratio=0.74
# min_possible_ratio=0.22
# 12 0
# remaining_states=14
# max_possible_ratio=0.74
# min_possible_ratio=0.46
# 0 12
# remaining_states=2
# max_possible_ratio=0.5
# min_possible_ratio=0.46
# 0 12
# remaining_states=-10
# max_possible_ratio=0.26
# min_possible_ratio=0.46
# 12 0
# remaining_states=-22
# max_possible_ratio=0.26
# min_possible_ratio=0.7
# 0 12
# remaining_states=-34
# max_possible_ratio=0.02
# min_possible_ratio=0.7
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0007.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 2 2
# remaining_states=46
# max_possible_ratio=0.96
# min_possible_ratio=0.04
# 0 4
# remaining_states=42
# max_possible_ratio=0.88
# min_possible_ratio=0.04
# 0 4
# remaining_states=38
# max_possible_ratio=0.8
# min_possible_ratio=0.04
# 0 4
# remaining_states=34
# max_possible_ratio=0.72
# min_possible_ratio=0.04
# 0 4
# remaining_states=30
# max_possible_ratio=0.64
# min_possible_ratio=0.04
# 0 4
# remaining_states=26
# max_possible_ratio=0.56
# min_possible_ratio=0.04
# 0 4
# remaining_states=22
# max_possible_ratio=0.48
# min_possible_ratio=0.04
# 2 2
# remaining_states=18
# max_possible_ratio=0.44
# min_possible_ratio=0.08
# 0 4
# remaining_states=14
# max_possible_ratio=0.36
# min_possible_ratio=0.08
# 0 4
# remaining_states=10
# max_possible_ratio=0.28
# min_possible_ratio=0.08
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0008.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 1 3
# remaining_states=46
# max_possible_ratio=0.94
# min_possible_ratio=0.02
# 3 1
# remaining_states=42
# max_possible_ratio=0.92
# min_possible_ratio=0.08
# 1 3
# remaining_states=38
# max_possible_ratio=0.86
# min_possible_ratio=0.1
# 0 4
# remaining_states=34
# max_possible_ratio=0.78
# min_possible_ratio=0.1
# 1 3
# remaining_states=30
# max_possible_ratio=0.72
# min_possible_ratio=0.12
# 1 3
# remaining_states=26
# max_possible_ratio=0.66
# min_possible_ratio=0.14
# 3 1
# remaining_states=22
# max_possible_ratio=0.64
# min_possible_ratio=0.2
# 1 3
# remaining_states=18
# max_possible_ratio=0.58
# min_possible_ratio=0.22
# 0 4
# remaining_states=14
# max_possible_ratio=0.5
# min_possible_ratio=0.22
# 1 3
# remaining_states=10
# max_possible_ratio=0.44
# min_possible_ratio=0.24
# Dataset saved to data/MICHAŁ_METRICS/datasets/0009.csv (actual attractor ratio: 0.30)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0009.csv
#    Loaded dataset with shape: (50, 8)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0009.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0009.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0009_BDE.sif
# ['G1', '+', 'G3']
# ['G1', '-', 'G5']
# ['G1', '+', 'G8']
# ['G3', '-', 'G2']
# ['G3', '-', 'G4']
# ['G6', '-', 'G8']
# ['G7', '-', 'G1']
# ['G8', '+', 'G3']
# ['G8', '+', 'G5']
# [BDE] Inferred 9 edges.
#    (Ground truth file found, evaluating metrics)
# [BDE] Failed: 'tuple' object has no attribute 'split'
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 11 1
# remaining_states=38
# max_possible_ratio=0.98
# min_possible_ratio=0.22
# 11 1
# remaining_states=26
# max_possible_ratio=0.96
# min_possible_ratio=0.44
# 10 2
# remaining_states=14
# max_possible_ratio=0.92
# min_possible_ratio=0.64
# 10 2
# remaining_states=2
# max_possible_ratio=0.88
# min_possible_ratio=0.84
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0010.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 10 2
# remaining_states=38
# max_possible_ratio=0.96
# min_possible_ratio=0.2
# 12 0
# remaining_states=26
# max_possible_ratio=0.96
# min_possible_ratio=0.44
# 9 3
# remaining_states=14
# max_possible_ratio=0.9
# min_possible_ratio=0.62
# 8 4
# remaining_states=2
# max_possible_ratio=0.82
# min_possible_ratio=0.78
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0011.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 4 0
# remaining_states=46
# max_possible_ratio=1.0
# min_possible_ratio=0.08
# 4 0
# remaining_states=42
# max_possible_ratio=1.0
# min_possible_ratio=0.16
# 0 4
# remaining_states=38
# max_possible_ratio=0.92
# min_possible_ratio=0.16
# 0 4
# remaining_states=34
# max_possible_ratio=0.84
# min_possible_ratio=0.16
# 0 4
# remaining_states=30
# max_possible_ratio=0.76
# min_possible_ratio=0.16
# 4 0
# remaining_states=26
# max_possible_ratio=0.76
# min_possible_ratio=0.24
# 4 0
# remaining_states=22
# max_possible_ratio=0.76
# min_possible_ratio=0.32
# 4 0
# remaining_states=18
# max_possible_ratio=0.76
# min_possible_ratio=0.4
# 4 0
# remaining_states=14
# max_possible_ratio=0.76
# min_possible_ratio=0.48
# 4 0
# remaining_states=10
# max_possible_ratio=0.76
# min_possible_ratio=0.56
# Dataset saved to data/MICHAŁ_METRICS/datasets/0012.csv (actual attractor ratio: 0.70)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0012.csv
#    Loaded dataset with shape: (50, 8)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0012.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0012.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: MDL...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0012_MDL.sif
# ['G2', '-', 'G6']
# ['G4', '+', 'G7']
# ['G5', '-', 'G4']
# ['G5', '+', 'G8']
# ['G6', '-', 'G7']
# ['G7', '+', 'G8']
# ['G8', '+', 'G6']
# [MDL] Inferred 7 edges.
#    (Ground truth file found, evaluating metrics)
# [MDL] Failed: 'tuple' object has no attribute 'split'
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 0 4
# remaining_states=46
# max_possible_ratio=0.92
# min_possible_ratio=0.0
# 0 4
# remaining_states=42
# max_possible_ratio=0.84
# min_possible_ratio=0.0
# 0 4
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 0 4
# remaining_states=34
# max_possible_ratio=0.68
# min_possible_ratio=0.0
# 0 4
# remaining_states=30
# max_possible_ratio=0.6
# min_possible_ratio=0.0
# 0 4
# remaining_states=26
# max_possible_ratio=0.52
# min_possible_ratio=0.0
# 0 4
# remaining_states=22
# max_possible_ratio=0.44
# min_possible_ratio=0.0
# 0 4
# remaining_states=18
# max_possible_ratio=0.36
# min_possible_ratio=0.0
# 0 4
# remaining_states=14
# max_possible_ratio=0.28
# min_possible_ratio=0.0
# 0 4
# remaining_states=10
# max_possible_ratio=0.2
# min_possible_ratio=0.0
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0013.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 12
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 0 12
# remaining_states=26
# max_possible_ratio=0.52
# min_possible_ratio=0.0
# 2 10
# remaining_states=14
# max_possible_ratio=0.32
# min_possible_ratio=0.04
# 0 12
# remaining_states=2
# max_possible_ratio=0.08
# min_possible_ratio=0.04
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0014.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 12
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 0 12
# remaining_states=26
# max_possible_ratio=0.52
# min_possible_ratio=0.0
# 0 12
# remaining_states=14
# max_possible_ratio=0.28
# min_possible_ratio=0.0
# 0 12
# remaining_states=2
# max_possible_ratio=0.04
# min_possible_ratio=0.0
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0015.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 4
# remaining_states=46
# max_possible_ratio=0.92
# min_possible_ratio=0.0
# 1 3
# remaining_states=42
# max_possible_ratio=0.86
# min_possible_ratio=0.02
# 2 2
# remaining_states=38
# max_possible_ratio=0.82
# min_possible_ratio=0.06
# 1 3
# remaining_states=34
# max_possible_ratio=0.76
# min_possible_ratio=0.08
# 0 4
# remaining_states=30
# max_possible_ratio=0.68
# min_possible_ratio=0.08
# 0 4
# remaining_states=26
# max_possible_ratio=0.6
# min_possible_ratio=0.08
# 1 3
# remaining_states=22
# max_possible_ratio=0.54
# min_possible_ratio=0.1
# 0 4
# remaining_states=18
# max_possible_ratio=0.46
# min_possible_ratio=0.1
# 0 4
# remaining_states=14
# max_possible_ratio=0.38
# min_possible_ratio=0.1
# 1 3
# remaining_states=10
# max_possible_ratio=0.32
# min_possible_ratio=0.12
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0016.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 2 2
# remaining_states=46
# max_possible_ratio=0.96
# min_possible_ratio=0.04
# 2 2
# remaining_states=42
# max_possible_ratio=0.92
# min_possible_ratio=0.08
# 3 1
# remaining_states=38
# max_possible_ratio=0.9
# min_possible_ratio=0.14
# 3 1
# remaining_states=34
# max_possible_ratio=0.88
# min_possible_ratio=0.2
# 3 1
# remaining_states=30
# max_possible_ratio=0.86
# min_possible_ratio=0.26
# 0 4
# remaining_states=26
# max_possible_ratio=0.78
# min_possible_ratio=0.26
# 2 2
# remaining_states=22
# max_possible_ratio=0.74
# min_possible_ratio=0.3
# 0 4
# remaining_states=18
# max_possible_ratio=0.66
# min_possible_ratio=0.3
# 0 4
# remaining_states=14
# max_possible_ratio=0.58
# min_possible_ratio=0.3
# 3 1
# remaining_states=10
# max_possible_ratio=0.56
# min_possible_ratio=0.36
# Dataset saved to data/MICHAŁ_METRICS/datasets/0017.csv (actual attractor ratio: 0.45)
# -> Loading external data from: data/MICHAŁ_METRICS/datasets/0017.csv
#    Loaded dataset with shape: (50, 12)
# -> Data written to data/MICHAŁ_METRICS/datasets_bnfinder/0017.txt
# -> Loading ground truth from: data/MICHAŁ_METRICS/bn_ground_truth/0017.csv
#
# === STARTING INFERENCE ===
# -> Running BNFinder with score: BDE...
# /home/asia/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/bnfinder/bnfinder.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edges.add((str(row[0]), str(row[1]))) # Parent, Child
#    Success! Output saved to data/MICHAŁ_METRICS/results/0017_BDE.sif
# ['G1', '-', 'G6']
# ['G1', '-', 'G9']
# ['G2', '+', 'G11']
# ['G9', '-', 'G5']
# ['G10', '+', 'G2']
# ['G10', '+', 'G4']
# ['G12', '-', 'G5']
# [BDE] Inferred 7 edges.
#    (Ground truth file found, evaluating metrics)
# [BDE] Failed: 'tuple' object has no attribute 'split'
#
# === DONE ===
# Ratios
# 0.25
# 0.75
# 7 5
# remaining_states=38
# max_possible_ratio=0.9
# min_possible_ratio=0.14
# 9 3
# remaining_states=26
# max_possible_ratio=0.84
# min_possible_ratio=0.32
# 7 5
# remaining_states=14
# max_possible_ratio=0.74
# min_possible_ratio=0.46
# 9 3
# remaining_states=2
# max_possible_ratio=0.68
# min_possible_ratio=0.64
# 8 4
# remaining_states=-10
# max_possible_ratio=0.6
# min_possible_ratio=0.8
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0018.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 7 5
# remaining_states=38
# max_possible_ratio=0.9
# min_possible_ratio=0.14
# 10 2
# remaining_states=26
# max_possible_ratio=0.86
# min_possible_ratio=0.34
# 9 3
# remaining_states=14
# max_possible_ratio=0.8
# min_possible_ratio=0.52
# 7 5
# remaining_states=2
# max_possible_ratio=0.7
# min_possible_ratio=0.66
# 7 5
# remaining_states=-10
# max_possible_ratio=0.6
# min_possible_ratio=0.8
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0019.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 4
# remaining_states=46
# max_possible_ratio=0.92
# min_possible_ratio=0.0
# 0 4
# remaining_states=42
# max_possible_ratio=0.84
# min_possible_ratio=0.0
# 0 4
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 0 4
# remaining_states=34
# max_possible_ratio=0.68
# min_possible_ratio=0.0
# 0 4
# remaining_states=30
# max_possible_ratio=0.6
# min_possible_ratio=0.0
# 0 4
# remaining_states=26
# max_possible_ratio=0.52
# min_possible_ratio=0.0
# 0 4
# remaining_states=22
# max_possible_ratio=0.44
# min_possible_ratio=0.0
# 4 0
# remaining_states=18
# max_possible_ratio=0.44
# min_possible_ratio=0.08
# 0 4
# remaining_states=14
# max_possible_ratio=0.36
# min_possible_ratio=0.08
# 0 4
# remaining_states=10
# max_possible_ratio=0.28
# min_possible_ratio=0.08
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0020.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 0 4
# remaining_states=46
# max_possible_ratio=0.92
# min_possible_ratio=0.0
# 0 4
# remaining_states=42
# max_possible_ratio=0.84
# min_possible_ratio=0.0
# 0 4
# remaining_states=38
# max_possible_ratio=0.76
# min_possible_ratio=0.0
# 0 4
# remaining_states=34
# max_possible_ratio=0.68
# min_possible_ratio=0.0
# 4 0
# remaining_states=30
# max_possible_ratio=0.68
# min_possible_ratio=0.08
# 0 4
# remaining_states=26
# max_possible_ratio=0.6
# min_possible_ratio=0.08
# 4 0
# remaining_states=22
# max_possible_ratio=0.6
# min_possible_ratio=0.16
# 0 4
# remaining_states=18
# max_possible_ratio=0.52
# min_possible_ratio=0.16
# 0 4
# remaining_states=14
# max_possible_ratio=0.44
# min_possible_ratio=0.16
# 0 4
# remaining_states=10
# max_possible_ratio=0.36
# min_possible_ratio=0.16
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0021.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 9 3
# remaining_states=38
# max_possible_ratio=0.94
# min_possible_ratio=0.18
# 0 12
# remaining_states=26
# max_possible_ratio=0.7
# min_possible_ratio=0.18
# 0 12
# remaining_states=14
# max_possible_ratio=0.46
# min_possible_ratio=0.18
# 0 12
# remaining_states=2
# max_possible_ratio=0.22
# min_possible_ratio=0.18
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0022.csv NOT created (requirements not met). Skipping inference.
# Ratios
# 0.25
# 0.75
# 12 0
# remaining_states=38
# max_possible_ratio=1.0
# min_possible_ratio=0.24
# 12 0
# remaining_states=26
# max_possible_ratio=1.0
# min_possible_ratio=0.48
# 0 12
# remaining_states=14
# max_possible_ratio=0.76
# min_possible_ratio=0.48
# 12 0
# remaining_states=2
# max_possible_ratio=0.76
# min_possible_ratio=0.72
# 12 0
# remaining_states=-10
# max_possible_ratio=0.76
# min_possible_ratio=0.96
# [INFO] Dataset data/MICHAŁ_METRICS/datasets/0023.csv NOT created (requirements not met). Skipping inference.
#
# [SUMMARY] Generated datasets: 5/24
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Uruchomienie pełnego eksperymentu (test całego pipeline'u)
# ----> 2 exp_trajectory_length.run_experiment(n_jobs=1)
#       4 # Sprawdzenie, jakie pliki zostały wygenerowane
#       5 from pathlib import Path
#
# File ~/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/analysis/experiment.py:280, in BooleanNetworkExperiment.run_experiment(self, n_jobs, subset)
#     277 print(f"\n[SUMMARY] Generated datasets: {success_count}/{len(rows)}")
#     279 # merge all csv
# --> 280 self._merge_csv()
#     281 # obtain metadata
#     282 self.save_experiment_df_to_csv()
#
# File ~/rok3/sad2/final_project/SAD2_final_project/src/sad2_final_project/analysis/experiment.py:162, in BooleanNetworkExperiment._merge_csv(self, csv_dir)
#     160 csv_files = sorted(csv_dir.glob("*.csv"))
#     161 if not csv_files:
# --> 162     raise RuntimeError("No CSV files to merge")
#     163 # join pdfs
#     164 df = pd.concat(
#     165     (pd.read_csv(f) for f in csv_files),
#     166     ignore_index=True
#     167 )
#
# RuntimeError: No CSV files to merge
